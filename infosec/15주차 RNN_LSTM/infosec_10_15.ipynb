# %% [markdown]
# # Word2Vector를 이용한 네이버 영화평 감정 분석

# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.5.30)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %%
from konlpy.tag import Twitter
from tqdm.notebook import tqdm
from gensim.models import Word2Vec
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
train_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_train.txt'
test_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_test.txt'

# %%
with open( train_path, 'r', encoding = 'utf-8') as f:
  for line in f.read().splitlines():
    print("line =",line)
    print("line.split(\t)", line.split('\t'))
    print("="*100)

# %%
# 테스트셋 로드
with open( train_path, 'r', encoding = 'utf-8') as f:

  result = [i.split('\t') for i in f.read().splitlines()]

# 첫 번쨰 칸 빼고 , 
result = result[1:]

train_tmp = result

# %%
train_tmp
# Out:
# [['9976970', '아 더빙.. 진짜 짜증나네요 목소리', '0'],
#  ['3819312', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '1'],
#  ['10265843', '너무재밓었다그래서보는것을추천한다', '0'],
#  ['9045019', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '0'],
#  ['6483659',
#   '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다',
#   '1'],
#  ['5403919', '막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.', '0'],
#  ['7797314', '원작의 긴장감을 제대로 살려내지못했다.', '0'],
#  ['9443947',
#   '별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네',
#   '0'],
#  ['7156791', '액션이 없는데도 재미 있는 몇안되는 영화', '1'],
#  ['5912145', '왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?', '1'],
#  ['9008700', '걍인피니트가짱이다.진짜짱이다♥', '1'],
#  ['10217543', '볼때마다 눈물나서 죽겠다90년대의 향수자극!!허진호는 감성절제멜로의 달인이다~', '1'],
#  ['5957425', '울면서 손들고 횡단보도 건널때 뛰쳐나올뻔 이범수 연기 드럽게못해', '0'],
#  ['8628627', '담백하고 깔끔해서 좋다. 신문기사로만 보다 보면 자꾸 잊어버린다. 그들도 사람이었다는 것을.', '1'],
#  ['9864035', '취향은 존중한다지만 진짜 내생에 극장에서 본 영화중 가장 노잼 노감동임 스토리도 어거지고 감동도 어거지', '0'],
#  ['6852435', 'ㄱ냥 매번 긴장되고 재밋음ㅠㅠ', '1'],
#  ['9143163',
#   '참 사람들 웃긴게 바스코가 이기면 락스코라고 까고바비가 이기면 아이돌이라고 깐다.그냥 까고싶어서 안달난것처럼 보인다',
#   '1'],
#  ['4891476', '굿바이 레닌 표절인것은 이해하는데 왜 뒤로 갈수록 재미없어지냐', '0'],
#  ['7465483', '이건 정말 깨알 캐스팅과 질퍽하지않은 산뜻한 내용구성이 잘 버무러진 깨알일드!!♥', '1'],
#  ['3989148', '약탈자를 위한 변명, 이라. 저놈들은 착한놈들 절대 아닌걸요.', '1'],
#  ['4581211', '나름 심오한 뜻도 있는 듯. 그냥 학생이 선생과 놀아나는 영화는 절대 아님', '1'],
#  ['2718894', '보면서 웃지 않는 건 불가능하다', '1'],
#  ['9705777',
#   '재미없다 지루하고. 같은 음식 영화인데도 바베트의 만찬하고 넘 차이남....바베트의 만찬은 이야기도 있고 음식 보는재미도 있는데 ; 이건 볼게없다 음식도 별로 안나오고, 핀란드 풍경이라도 구경할랫는데 그것도 별로 안나옴 ㅡㅡ',
#   '0'],
#  ['471131', '절대 평범한 영화가 아닌 수작이라는걸 말씀드립니다.', '1'],
#  ['8480268', '주제는 좋은데 중반부터 지루하다', '0'],
#  ['4254115', '다 짤랐을꺼야. 그래서 납득할 수 없었던거야.. 그럴꺼야.. 꼭 그랬던걸꺼야..', '0'],
#  ['7295746', 'kl2g 고추를 털어버려야 할텐데', '1'],
#  ['5457633', '카밀라벨 발연기', '0'],
#  ['6091784', '재밋는뎅', '1'],
#  ['8322926', '센스있는 연출력..탁월한 캐스팅..90년대의 향수.. 그래서 9점..', '1'],
#  ['6331922', '엄포스의 위력을 다시 한번 깨닫게 해준 적.남 꽃검사님도 연기 정말 좋았어요! 완전 명품드라마!', '1'],
#  ['9005897', '졸쓰레기 진부하고말도안됌ㅋㅋ 아..시간아까워', '0'],
#  ['164908', '재밌는데 별점이 왜이리 낮은고', '1'],
#  ['9671124', '1%라도 기대했던 내가 죄인입니다 죄인입니다....', '0'],
#  ['5712231', '아직도 이 드라마는 내인생의 최고!', '1'],
#  ['4726746', '패션에 대한 열정! 안나 윈투어!', '1'],
#  ['7203432', '키이라 나이틀리가 연기하고자 했던건 대체 정신장애일까 틱장애일까', '0'],
#  ['112724', '허허...원작가 정신나간 유령이라... 재미있겠네요!', '1'],
#  ['1105872', '포스터는 있어보이는데 관객은 114명이네', '0'],
#  ['4805788', '이 영화가 왜 이렇게 저평가 받는지 모르겠다', '1'],
#  ['9336496', '단순하면서 은은한 매력의 영화', '1'],
#  ['9994900',
#   "'다 알바생인가 내용도 없고 무서운거도 없고 웃긴거도 하나도 없음 완전 별싱거운 영화.ㅇ.ㅇ내ㅇ시간 넘 아까움 .. . 완전 낚임",
#   '0'],
#  ['6760577', '오게두어라! 서리한이 굶주렸다!', '1'],
#  ['3440864', '정말 맘에 들어요. 그래서 또 보고싶은데 또 보는 방법이 없네? >.. ㅜㅡ', '1'],
#  ['8548510',
#   '윤제문이라는 멋진 배우를 발견하게 됐어요. 소소한 일탈이 잔잔한 미소를 머금게 합니다. 음악은 조금 아쉽네요ㅠㅠ 8점 주고 싶은데 평점 올리고 싶어 10점 줄게요^^',
#   '1'],
#  ['7719892', '평점에속지마시길시간낭비 돈낭비임', '0'],
#  ['9440670',
#   '리얼리티가 뛰어나긴 한데 큰 공감은 안간다. 이민기캐릭터는 정신의학상 분노조절장애 초기 증상일거다. 툭하면 사람패고 욕하고 물건 파손하고.. 조금 오바였음. 극 초반엔 신선했는데 가면 갈수록 이민기 정신상태 공감불가.',
#   '0'],
#  ['7991636', '마이너스는 왜없냐 ㅋ 뮤비 보고 영화수준 딱 알만하더군 ㅉㅉ 북한에서 이런거 만들라고 돈 대주던?', '0'],
#  ['4679407', '난 우리영화를 사랑합니다....^^;', '0'],
#  ['9837767',
#   '데너리스 타르 가르엔...나도 용의주인이 되고 싶다...누이랑,근친상간이나 하고 다닐지라도,소설 속에선 제일 멋진 놈이 자이메 라니스터였는데,드라마속에선,드래곤(용)이 제일 멋지네(웃음)감독님 토르-2 다크 월드는 말아 잡수셨을지라도,기본 선방은 했음',
#   '1'],
#  ['9063648', '영화가 사람의 영혼을 어루만져 줄 수도 있군요 거친 세상사를 잠시 잊고 동화같은 영화에 행복했네요', '1'],
#  ['8272095', '야 세르게이! 작은고추의 매운맛을 보여주마! 포퐁저그 콩진호가 간다', '0'],
#  ['2345905', '이렇게 가슴시리게 본 드라마가 또 있을까? 감동 그 자체!', '1'],
#  ['7865630', '난또 저 꼬마애가 무슨 원한이 깊길래.,. 했더니 OO 그냥 혼자 나대다 OO걸 어쩌라고.', '0'],
#  ['7207064', '재미있어요', '1'],
#  ['5719655', '전 좋아요', '1'],
#  ['1651126', '최고', '0'],
#  ['7246040',
#   '너무 충격적이엇다. 기분을 완전히 푹 꺼지게 하는 느낌... 활력이라고는 하나도 없는 너무나도 무거운....지독하고 차갑고 무자비하다. 그저 일본인들의 상상력은 정말 대단한거 같다는 생각이 든다.',
#   '1'],
#  ['717775', '심심한영화.', '0'],
#  ['8317483', '백봉기 언제나오나요?', '1'],
#  ['1031725', '보는내내 그대로 들어맞는 예측 카리스마 없는 악역', '0'],
#  ['3993146', '불알이 나와서 당황...아무튼 영화가 중간에 끝나는 느낌', '0'],
#  ['2196616', '평범함속에 녹아든 평범한 일상. 조금 밋밋한게 흠.', '0'],
#  ['8203798',
#   '보던거라 계속보고있는데 전개도 느리고 주인공인 은희는 한두컷 나오면서 소극적인모습에 짜증이 ㅜㅜ 맨날 언제끝나나 기대만하고있어요 전개좀 빨리빨리 ㅜㅜ',
#   '0'],
#  ['2332588', '사랑하고싶게하는,가슴속온감정을헤집어놓는영화예요정말최고.', '1'],
#  ['10084753',
#   '많은 사람들이 이 다큐를 보고 우리나라 슬픈 현대사의 한 단면에 대해 깊이 생각하고 사죄하고 바로 잡기 위해 노력했으면 합니다. 말로만 듣던 보도연맹, 그 민간인 학살이 이정도 일 줄이야. 이건 명백한 살인입니다. 살인자들은 다 어디있나요?',
#   '1'],
#  ['8518645',
#   '예전 작품 캐릭터, 에피소드 재탕 삼탕 사골우려먹듯 우리고 내용은 산으로 가고 시청률은 아예안나오고 이제 70회중반인데 120부작이라니 ...',
#   '0'],
#  ['7956793', '김남길의 백점짜리 연기력과 초반 몰입도에도 불구하고 지루하고 손예진 ㅈㅈ', '0'],
#  ['3996917', '재밌네 비슷한 영화를 안보신 분들한테는 재미있을 듯', '1'],
#  ['8128006', '노래실력으로뽑는게 맞냐? 박시환이 mama나가면 진짜 망신이다', '0'],
#  ['2192046', '아 일본영화 다이런건가?? 유치하다', '0'],
#  ['7250961',
#   '이틀만에 다 봤어요 재밌어요 근데 차 안에 물건 넣어 조작하려고 하면 차 안이 열려있다던지 집 안이 활짝 열려서 아무나 들어간다던가 문자를 조작하려고하면 비번이 안 걸려있고 ㅋㅋㅋ 그런 건 억지스러웠는데 그래도 내용 자체는 좋았어요',
#   '1'],
#  ['5679106', '졸작', '0'],
#  ['9179128', '재밋네요 달팽이가 빨라서 더 재밌었어요', '1'],
#  ['9048450', '어설픈 전개 어이없는 결말', '0'],
#  ['8387244', '부패한 로마노프 왕조를 기리는 뭣같은 영화... 온몸으로 항거했던 러시아 민중들이 그저 폭도냐', '0'],
#  ['9803156', '내용전개는 무난한 편이였구 잘 보았습니다 ^^', '1'],
#  ['2135015', '매우 실망.....', '0'],
#  ['7884025', '한국영화 흥행코드: 갈등-갈등-계~에속 갈등-화해-감동- 평점 10점 남발- 흥행 뻔하지 뭐...', '0'],
#  ['9801316', '아햏햏 아햏햏 아햏햏.', '1'],
#  ['2009382', '뭐냐..시작하고 3분만에 나왔다. 리플릿 사진 보며 불안하더니만..', '0'],
#  ['10112591', '단연 최고라고 할수있지', '1'],
#  ['7280935', '감독이 럼먹고 영화를 만들었나보다.. 관객에게 뭘 말하는지도 모르겠고, 엉망진창 개진창이다.', '0'],
#  ['5971506', '이건 뭐냐? 우뢰매냐? ;;;', '0'],
#  ['9875922', '정말쓰레기영화입니다', '0'],
#  ['9850710', '진정 위대한 영화 최고임', '1'],
#  ['1927486', '별루 였다..', '0'],
#  ['5023820', '내일이 기대되는 `', '1'],
#  ['1859380', '근데 조미가 막문위 좋아한건가요??', '1'],
#  ['1635552', 'ㅋㅋㅋ 진짜 골깜..ㅋㅋ 눈 부라릴때 쓰러짐..ㅋㅋ', '1'],
#  ['7852366', '성룡영화중 최악인듯 ㅋㅋ', '0'],
#  ['9480003', '골때리네ㅋㅋㅋㅋ 걸스데이 이혜리 잘 되라!', '1'],
#  ['1797212', '서기가이뻐서', '1'],
#  ['6374262', '완전 재밌어요ㅋㅋㅋㅋㅋ백인공주귀여움ㅋㅋㅋㅋㅋㅋ', '1'],
#  ['1607129', '인상적인 영화였다', '1'],
#  ['8763660', '어내스트와 셀레스틴 완전 강추에요~ 정말 재밌습니다^^', '1'],
#  ['9361974', '재미있는영화입니다.', '1'],
#  ['7928957', '클라라볼라고화신본거아닌데', '0'],
#  ['10250221', '진짜 보면서 너무 슬펐던 영화다', '1'],
#  ['6122458', '설정이 재밌고 새로운 에피소드 내에서 메인 스토리도 차차 나오는게 재밌음', '1'],
#  ['10044377', '신카이 마코토의 작화와,미유와 하나카나가 연기를 잘해줘서 더대박이였다.', '1'],
#  ['6158844', '재미없음 진심 1이훨나 캐스팅두못한듯', '0'],
#  ['1723799', '잔잔한게 생각보다 볼만한 영화인거 같습니다 ㅋ', '1'],
#  ['10273782', '감독님들 고은님 쓰면 영화안봅니다 .', '0'],
#  ['1666795', '무섭지도 않았고 스토리도 ..ㅡㅡ', '0'],
#  ['4866815', '영화속 억지스럽고 노골적인 술광고를 좀 은은하고 센스있게 했으면 어땠을까?', '0'],
#  ['7747745', '킬링타임', '0'],
#  ['8213218', '크리스마스하면 떠오르는영화', '1'],
#  ['8659712', "재미있게 봤습니다. 매력적인 행복이네요, '-' ㅎㅎㅎ.", '1'],
#  ['1204710', '음악에 완전히 빠져서 볼 수 있었던 영화. 쫌 산만하긴 하던데;;', '1'],
#  ['3926204', '태어나서 처음으로 영화보다 중간에 나왔습니다,,,,불륜이 로맨스냐,,', '0'],
#  ['2304429', '왕짜증.....아주 전개를 짬뽕으로 믹스했구나...음향만 무섭게하네..하아', '0'],
#  ['9685228', '솔직히 난 별루더라 시간낭비느낌', '0'],
#  ['7115568', '대박', '1'],
#  ['6205383', '시청률 기준이 되는 패널가구들 머하는거지 명작드라마 다 망치네 ㅡㅡ 내가 다 서운하다...', '1'],
#  ['85848', '내용이 이상해;', '0'],
#  ['8741214', '몬스터 주식회사 3D 재밌게 봤다', '1'],
#  ['7785809', '내용전개가 너무나 느리다........', '0'],
#  ['9757434', '소재는 흥미를 끌지만 이야기 전개가 투박해서 몰입이 안되는군', '0'],
#  ['9753792', '절대 보지마라 쓰레기 영화', '0'],
#  ['7520154',
#   '중국인 특유의 과장, 허풍... 있어보이려고 안간힘 쓴 노력은 가상하나, 고증과 현실감 떨어지는 설정이 거북스럽다... 도대체 그들은 왜 이렇게까지 스스로를 과대포장하는 것인지...',
#   '0'],
#  ['8902582',
#   '그냥 불법체류자 때려잡는 영화면 좋았을텐데...무슨 우상화를 만든다고 미국의 따뜻한 설정...이건 뭥미??',
#   '0'],
#  ['9578691', '2년의 삶속에 주인공의 생애가 전부 드러난 듯 하다.', '1'],
#  ['7469033', '별점10점가자', '1'],
#  ['3914806', '별로다.', '0'],
#  ['10212945', '본지 꽤 지난 후에 남기지만...재미있었음', '1'],
#  ['9893434', '아니 이게 왜 9점대 일까...;;;', '0'],
#  ['9615602', '10년이 지나 다시 보게된 영화 .. 다시봐도 그 순수한 사랑에 감동 ㅠㅠ 숀펜의 연기또한 甲', '1'],
#  ['10138538',
#   '올레에 공짜로있길래 봤음 ㅋㅋ 헐 ... 스토리가 문제가아니라 연기자들이 전혀 배역이랑 어울리지않음 그리고 상대배우들하고 다 따로 노는거같음~~ 이건 연기자들도 문제있음 보아는 진심 완전 별로임 라미란하고 아들이 젤 볼만했음',
#   '0'],
#  ['6139250', '너무 욕심이 많았던 영화. 어느 한 쪽만이라도 제대로 보여줬다면......', '0'],
#  ['6738759', '아 빵점~', '0'],
#  ['10108387', '베댓이 말을 아주 잘써놨네', '1'],
#  ['5678216', '아주 모자라진 않다.', '0'],
#  ['8470143', '영화 도둑들이나 뫼비우스 하고 같은 나라에서 만들어졌다는게 믿어지냐..?', '0'],
#  ['6565615', '온몸이.. 찌릿..짜릿. 나두 용기를 가져야지!!', '1'],
#  ['7838658', '정말재미있고 교훈적인 영화이네요!', '1'],
#  ['3526263', '당시의 상황과 주제를 주입식이 아닌 긴장감있고 재밌게 전하는 작품', '1'],
#  ['625839', '케이블에서 그만 나와줬으면 - -', '0'],
#  ['6153764', '다르덴,이냐리투,차이밍량이 하나도 안섞인채 짬뽕 그릇에 담겨있다.', '0'],
#  ['9179457', '여군 잼없음 뭐하는건지 ...ㅡㅡ잼없음 엠비씨 다잼없음 질린다이제', '0'],
#  ['3685947', '좋구나', '1'],
#  ['8747603', '한석규, 김혜수 연기만 돋보인 영화. 어딘지 모르게 많이 어설픈 영화.', '0'],
#  ['9153275',
#   '솔직히 에볼라바이러스가 떠들석해서 보게된영화인데 작품성이나 어떤면에서도 20여년전 영화라고보기엔 믿기힘들정도로 정말 잘만들었다고본다 마지막후반부가 살짝 아쉽긴하지만 이정도면 수작이라고본다 시간이 아깝지않은영화',
#   '1'],
#  ['2850477', '볼만해;', '0'],
#  ['8513072', '재미있다고 허풍 떨지 마세요', '0'],
#  ['8546726', '용가리 진짜짱짱맨이다ㅋ', '0'],
#  ['8674440',
#   '이 영화를 이제서야 보다니.. 감히 내 인생 최고의 영화중 하나로 꼽을 수 있을만한 작품. 어떻게 살아야할지 나를 위한 고민을 한번 더 하게 되는 시간. 그리고 모건 프리먼은 나이가 들어도 여전히 섹시하다.',
#   '1'],
#  ['6842532', '작가가별로다 내용이진짜별로임.. 맨날그냥기대하고 재방송하면 혹시나하고봐줘도 답없다진짜..', '0'],
#  ['9106604', '명작도 이런 명작이 있을까 싶다. 보고 또 봐도 여운이 남는 영화.', '1'],
#  ['10261336',
#   '아~ 진짜 조금만 더 손 좀 보면 왠만한 상업 영화 못지 않게 퀄리티 쩔게 만들어 질 수 있었는데 아쉽네요 그래도 충분히 재미있었습니다 개인적으로 조금만 더 잔인하게 더 자극적으로 노출씬도 화끈하게 했더라면 어땠을까 하는 국산영화라 많이 아낀 듯 보임',
#   '1'],
#  ['8518274', '그만좀 끌고 이제 끝내라. 지겹다 지겨워.', '0'],
#  ['7348295', '아', '0'],
#  ['5882876', '역시 드니로의 연기는 일품 나도 맥스가 샘을 죽이길 바랬다', '1'],
#  ['8472176', '나름 괜찮은 작품입니다', '1'],
#  ['4446905', '너무 좋은 영화', '1'],
#  ['6252170', '정말 실망 스러웟음..', '0'],
#  ['8777723',
#   '배우들은 지네들 안뜨니까 이런영화 찍을껀데??? 왜 안뜨는지 진짜 모르는거야? 면상 딱 보면 알겠구만... 왜 지네 자신들은 모를까?',
#   '0'],
#  ['8670820', '어린이가 좋아할듯...내어릴적 동심은 멀리 떠낫나보다.', '0'],
#  ['3384269', '무술인이 왜 총을드나?', '0'],
#  ['7781028', '10점', '1'],
#  ['9890330', '크리스토퍼왈츠와 타란티노의 조합이란 ㅠㅠ', '1'],
#  ['8660428', '한국에선유명한편은아니지만 외국에선 상상초월한 유명한 영화입니다.', '1'],
#  ['10212029', '오랜만에 재밋는영화봤네요', '1'],
#  ['8575963',
#   '종방되어 아쉬워요. 오늘막방도 잘봤어요.방송대본이 꽤 완성도있다는 느낌받았고요. 요즘 드라마들의 막장에 지쳐있었는데 수백향은 정말 바른드라마였던듯해요.악역들도 그리 심하게 어이없지도 않았고요..MBC화이팅!!',
#   '1'],
#  ['7033414',
#   '평점조절위원회에서 나왔습니다(웃음)김혜선은 @내일이 오면@의 김순정,순정이 역할이 제일이다.팜므파탈로써,그 정도까지 잘해낼 줄은,정말 의외였어...연기20년 한사람에게 요즘 사극에서 벌어지고 있는,그녀에 대한 연기논란은 왠지 코미디의한장면 같음(웃음)',
#   '0'],
#  ['10122280', '"""영화 끝나갈때쯤에 멍하다가 다보고나면 한마디 나올거임 """"ㅈ같다."""""""', '1'],
#  ['8062501', '공유 존잘!!!ㅎㅎㅎ', '1'],
#  ['2937929', '상쾌발랄한 영화다. 말하기 껄끄런 성이란 소재를 유쾌하게 해설했다.', '1'],
#  ['4777325', '소파에 죽 치고 앉아 지켜 볼 이유가 없는 작품.', '0'],
#  ['7047706', '로큰롤!!!!!!!!!!!!!!', '1'],
#  ['7263316',
#   '주된 타겟이 어린이니 일반적인 논리가 통하지 않는 건 알겠다. 하지만 게임은 흥미롭지 않고, 요원이라는 주인공이 너무 무능력해서 별로 재미없다. CG 배경도 거슬린다.',
#   '0'],
#  ['9297500',
#   '뮤지컬 영화인데 사운드 녹음 엉망, 남주는 춤도 못추고, 내용은 뻔할뻔, 주인공들 목소리도 너무 안어울리고 어제 CGV에서 뛰어 나가려다 참았습니다.진심 말리고 싶습니다. 영국의 저예산 DVD용 영화뮤지컬영화 아닙니다. 맘마미아 1/10도 안됨',
#   '0'],
#  ['3234156', '어린나이에 봤음에도 꽤나 좋아했던 로맨틱코미디', '1'],
#  ['6245450', '게이물인줄 모르고 봤네...', '0'],
#  ['5249559', '알바는꺼저라', '0'],
#  ['8570013',
#   '이 영화 머임????내가 왜 받아 봤을까? 그것이 알고싶다....이 영화는 배우들과 스텝들이 감독의 꼭두각시였음.',
#   '0'],
#  ['8880577', '4대2라니....최악', '0'],
#  ['6197121', '정말 아름다운 영화 입니다', '1'],
#  ['9169160', '자극적인 것에 익숙해진 현대인이 봐도 눈을 떼기 힘든 연출력.', '1'],
#  ['10066840', '뻑~뻑~잘 읽어볼걸 나도 당했음', '1'],
#  ['8681070',
#   '정말 짜증의 극치를 보여주는영화. 굉장히 언밸러스한 느낌. 뚱뚱하고 못생긴 남자애의 발연기를 시종일관 봐야하는게 고역인듯. 간간히 흘러나오는 잔잔한 클래식풍의 음악조차도 듣기싫어 짜증날정도로 상당히 싫은영화.',
#   '0'],
#  ['6077668', '감동감동ㅜㅜ, 정말 최고네요!!!!', '1'],
#  ['6555618',
#   '별점 주기도 아깝네요 얼마나 내용이 진부한지 욕 밖에 안나오네요보고 재밌다고 하는 사람 초딩들인가요 죄송해요 너무 화가나서.아무 것도 볼게 없습니다 보지 마세요 그냥 티비판짜집기 한거 같네요',
#   '0'],
#  ['4989285', '나 왠만해서 짜증안내는데...-_-', '0'],
#  ['1711932', '돼지피먹고 닭목따는 장면에선 우웩~ 역시 무당은 아무나 하는게 아니다.', '0'],
#  ['1870395', '버려', '0'],
#  ['9829888', '유치하고 지루하고 잠이 왔다', '0'],
#  ['8333987', '3류풍 판타지 3점만 가져가', '0'],
#  ['8126489',
#   '윤종신 복귀는 좋았지만 이하늘은 도대체 왜 뽑혔는지 알수가없다. 참가자 실력을 따지기 전에 심사위원 인격과 실력부터 쌓고 오시길^^ 어하어허 그만좀 하고요',
#   '0'],
#  ['81637', '광장한 작품 옛날것도 보고 싶다', '1'],
#  ['23929', '내 생의 최고의 영화', '1'],
#  ['6663588', '어린시절 너무 무섭고 재미있게 봤던 추억의 판타지영화.절대 나쁜짓은 금물.지옥가요..', '1'],
#  ['5503928', '기존 멜로영화 형식을 탈피하려고 하였으나 감정의 절제가 지나쳐 너무 담백한 영화', '0'],
#  ['6344106', '난 사랑비 서준에게 쏙 빠져버렸네. 1.2.3초만에 쏙ㅋㅋ난 절대잊지도않고후회도안할거야', '1'],
#  ['10149152', '이영화를보니까 교훈을 주네요! 나도 남은인생을 화려하게 살아야겟다.. 말밖에 안나오네요..', '1'],
#  ['9295404', '나름 추억에 젖어들고 좋았음ㅋㅋ아무생각없이 가볍게 보고오기 추천요~', '1'],
#  ['9603725', '단순한 싸이코물을 벗어난', '1'],
#  ['9163009', '이게 14년도에 만들어진건가요? 아니면 예전에 만든거 다시개봉한건가요?ㅠ너무 허접해요 ㅠ', '0'],
#  ['9418231', '넘 사랑스러운 영화다 ㅠㅠ 1보고 2 연이어 봤다~!! 넘 귀여워 ㅠㅠ♥♥', '1'],
#  ['9687122',
#   '청춘 영화만이 줄 수 있는 감성이 넘쳐난다. 이 순간 지나가면 다시 돌아오지 않을테지만, 그 순간만큼은 무한할 젊음이 줄 수 있는 그런 감성.',
#   '1'],
#  ['4038387', 'TV용 건담 시리즈 중에서 아직까지도 최고봉', '1'],
#  ['8913715', '개콘은 요즘 갈수록 코너들이 다노잼이고 웃음이안난다', '0'],
#  ['7927383', '사다코의 한이 서린 우물펀치ㅜㅜ 감동', '1'],
#  ['8508764',
#   '후세와 사랑하게된 결정적 계기 그시간이 표현되지 않았으며 시람의 생명을 빼앗아야만하는이유등을 시노가 출현하는 연극으 로 더 알려주었으면 하는 생각이든다. 또한 시노가 얼마나 본능을절제히면서 시랑을 하려고 노력하는지를 더 보여줬다면 좋았을뻔했다',
#   '0'],
#  ['3403149', '새벽시간에 하는 일본 영화들은 전부 개졸작이다.일본영화원래 다이래??', '0'],
#  ['1119950', '강수연의 나가있어~!그리고 최정원의 신음신~', '0'],
#  ['6976560', '아..정말 김혜성 너무 예쁘네요 이현진도 웃는 거 정말...하....', '1'],
#  ['4817061', '가발 쓰고 싶다', '0'],
#  ['1025241', '화려한여정이인상깊어요ㅋㅋ재밋어요ㅋㅋ배두나연기정말잘해요ㅋ', '1'],
#  ['2922082', '10대들을 위한 성적 호기심 영화?', '0'],
#  ['5444748', '감동적인 영화', '1'],
#  ['9363921', '이건 말이 필요 없다 그냥 닥치고 봐라', '1'],
#  ['2361255', '각기 다른 사람들의 재밌고 멋진 사랑영화', '1'],
#  ['2385954', '역시 미국드라마의 파워. 정말 알수없는 그 미묘함까지 사로잡아버렸다 최고!!', '1'],
#  ['5686473', '너무너무 훈훈하네요^^', '1'],
#  ['7227535', '이거 응답하라에서 은지원원도 스스로 욕하지 않앗나? ㅋㅋㅋㅋ', '0'],
#  ['1508152', '아 너무 웃기고 배꼽 빠질뻔했네^^ 내 컴에 이 영화 있는데^^', '1'],
#  ['3943125', '구성이 상당히 부실한 영화. 역시 네이버 평점은 믿을수 없다.', '0'],
#  ['1922525', '장끌로드의 몰락을 가져온 오우삼 헐리우드 작품중 가장 재미없었던 졸작', '0'],
#  ['9039778', '언제적 영웅본색 연출인지 현실성 제로인 영화', '0'],
#  ['7805059',
#   '작은거 하나에도 설레어했던 학창시절 그때 그느낌을 다시 느껴볼수있는시간이었다. 장면 하나 하나 대사 하나 하나 배경음악 하나 하나 버릴게 없는 드라마.',
#   '1'],
#  ['9324383', '진심 재미 없는데 너무 평점 높아서 화남;', '0'],
#  ['9150201', '더럽게 재미없다 어떤 형태로도 와 닿지 않는 허무하고 완벽히 지루한 영화고 영양가 하나도 없는 영화다', '0'],
#  ['7473724', '이승기 정말 연기 잘하는.. 조연들도 연기 정말 잘하고', '1'],
#  ['7573034', '현실은 꿈, 꿈은 현실', '1'],
#  ['4550192', '오늘 현충일특집프로로 보게되었습니다 1963년도의 매우 훌륭한 작품입니다', '1'],
#  ['1347002', '판의미로와 동급 trash of the trash', '0'],
#  ['6590993', '제대하고 보니까 더 재밌네요 ㅋㅋㅋㅋ', '1'],
#  ['6580205',
#   '영화를 보는것만으로도 마음의 휴가를 다녀온 느낌.소박하지고 잔잔하지만 지루하지않은..그래서 다시 보고싶은 영화.햇살가득한 비이의 부엌과 요리도 인상적',
#   '1'],
#  ['9666256', '코믹한건 좋았는데 짜임새가 너무 허술하다', '0'],
#  ['9967162',
#   '1996년 그때 당시에는 우리 나라에 이런 판타지 로맨스가 없었다... 아직도 신현준의 황장군 연기는 음... 괜찮네... ㅎㅎ....한석규의 전성시대가 열린 영화.... 이때 한석규한테 뿅 갔었다~~♥',
#   '1'],
#  ['5304583', '일단 재생하면 괴물같은 서스펜스 귀신같은 흡입력', '1'],
#  ['8309459',
#   "하..진짜 댓글보고 한번쯤볼만한 영화인거같아서봤지만 기가찬다..이게무슨버킷리스트인가! 죽기직전에 소원들어주기? 내가보기엔 죽기직전에 막 살자 인거같다. 감동도없고.. 진짜 '버킷리스트' 란 영화에 발톱에 때만큼도 못따라가는쓰레기영화.. 완존실망..",
#   '0'],
#  ['8010423',
#   '이시간좀...밝고긍정적인드라마보고싶어서..보긴보는데....오버하는연기들이거슬리네요...연기인게너무표나요....홍혜정역이그나마도후련기도하고시원하고.....나머진다들답답하네요...낼월요일인데...해피한것만보고싶네요....',
#   '0'],
#  ['7712668', '정치인의 모순인가, 정치범의 모순인가....', '0'],
#  ['5923805', '어떻게 이런 상상을 대단하다.', '1'],
#  ['5613442', '좀 어렵기도 하고, 전쟁에 대한 묘사가... 잘 모르겠다.', '0'],
#  ['4193028', '일본에서10주년 극장판만드는데 우리나라에선 10주년으로 재개봉하니이건 좀 ㅄ 아님?', '0'],
#  ['9103654', '한대희가 개그콘서트본다고 내전화끊음개그콘서트 없애주세요 ㅡㅡ', '0'],
#  ['9737474', '한물 간 동서양 두 배우의 싸움판.', '0'],
#  ['8711262', '푸하하하 이거 기대 안했지만.. 역시나 구만..ㅋ', '0'],
#  ['4437265', '세계최초의 반공 애니매이션이라는 역사적 가치가 있다.', '1'],
#  ['36087', '감각적인..시각으로...바라보는..색다른...느낌의...사랑...문학적이', '1'],
#  ['10114923', '엄마는 무고한 지 딸을 감옥살이 시켜시켜? 이해 안돼요', '0'],
#  ['3988502', '이영화는.제발 책을보세여.감독이 미친겁니다.이따위로 만들어놓고.화가 날정도 ㅡㅡ', '0'],
#  ['512688', '신나는 흑인음악과 아이스 큐브 뿐 남는게 없다', '0'],
#  ['10010968', '드럽게 재미없네 시간이 돈이다? 내 시간은 어쩔건데', '0'],
#  ['3265565', "그저 한마디뿐 '알리시아'", '1'],
#  ['8890254', '진짜 생생하게 느낄 수 있었다', '1'],
#  ['9119967', '재밌는데 평점이 이상하다 싶을 정도로 낮다.', '1'],
#  ['7435669', '옥소리 프로필 사진에 1점남기고 갑니다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ완전 대박이다 진짜 아우 짜증나!', '0'],
#  ['7603466', '드라마 너무 재밓당', '1'],
#  ['8055931', '아진짜너무좋아요ㅜㅜ짱짱!!!', '1'],
#  ['2182684', '연기 굿', '1'],
#  ['8154957', '이런 영화 다시는 안나오겠지..그때 시절을 잘나타내주었던거같아요 ㅎㅎ', '1'],
#  ['3545895', '중간정도 부터 봤는데도 꽤나 대단하군요...', '1'],
#  ['9414462', '콩은 까야 제맛 콩은 까야 제맛', '0'],
#  ['6291727', '이적의 소설. 재미없다.', '0'],
#  ['3427286', '액션영화가 아니다.범죄 느와르 영화다. 허나 범죄 느와르 영화로서도 실패작.......', '0'],
#  ['1207277', '뭔가알수없는매력에빠져드는 영화', '1'],
#  ['8670966',
#   '모녀를 토막살해한 살인자가 부성애라니.... 말이되나... 감동받은 사람들 본인들이 피해자가 되도 감동받았다고 할수있을까... 진심 묻고싶습니다...',
#   '0'],
#  ['6871120', '재밌는데 평점이 왜 이렇게 구리지', '1'],
#  ['5124760', '아 OOO기.. 이걸 본 내눈이 아깝다 ㅡㅡ 진짜 아놔 진짜 OOO기명작이네요', '0'],
#  ['6931068', '필름값이 아깝다..재미 더럽게없다..2점부터 점수준것들 매미 OO', '0'],
#  ['1618314', '또보고 싶은데 어디서 보죠???', '1'],
#  ['4289323', '영화 재미있드만.. ㅎㅎ', '1'],
#  ['8381652',
#   '남주인공 연기력 안습이네요... 혀짧은 소리 듣기도 너무 힘들었네요 매니저역활분이 남주인공하는게 훨 좋았겠다는 생각이 들정도... 영화 자체는 적당히 볼 만 합니다 ^^',
#   '0'],
#  ['8557261', '3점이 딱.... 액션,스릴러인데 액션과 스릴이 없다.', '0'],
#  ['3187395', '완전 스토리도 엉망이구, 완전 비추..ㅜ', '0'],
#  ['10274403', 'OOO영화 뭘전달하려는지모르겠네 오글거리고', '0'],
#  ['2523528', '좋은영화', '1'],
#  ['7041870', '......더빙이 이상해요.....할머니는 월래익숙한 ㄷㅔ.....', '0'],
#  ['9268003', '이게 2편이 나왔어???', '0'],
#  ['917164', '모든게 2%씩 다 부족했다...아니..50%씩...', '0'],
#  ['1595727', "정말 말 그대로 '쇼'하는 영화..", '0'],
#  ['10079284', '12년 전에 봐서 기억이 나질 않지만 진개가(천카이거) 감독 이름 세 자는 기억해 두었던.', '1'],
#  ['9077483',
#   '정은지 언니!! 연기 잘하구..노래도 잘부르시고! 마지막회 웃으면서 즐겁게! 봤습니다! 트로트의 연인!♥',
#   '1'],
#  ['1724444', '이게 웃겨?', '0'],
#  ['7124022', '망함', '0'],
#  ['6409443', '아이의 시선으로 보는 전쟁.., 보는 내내 가슴이 먹먹했다는...', '1'],
#  ['10243387',
#   '사람들이 재미없다고 해서 레알 기대 안했는데 생각보다 볼만함. 근데 여자애랑 복순이랑 다투는 장면? 그건 굳이 없어도 됐다고 생각함 몰입도 겁나 없애고, 어색해보였음',
#   '0'],
#  ['2577310', '설정이 연속극같은 느낌이 든다. 하지만 배우들의 연기가 뛰어나다.', '1'],
#  ['4523923', '여주인공 인터뷰할때 지루해죽는줄알았음 ㅡㅡ 그냥저냥 킬링타임용 스릴러', '0'],
#  ['7862272',
#   '전미 박스 오피스1위 ㅋㅋ 그냥 몰아주기 하는건가 어떻게 이런영화가 1위를 하지 옛날 80~90년대 우뢰매수준의 물폭탄싸움이네 ㅋㅋ 손에서 빔나가나 손에서 물폭탄 나가나 다를게 뭐지?',
#   '0'],
#  ['573776', '감독이 여자다보니 기량이 많이 딸리네', '0'],
#  ['9056760', '또 보고 또 울.었.다..', '1'],
#  ['9643549', '이런 영화는 하나의 개연성만 없어도 허무하게 만들어 버린다. 조디포스터의 이쁜 모습만 남을 영화.', '0'],
#  ['6081437', '굳굳', '1'],
#  ['9907350',
#   '스토리도 말이 안되고 개막장 사랑이야기도 아니예요 이걸보고계신다면 당신의 시간과돈을 아낀거예요^.^휴 그래도 본다면 호구',
#   '0'],
#  ['4445737', '네놈을 살려두기엔 쌀이 아까워! 세기의 명대사', '1'],
#  ['6969112',
#   '평점이 너무 높다. 전혀 재미있지 않았다. 쓸데없이 말만 많음. 이런 류의 영화는 조연들의 뒷받침이 중요한데 조연들의 내용자체가 전혀 없음. 또한 여배우도 별로 매력 없었다. 이틀전에 저스트고위드잇의 애니스톤을 보고 이 영화를 봐서 그런가. 실망했음',
#   '0'],
#  ['5149470', '맛깔 나는 드라마.', '1'],
#  ['7696175', '시베리아인가 거기가서 훈련할때나오는 ost 개작살', '1'],
#  ['9197636',
#   '이건 시종일관 질~~질왜? 제목이 야경꾼 일지냐고 지금 10회가 넘어가는데 즉 2달이 넘어가는데. 앞에서 누군가가 얘기 하더만 이거 100부작이냐고 그러다 또 한 순간에 모든걸 훅진짜 지루함의 지존',
#   '0'],
#  ['7303814', '나이들수록 이해가 가는 영화', '1'],
#  ['6256531', 'ㅠㅠ 슬픔', '1'],
#  ['7860179',
#   '장면 개연성도 없고 아역은 연기도 못하고 무슨 추노에 나오는 민폐언년 외국판인줄....초반만 그럴싸한 저급영화',
#   '0'],
#  ['4813296', '이 영화 정말 별루예요. 결말이 이상해요....', '0'],
#  ['8153915', '딱히 재미는 없네요 킁;;', '0'],
#  ['9698597', '송강호는 정말 연기를 하기위해 태어났고 그로인해 우리는 즐거움을 느낀다 역시 송강호는 연기파다.', '1'],
#  ['9936129', '일본영화 수입 금지 시절에도 비디오 테이프로 돌려봤던 불후의 명작 아 그립다', '1'],
#  ['7758340',
#   '살인을 소재로 한 영화가 이토록 재밌을 줄이야. 살인에 대한 감독의 해석이 정말 재치있다. 대 배우님들의 10여년전 모습도 새롭웠고. ㅋ. 정말 유쾌하고 재밌다.',
#   '1'],
#  ['7983475', '누미 라파스 신봉선 닮아서 안 본다', '0'],
#  ['6986888', '케이블에서 그만 좀 재탕해라.', '0'],
#  ['220218', '멋졌다. 정말이지, 멋지다는 말 이외엔 할 말이 없다.', '1'],
#  ['8730958', '98년에 어떻게 이런영화가 만들어졌는지 의문.. 당대 최고의 영화 지금봐도 퀄에서 결코 떨어지지 않아요', '1'],
#  ['7717145', '지금 이거 티비로 돈내고 보고있는 내가한심하다', '0'],
#  ['7713083', '쓰레기 연예인 재기의 장~~그러나...', '0'],
#  ['5941602', '굿 좋아', '0'],
#  ['472846', '많은 감동을 준 드라마이다.', '1'],
#  ['9796817',
#   '발로만든영화. 지진나서 주인공 넘어지는데 뒤로 사람들 유유히 걸어다니고 있음. 발CG + 발연기 + 발시나리오.... 내용도 정말 뭐같음 ㅋㅋㅋ',
#   '0'],
#  ['7049293', '적당히 해야지 언제 끝나는것인가?', '0'],
#  ['214940', '잊을 수 없는 안개낀 워터루 다리와 마스코트.', '1'],
#  ['8520381',
#   '곤사토시 감독... 2010년 안타깝게 돌아가셔서 가슴이 먹먹합니다.. 정말 천재적인 감독인데 암으로 가시다니.. ㅠㅠ 이제와서 다시봐도 모든 작품이 대작...',
#   '1'],
#  ['9360766', '많은생각을 하게 됐습니다. 예뼈지고 싶은 맘은 있었지만 과하면 독이겠네요. ^^', '1'],
#  ['8830133', '아 츠무구만 없어지면 별 5개줄게', '0'],
#  ['10043297',
#   '어릴땐 조폭영화로 알다가 나이가들수록 이게 인생이구나 하고 뭉클해지는 영화.세상을 살아가면 갈수록 와닿는게 많아지네요...세상은 비정하지만 비정함마져도 따뜻해지는게 친구라고...',
#   '1'],
#  ['3398464', '영상이 너무나도 멋지다.', '1'],
#  ['1576800', '비디오가 있어서 봤는데 1997년도인줄모를정도로 잘만들었습니다 긴장감도있고', '1'],
#  ['4913424', '처ㅝ주', '1'],
#  ['9182989',
#   '2009년에 만들어진것치곤 재밌음 영화가 길어서 좀 다듬었으면 ..소재도 좋고 몰입감도 기대이상 매끄럽지 못한 부분도 있지만 연기는 둘 다 잘한듯',
#   '1'],
#  ['8189929',
#   '철지난 조폭 코미디와 뼈대 있는 가문의 이야기를 섞었지만, 둘 다 지루하다. 박정아를 비롯해 배우들은 보기 민망한 연기를 펼치고, 기억에 남는 건 하나도 없다.',
#   '0'],
#  ['8823884', '군더더기 없이 잘 진행되는데 재미도 없는게 문제', '0'],
#  ['10052602', '심심해서봤는데 재밌네요 탑연기 못할줄알았는데배우포스나고 잘하군요', '1'],
#  ['7728430', '고다미 괜찮음', '1'],
#  ['1374993', '아 지대짜증 아빠랑 봣는데 민망해 죽는줄', '0'],
#  ['6394494', '0점은 못주냐??', '0'],
#  ['3743025', '빠순이 영화 ㅋㅋㅋㅋㅋㅋㅋ 훈훈하긔 재밋쎠', '1'],
#  ['1699544', '최악의 애니메이션.. 지루하고 재미없고 스토리마저 진부하다', '0'],
#  ['6352418', '좋은 의도와는 다르게 불쾌한 표현법', '0'],
#  ['2211206', '줄리아로버츠 귀여운연인은 이거보다 5년전꺼다 ...', '0'],
#  ['10212408', '신선하네..,,..,,..', '0'],
#  ['9751638', '예술가로써의 한 사람의 인생과당시 시대적 상황을 질 느낄 수 있었던 명작', '1'],
#  ['10225984', '관객수가 너무 아쉬운 영화...베테랑보다도 더 류승완감독의 역작이고 더 강한악역이다', '1'],
#  ['5591006', '한창 핵펭귄이 남북 거짓평화로 전국민을 속이던때 만들어진 영화', '0'],
#  ['9793236', '지금 티비에서 하는데.. 못 보겠다..', '0'],
#  ['9502251', '여자애 한명이잘 못해서몇명이죽는거야ㅋㅋ답도없다ㅋ', '0'],
#  ['8504382', '성룡의 헐리웃작 중 단연 최고지 ㅋㅋㅋ', '1'],
#  ['2092294', '안습', '0'],
#  ['4930770', '감독의 의도를 전혀 알아차리지 못했다.', '0'],
#  ['5402666', '하나님이가정을온전히만든다. 진리이신분이만든영화. 눈으로만보지말고마음으로봐라.', '1'],
#  ['8198021', '2편도 나름 흥미진진한데 핀헤드가 죽은게 좀 아쉬운 점이랄까?', '1'],
#  ['9823215', '국산 코미디영화중에서 난 신라의달밤이 제일좋았음뭔가 푸근하고 따뜻함..', '1'],
#  ['9569992', '최악이다 영화보다가 잠오긴첨임 지루해둑을뻔', '0'],
#  ['7751180', '탄탄한 !~배우들 될고 ~머하는 건지~~~~~~~~~~~', '0'],
#  ['9467674', '영화가 점점 끝을 달려갈수록 몰입도가 더 높아진 영화는 이번이 처음이네요.', '1'],
#  ['9954533',
#   '결국 감독 자신이 하고 싶은 의견을 지존파 핑계삼아 하려고 한듯. 지존파 살인은 정당화하고 정부탓이 였다는.사회탓이라는.',
#   '0'],
#  ['8555924',
#   '사실여부를 떠나,알고왔던 아더와 너무 매칭이 안돼더라.원탁기사중 실제 검술 최고수는 랜슬롯으로 알고 있는데,트리스탄보다 못하고,싸우는 검술은 마치 중국검술 흉내낸거 같은게;; 그리고 란슬롯이 실제는 쌍검였나?너무 매칭이 안대 하튼 ㅋ기네비어역도 미스.',
#   '0'],
#  ['5277723', '대한민국 영화 수준의 평균치를 하락시키기에 충분한 C급 영상물', '0'],
#  ['7917426', '0점은 없나??', '0'],
#  ['5767948', '재밌는데', '1'],
#  ['6237814', '재미없다... 기대 완전 했는데.... 완전 못함!!! 실망....', '0'],
#  ['2334468', '종착역 없는 인생의 대유. 트레비스는 단지 흘러간다.', '1'],
#  ['9831680', '돈과 시간이 아까운 영화', '0'],
#  ['9751497',
#   '네러티브는 하나도 없는 예쁜 음악 동영상. 취미로 영화만드는 것은 이걸로 끝나길 . 잘하는 음악에 올인하길.',
#   '0'],
#  ['8117850', '배우들의 연기는 좋았는데.. 뭘 말 하려는 건지?', '0'],
#  ['6277438', '학위위조성범죄자 문제자들만 모아서 영화찍음 왜그랬으까 제작비 아끼려구 패자부활전 하냐?', '0'],
#  ['5878347', '솔직히', '0'],
#  ['9465707', '완전재미있어요.애들도보기에알맞는듯', '1'],
#  ['9405373', '잔인하기도 하고 무서웠어요ㅠ탑은 멋있더라구요~~', '0'],
#  ['4758250', '무섭지도 않고 기분만 나쁘고 쩝', '0'],
#  ['3644982', '군더더기 없는 깔끔한 그러나 강한 메세지 전달. 뜻밖의 참좋은 영화..!', '1'],
#  ['9724344', '이 영화는 최고다. 그냥 최고야 그런 줄 알아', '1'],
#  ['9040261', '그랜드 부다페스트 호텔과 시리즈 같네.. 캐스팅이 아까워~', '0'],
#  ['6824144', '빨리감기해서 봤음...투자비는 많이 들었을 것 같은데...영화사 망했네~ㅎ', '0'],
#  ['10184469',
#   '도대체 뭐가 재밌다는건지 모르겠네요 무슨 아이언맨 시리즈의 개그도 뛰어넘는다 하는데 어디서 웃어야할지도 모르겠고 내용도 뭔지 뜬금없는 히어로놀이는 또 뭔지.. 왜이렇게 평점이 높은지 모르겠습니다',
#   '0'],
#  ['9589406',
#   '왜 극을 끌어가는 중심있는 캐릭터가 있어야 하는지 알게 된영화 살인마와 대적하는 그리고 사건을 해결하는 인물이 없고 그리고 왜 마지막에 다 탈출 해놓고 나서 잡히고 죽임을 당하는지 이해할수가 없다. 대체 조달환 정유미는 왜 나옴?',
#   '0'],
#  ['4879638', '진 짜 리얼 개 쓰레기 영화 . 다 보고 나면 정말 찝찝해지는 영화 절대보지마', '0'],
#  ['9915234',
#   '비록 로봇이지만 점차 인간의 감정을 가지고 자신에 대해 고민하면서 결국 인간이 되어 죽는 앤드류의 모습내가 봤던 영화 중에서도 최고의 감동을 선사한 영화',
#   '1'],
#  ['3274253', '영구와땡칠이시리즈는 레전드영화다', '1'],
#  ['8652917',
#   '초딩 때 친척형이 비디오로 빌려와서 봤던 기억이 난다...너무 재미 없었다 근데 나중에 우연히 다시보니 재밌더라 그 땐 왜 그렇게 재미가 없었을까?? 98년이면 내가 초등학교 2학년 때니까...사촌형이 당시 나름 최신 비디오를 빌려온거 같다',
#   '1'],
#  ['1043813', '지루할만큼 고요하고 서글픈 시선속에 머문 깊은 성찰과 사색.', '1'],
#  ['10221467', '영화 진짜 보고 .. 펑펑울었습니다 , 너무슬픈거같아요 .. ㅜㅜㅜ !', '1'],
#  ['1656447', '누가 더 혀짧은가 내기하면 박빙일것같다', '0'],
#  ['1911721', '애 둘 딸린 심은하의 그 눈부신 미모, 아름다운 영상, 메인 주제가', '1'],
#  ['10080984',
#   '3기 나오겠죠 ? 아직 안풀린 이야기들이 많은데 극장판은 정말 시간가는줄도 모르고 봤네요 역시 싸패..',
#   '1'],
#  ['9999070', '개노잼;; 뭔가 스토리도 부족하고 다이상함 진짜;', '0'],
#  ['8063353', '답없네, 뭐하는건지..', '0'],
#  ['7685723', '절망과 슬픔 속에서도 자신을 챙겨야만하는 삶의 잔인함을 거부한 비참함에 대하여', '1'],
#  ['6641262', '페이스 허거 같음ㅋㅋㅋㅋㅋ', '0'],
#  ['9219254', '시간이 흘러도 퇴색되지 않는 맛이 있는 영화', '1'],
#  ['9673595', '진짜 어마어마한 여운을 주는 멜로 영화에요.ㅎ', '1'],
#  ['9855049',
#   '소피마르소와의 말같지도 않은 불륜이 내용 다 망침. 물론 실제 역사에는 그런 똥같은 이야기는 전혀 없었음.(주인공 죽을때 공주는 10살이었음)한마디.만약 미국인과 맞서 싸우는 아메리칸 원주민의 자유 투쟁기였으면 절대 아카데미상 못 받았음.',
#   '0'],
#  ['3877797', '훈훈하고 따뜻한 부정을 느낄수잇엇음', '1'],
#  ['7679615', '잼', '1'],
#  ['8888834', '전 정말 재미있게 봤습니다', '1'],
#  ['9298858',
#   '어딘가에서 일어나고 일일것같은 느낌이 강하다.우베볼이 이런 영화를 만드는 이유는 누군가 실제로 따라 했으면 하고 바라는것 같은데 정장 월가 있는 애들이 보면 웃겠지...',
#   '1'],
#  ['10232830', '림프비즈킷의 OST만 10점. 개봉 당시 극장에서 봤는데 영화내내 오우삼 쥑이고 싶었던ㅋㅋ', '0'],
#  ['8057595', '견자단 대박!!엽문 시리즈는 계속된다.', '1'],
#  ['6989907',
#   '정말 오월의 멜로는 정말로 보고보고 또봐도 계속 보고싶은 영화순위 1순위다하,,,늦은 밤이라 그런지 야릇한 느낌이 들었다',
#   '1'],
#  ['3829341', '흥미롭게 봤어요. 여배우들 이쁘네요. 반했음', '1'],
#  ['8313164', '스토리, 액션, 그래픽 머 하나 건질게 없는 망작. 그냥 게임으로나 즐기셔~', '0'],
#  ['9964594', '그냥 레전드다 레전드!!!', '1'],
#  ['10107265',
#   '평론가 명치를 겁나 때리고 싶다. 정말 이 영화 재미없을거라 생각했는데 재미도 있고 내 인생에 도움이 가장큰 영화입니다. 본인이 깨달고 싶으면 꼭 보세요. 인생을 바꿔줄겁니다.',
#   '1'],
#  ['9753915', '키아누 리브스 최고의 액션 영화!!', '1'],
#  ['7778515',
#   '소재가 아름다운 영화. 다소 아쉬운 부분들이 있는 이유는 이 영화는 영화스러운 극적 로맨스보단, 좀 더 사실적으로 한 남자의 마음과 시선을 말하고 싶었기 때문 아닐까.',
#   '1'],
#  ['3562504', '영화평론가는 아니지만, 좋았다, 한번보고마는 영화가 아닌, 울림이있는영화', '1'],
#  ['5523522', '역시 효느!!! 역시 재밌다ㅋㅋㅋ 재탕중...', '1'],
#  ['7448331', '4대강', '1'],
#  ['8939261', '간첩색휘들 애쓴다 밥은 먹고 다니냐?', '0'],
#  ['7857671', '좀 검증된 애들좀 출현시켜라이탈리아 특집 장난하냐', '0'],
#  ['142324', '아 정말짜증나네 절때보지말껄욕나옴', '0'],
#  ['5427136', '슬프다 ㅠㅠ', '1'],
#  ['2331482', '.최악의 환경속에서 이런 만화라도 만든사람들에게 경의를 보낸다.', '1'],
#  ['4221289', 'What is this movie for?', '0'],
#  ['8648758', '여운이 엄청~길게 남는영화.. 이이경을 사랑하게하는 영화!', '1'],
#  ['4779812', '이딴게 한국 영화라니', '0'],
#  ['8497657', '짜가인가 이게뭐여..뭔..', '0'],
#  ['9456842', '굿 10자 이상 .가나다라', '1'],
#  ['8665016',
#   '짱이다ㅎ 혼자자식키우며살아온엄마 그의아들 힘들게살아오면서 서로예민해지고날카로워질때도잇엇지만 결국 ..가족ㅎ 아빠라는 사람도 생각보다최악이아니고..여자는, 확실히 요구하면도와준다는 그말이 왠지짠하게와닿는다ㅎ 나혼자괜히끙끙거리지말자ㅡ이런단순한생각이든다',
#   '1'],
#  ['8896748', 'CG도 별로고 전개도 별로고 연기도 별로고 한마디로 재미없다', '0'],
#  ['3107684', '번지수 잃고 갈팡질팡', '0'],
#  ['9509970', 'Yesterday when i was young', '1'],
#  ['5549220', '너무 사랑스럽고 감동적인 영화:) 정말 좋앗어요', '1'],
#  ['7538996', '최고의영화', '1'],
#  ['9113253',
#   '13년전 영활 다시보니 공효진 코평수줄이고 콧대높였네...완전 못생겼어 ㅎㅎ호 권상우는 화산고때 왼쪽 팔자 심하더니 지금 사라지고 더 잘생겨졌고 장혁은 멋지게 늙었네. ㅋㅋㅋ다시보니 웃겨',
#   '1'],
#  ['5025054', '말랑말랑 ...', '0'],
#  ['7648726', '공부 열심히 합시다 공부 안하면 저런 OO인생 삽니다.', '1'],
#  ['7084152', '그냥. 최고다.', '1'],
#  ['8937659',
#   '전쟁이후의 아픔을 잘 그린영화마지막 장면이 압권유대인줄 알아 더럽게 여기나 도움이 필요하니동행했던 토마스에게 더러운유태인이라고 말한장면 그러나 유대인인척한 사실 유대인가족사진을 보면서 미묘한 감정들을 사슴인형을 밟아까며 대변한다므찐영화^^',
#   '1'],
#  ['10147064', '오랜만에 동화다운 동화를 본 기분이다.', '1'],
#  ['10001967', '감사합니다 정말로 감사합니다.', '1'],
#  ['4655750', '걍 둘다 변태', '0'],
#  ['6167275', '샤넬의 인생과 성공,이 아니라 샤넬과 그의 남자들', '0'],
#  ['4877829', '영화가 내용이 없다', '0'],
#  ['9601176', '십수년의 세월을 찰나의 순간처럼, 찰나의 순간을 영원한 기억으로 남기는 시간의 상대성 이론에 관하여.', '1'],
#  ['8216491', '니노의 이중인격연기 두근거리네요♥', '1'],
#  ['10242465', '보다가 울컥핫 영화...재미도 있고...먼가 감동적임', '1'],
#  ['3231034', '열정만으로 돌진하고 싶게 만드는 영화.', '1'],
#  ['9248386', '연기력에서 유혹하지 못한다', '0'],
#  ['5483898', '난감하다. 재미도 없고, 세상을 깜짝 놀라게 하는 센세이션도 없다.', '0'],
#  ['6302401', "아무리 노력했어도 '차이나타운'을 대놓고 베낀 것은 용서가 안 됨.", '0'],
#  ['9200443', '신화 화이팅 에릭 화이팅>< 모두 힘내요 !', '1'],
#  ['7654525', '엔딩이 넘 슬퍼요 :(', '1'],
#  ['3960206', '영화관에 가서 보면 더 좋았을걸...어린시절로 돌아간 느낌이들어 만감이...', '1'],
#  ['7561877', '정말 최고였어요 ㅠㅠ 이민정씨와 신하균씨 연기 너무 좋았어요!!', '1'],
#  ['8781402', '몇 안되는 재밌게 본 영화', '1'],
#  ['8825291',
#   '교양시간에 보고 좀 충격먹은 영화....마지막에 너무 슬펐다 빨갱이라 소리지르던 몬초가 갑자기 다른 단어를 말한건 선생님에대한 그리움 미안함 슬픔이었을까...몬초가 마지막에 좀 울먹인거 같기도 하고...',
#   '1'],
#  ['1033103', '잘봤습니다', '1'],
#  ['3379092', '안무서워!! 귀신이 애기라 그런건지,,, 그냥 깜놀하기만할뿐이야', '0'],
#  ['5785985', '뭐하자는건쥐... 모든것이 다 어설프고...', '0'],
#  ['5842441', '배우들의 따뜻한 연기도 일상의 힘겨움을 그리는 현실감도 다 좋았어요.', '1'],
#  ['3249844', '남자배우들 정말 미스캐스팅. 연기력 안습... 조은숙, 김유미 연기땜에 참고 봤다', '0'],
#  ['9853892',
#   '1차 세계대전 中 피고 진 청춘들. 무기와 기술력은 20t세기, 전쟁을 일으킨 정치인들과 전쟁을 지휘하는 고위 장교들의 생각은 19세기.',
#   '1'],
#  ['5414569', '책과는 분명히 다른시선. 괜찮네요', '1'],
#  ['5059623', '내가 이거 왜 봤지 싶은데 한예슬이랑 김태희 나와서 본 듯. 적월도 개 쌤 ㅋㅋ', '1'],
#  ['9762198', '솔직히 6점때가 뭐냐 약간 더러운 장면만빼면 7.5정도다', '1'],
#  ['9808764', '와 이연서님 신인답지 않은 연기력 잘 봤습니다 다음 작품에서 또 뵙길 바랍니다', '1'],
#  ['10018872', '반전이 전부가 아닌영화..몇 번을 봐도 또 보고 싶은 영화', '1'],
#  ['7871532', '피해자만 있고,피의자는 없는 ..', '1'],
#  ['9488543', '개답답 먼주인공이 지혼자 복수도 못함?주변에서 해주길바라는 민폐녀?아직도 끌려다니고ㅡㅡ', '0'],
#  ['7360385', '신선한 소재. 화끈한 액션. 스피디한 전개', '1'],
#  ['10131631',
#   '이 영화의 3박자는 디테일이었다. (정말 시가전의 퀄리티는 완벽했고) 남자의 사랑에 대한 묘사... (작중에 한석규는 누군가를 사랑하는 마음은 정말 디테일이 대단했다.) 마지막 얘기의 완급조절이 완벽했다. 이 영화가 정말 멋졌다.',
#   '1'],
#  ['9342020', '탕웨이찡 그녀 만으로도 10점주기에 충분하다!!', '1'],
#  ['5351337', '감동적인 영화다', '1'],
#  ['5686145', '당시 대박쳤던 영화..괜찮다!!', '1'],
#  ['8392466',
#   '억지스러운 시나리오..지루한 전개.. 1편 보다 못한 구성등.. 2편은 안나오는게 나았다..망작..배우들이 영화보는 눈이 없어서 안타깝다.',
#   '0'],
#  ['3398398', 'ㅋㅋㅋㅋㅋㅋㅋㅋ 반도 안되는 영화', '0'],
#  ['2504572', '이 영화가 평점이 높은 이유를 모르겠어..ㅡ.ㅡ::', '0'],
#  ['1747519', '평생 기억할만한 영화,정상적인 소재는 아니지만', '1'],
#  ['9972054', '요즘 상황 보고 이 영화가 생각났다.', '1'],
#  ['10226361', '많을 것을 생각하게 만드는 영화입니다.마지막에 사람들이 짐승으로 보이고 아수라가 사람같아 보였습니다.', '1'],
#  ['6150881', '진짜 재미 없는 영화 공통점....스포츠영화,군대영화,자막 나오는 영화', '0'],
#  ['3800651', '로버트 드니로의 광기의 복수 연기를 만끽할수 있는 수작 서스펜스 스릴러물', '1'],
#  ['8705316', '감동감동감동의 도가니탕', '1'],
#  ['8164006',
#   '세계 어디서나 정치 경제 문화 사회 전반에 걸쳐 변화가 절실한 상황이지만 변화를 가져올 방법이 없다는게 함정인 것 같다...',
#   '1'],
#  ['501464', '귀여운벤지.. 똑똑한 벤지 예쁘고 귀여운 친구... 압삘럽 ㅎ', '1'],
#  ['2163194', '당시 개봉날 보고 울면서 나왔다. 돈아까워서..ㅋㅋ', '0'],
#  ['10242398', '정말 최고의 영화...', '1'],
#  ['9733856',
#   '잔잔하게 숨막히는 영화 . 연출이 대단하다. 곳곳에 숨어있는 복선. 치밀하다 싶을정도로 섬세한 감정표현. 거기에 김영애의 연기까지',
#   '1'],
#  ['10147571', 'once upon a dream', '1'],
#  ['9990660', '시나리오 연출 연기 어느것 하나 갖추지 못한 시간이 넘 아까운 억지 싸구려 중국 신파 경극...', '0'],
#  ['10055131', '거부하는 몸짓으로 저 하늘을 ~ ^^', '1'],
#  ['7086350',
#   '그만빙빙돌리고 밝혀지게하면안되나요 ?보려다아직도질질끌어짜증나.안봄 여기서또사고터져 또질질끌면진짜짜증날듯 ?빨리빨리밝혀질건밝혀지면서반전이있든지 ?작가님 이드라마사랑하고잼있는데 넘끌어짜증나요',
#   '0'],
#  ['9849333', '졸면서 봤다 왜이리 평정이 높은겨 내용도 별거 없고 아오 감수성 영화냐 이거', '0'],
#  ['2626505', '기대하지 않았던 영화의 아름다움이 밀려온다. 꽤 괜찮다았던 영화.', '1'],
#  ['6237908', '진짜 한번만더 이런영화 상영하면 용서하지 않는다지금 영화보면서 카톡하고잇음 아놔 진짜', '0'],
#  ['9484080', '살아는 있지만 생동감을 잃은 박물관', '0'],
#  ['9578706', '노땅들의 한심한 추억미화', '0'],
#  ['4996289', '어릴적에 눈물흘리며 웃던기억에 간신히 찾아 다시 봤네요 ^^', '1'],
#  ['1109987', '인종차별과 유괴라는 두주제의 불협화음', '0'],
#  ['7551529', '고명환이 연기가 쩌냐? 아니면 돈이 없어 쓴거냐..후자라면 볼가치가 없는영화', '0'],
#  ['5080819', '속편에서는주인공이전작처럼앨빈의밴드였으면좋았을것같다.캐릭터추가로더이상해진듯', '0'],
#  ['156982', '혼자 보긴 너무 아깝다. 2004년 올해의 영화.', '1'],
#  ['8082654', '마지막 결투씬 최고! ㅋㅋ 폭풍눈물에~ 팝핀현준 할아버지 ㅋㅋㅋ', '1'],
#  ['9659875', 'ㄵ 5점대asfgsdlgkbjsjvb', '0'],
#  ['9215986', '좋아 상술최고..아니 선거술 최고...', '1'],
#  ['9076407', '쓰레기 함부로 버리지 맙시다.', '1'],
#  ['9265375', '글쎄 나와는 안 맞는 성향의 영화 중 하나. OST는 들을 만함', '0'],
#  ['3978509', '즐~~~~~', '0'],
#  ['9293103',
#   '막장도 재미가있어야 보지..재미도 없고 짜증만 남남녀주인공이 어울리면 참고보겠는데 진짜 안어울리고웬만하면 다 재밌게 보는데 진짜 내가본것중 제일 최악이였음!!무튼 주인공들부터시작해서 성격 개 이상함!!조기종영이 답이다...',
#   '0'],
#  ['7931340', '줄리델피는 나이가 들수록 멋지다!', '1'],
#  ['3382430', '내가 본 일드 중 쵝오~!!!!!>0<', '1'],
#  ['9880437', '역시 명작은 명작이다...', '1'],
#  ['10153465', '글쎄요.... 뭐랄까... 영화 제목을 잘못 보고 착각한 내 잘못이랄까...', '0'],
#  ['10049872', '그냥 기독교영화네요. 좀 더 깊이있는 내용을 기대했는데.. 실망입니다. 영화도 뭔가 엉성해요;;', '0'],
#  ['9427493',
#   '그냥 책으로 읽는게 더 절절하게 다가온다. 영화는 내용을 너무 비약하고 삭제해서 행간을 잃어버렸다. 책에서 꽉 찼었던 느낌과 반대로 모든 것이 엉성하다.',
#   '0'],
#  ['6629097', '너무나 감동적인 영화', '1'],
#  ['9995177', '스킨헤드성님들이 이 영화를 싫어합니다.', '0'],
#  ['9600841', '자동차 매니아인 나의 평점은 5점 이하~속았다...아오~', '0'],
#  ['9244416', '나 이거 보고 인형 절대안삼', '1'],
#  ['6159178', '정체성은 사치인가?', '0'],
#  ['10059230', '나이먹은아저씨들이 일찐놀이하는영화 개역겹다. 알바풀었냐 현실감 개진짜 개제로', '0'],
#  ['9988541', '남극은 왔는데 그만 길을 잃었다. 오르지 못할 곳은 오르는 것이 아니다.', '0'],
#  ['7790870', '재밌음 귀엽고 신남', '1'],
#  ['8130040', '포스터는 진심 개쩐다~ 엑소시스트를 능가하는 공포물 같지만 실상은 처키보다 못한영화', '0'],
#  ['5398829', '시청률 44%는 개뿔;; 존11나 재미없어;; 이제보니 MBC가 사극너무못만드네;;', '0'],
#  ['7141862', '요즘 재방보는데 넘 재밌는데...왜 시청률은 저조했을까 싶네요...둘다 귀요미', '1'],
#  ['8605792',
#   '연출 연기 영상이 아름다운 영화입니다. 저예산영화인 관계로 스펙타클은 부족하지만 한국영화계에 새로운 바람, 희망, 다크호스가 될것임을 믿습니다. 많은 응원부탁드리고 벌써부터 일찍 관람해주신분들 진심으로 감사합니다. New hope',
#   '1'],
#  ['8852339',
#   '평점이왜이렇게낮지?난 이거 또다운받고있다.3번째...정말잼있던데...끝에 견자단하고 대빵하고싸울땐 정말 가슴이뜨거워졌다.난정말로 잼있게봤다...최근댓글이니 내가 알바아닌줄은 알거다.',
#   '1'],
#  ['5924043', '이게 어떻게 평점이 낮을수가 있지?', '1'],
#  ['10095254', '블랙코미디 조롱 대상이 우린데 기분 드러워서 점수 주겠냐? 성기 노출 등으로 어그로나 끌고서는 ㅉㅉ', '0'],
#  ['7545407', '촌동네 조폭삼류영화. 가끔씩 툭툭들이미는 유머도 영쌩뚱맞구 촌스럽기까지하다.', '0'],
#  ['1028779', '10점 만들기', '1'],
#  ['5947102', '스타뎀 형님의 얼굴에 먹칠을 한영화..', '0'],
#  ['29672', '헐...남자몸매보면 기분 좋나?', '0'],
#  ['8673629', '안봐도 별점 한개 주고싶은 10류 영화 같다... ㅋㅋ심형래 아저씨와 동급감독인듯 ㅋㅋㅋ', '0'],
#  ['9922565', '정말 완벽했다.최고의 영화중에 꼽히는 영화.', '1'],
#  ['9869002', '조잡하고 유치한 저예산 3류 B급 영화다.. 스토리에 깊이감도 없고 전체적으로 루즈하다.', '0'],
#  ['8622080',
#   '진짜..뭐냐 민국이나 지아는 더빙 더이상시키면안되겠네 더빙이 얼마나중요한데 이런애들을시켜데뷔도안한애들을 연예인이해도 뭐라고하는판에',
#   '0'],
#  ['8954713', '그냥 재미가 없어요....ㅠㅠ', '0'],
#  ['1998203', '쇼를해라 쇼', '0'],
#  ['4355661', '중심이 약하니 언저리 가지고 무리한 승부수를 띄운다', '0'],
#  ['247380', '주연배우들의 이름만 기억에 남.', '0'],
#  ['9149689', '그냥 안보는게 이득 ...', '0'],
#  ['8931143', '키기키기키기키기키기', '0'],
#  ['5364316', '박얘쁜 빠수니 죄다 OO 없어져버려', '0'],
#  ['9915858', '진짜 짜증나는 영화..', '0'],
#  ['9985367',
#   '불은 잘 보이지도 않고 사람 죽어나갈 때는 엄청난 웅장한 음악만 나오고 전혀 마음에 와 닿지 않는 설정들',
#   '0'],
#  ['6438587', '망작', '0'],
#  ['9678213', '상당히 재밌게 봤습니다', '1'],
#  ['4602811', '내코끼리내놔가 더재밌음ㅋ', '1'],
#  ['586485', '코믹은 코믹으로 봐라 패러디하고 카메오들보는 재미도 있다', '1'],
#  ['10101756', '유치짬뽕이네!!. 딱 초등3학년 영화다. 초등학교 자녀 있는 가족분께 추천함!!', '0'],
#  ['9425646', '후속 지금이라도 나와라 한국애니 좀 살려보자', '1'],
#  ['4376802', 'EBS를 통해 봤는데.. 정말 재밌게 잘 봤어요. 요 근래 본 영화 중 최고인듯!', '1'],
#  ['7806661', '기대않고 봤는데, 찰지게 만든 토종느와르네~! 흥미진진하다..', '1'],
#  ['6238614', '성인영화를 가족영화로 만드려하는 멍청한 자막제작자가 마음에 안들어서 1점', '0'],
#  ['720113', '일본인 특유의 어색한 연기 여주인공 연기 너무 못해', '0'],
#  ['7674213',
#   '전반적으로 무거운 느낌의 영화네요.가비의향과맛처럼,씁쓸함이 느껴집니다.장윤현감독님께서,커피부분에관해 신경을 쓰시다보니,연출부분에있어서,좀 미흡하지않았나싶고, 배우들연기력은 괜찮았습니다.',
#   '1'],
#  ['9719704', '전작보다 100 재밌다. 배우, 내용 모두 세련됨', '1'],
#  ['8679307', '진지하고 무거운 소재를 경쾌하고 재미있게 만들었다', '1'],
#  ['6148658', '유럽작품상 탈만한 유럽에 중요한 얘기..또한 픽션', '1'],
#  ['4550608', '풍정정은 어케된거지ㅋㅋㅋ과도한 압축으로 개연성없지만...배우들이 호화로워서...', '1'],
#  ['9353256',
#   '이영화 구성좋다는분들 ㅋㅋ아마 친구랑 같이영화보고 님들이 영화 좋다고 재밌다하면 같이본 친구들은 이해하지 못할겁니다 ㅋㅋ진짜 최악 최저 스토리 주인공 행동 개연성없음캐릭간의 이해관계 최악 ㅋㅋㅋCIA갘ㅋㅋ이렇게 허접하게 표현된 영화 간만이라능ㅋ',
#   '0'],
#  ['6082274', '이젠 그만 보고 싶은, 막돼먹은 스토리텔링.', '0'],
#  ['8935552', '말이 필요 없다.로맨스 싫어하는 내가 봤을때 기절할 것 같았어 ㅜㅜㅜㅜ', '1'],
#  ['10257700', '제 취향적 이고 우울한 마음을 완전히 날려버리고 슬픈내용을 본뒤 마음을 정화시켜주네요.', '1'],
#  ['9437693', '영상미가 역시 최고네요', '1'],
#  ['6825866', '끙.....', '0'],
#  ['9326219', '역시 한국영화는 보지말아야돼', '0'],
#  ['455825', '괜찮은 영화...', '1'],
#  ['208558', '요즘 재밌음!', '1'],
#  ['10038451',
#   '소재는 참 좋아서 삼점준다. 제작된 영화는 공포도, 스릴러도 아닌 본분을 잊은 드라마아닌 드라마같은 느낌이다. 연기, 연출은 괜찮았다. 다만 시작부터 끝까지 지루할 뿐이다. 또 어떤 장면들은 살짝 유치했다.',
#   '0'],
#  ['8411258', '남자인데 보는내내 울었다 딸 낳으면 잘해줘야지...', '1'],
#  ['9566485', '안타까울뿐. 안타까울뿐.', '0'],
#  ['6027897', '영웅은 사람들이 원하기 때문에 만들어지는 또다른 희생자다..', '1'],
#  ['6361907', '그냥 평작. 욕까진안나오고..', '0'],
#  ['10149061',
#   '극장가서 안본 내머리를 깨버리고싶네요. 제인생 최고의 영홥니다. 키이라작품 중에서도 최고일듯. 알럽키이라♡♡',
#   '1'],
#  ['1135339', '중고생들의 마마추어 포르노', '0'],
#  ['9134639', '비디오 물이냐 동시상영물이냐 ~ 넌 정체가 모냐', '0'],
#  ['8759753', '이건 말로 설명할 수 없는 유치함이다. 진짜 필름이 아깝다', '0'],
#  ['5658983', '이승연의 강렬함이 묻어나는 영화. 그러나 홍경인은 너무 불쌍하게 나옴', '1'],
#  ['2955927', "'드릴브라' 에서 뿜었다", '0'],
#  ['8821260',
#   '2% 부족한 영화가아닌 98%부족한 영화감동이 있다길래 참고 끝까지 다봤는데...;;진심으로 이렇게 재미없다고 느끼는건 처음;;',
#   '0'],
#  ['8384832', '계몽영화의 한계를 고스란이 답습한다', '0'],
#  ['3711748', '우와 정말 오랜만에 통쾌하게 웃었네요 ㅎㅎ 내일이 기대됩니다', '1'],
#  ['8759142', '청춘에는 마침표가 없다.', '1'],
#  ['7459571', '세얼간이 아줌마 나와서 한번 본건데 실망...신선한 반전을 주고싶었나 본데 개연성도 없구 뭐이런...', '0'],
#  ['9618670', '좋은 소재에 만족할 연출.', '1'],
#  ['522869', '심혜진이 나와서 겨우 저정도라니 실망이다', '0'],
#  ['9505968',
#   '아들놈은 끝까지 아빠한테 미안한 감정 없어..ㅠ 소재가 신선했는데 영화 자체는 메시지도 모호하고 스토리가 짜임새 있지 않은 것 같다.',
#   '0'],
#  ['8567896',
#   '창업을 꿈꾸는가! 좋은 아이템이 있어 사업을 하려하는가!! 그렇다면 기를 쓰고 이 영활 보기바란다!! 그 멀고 험한 여정에 스승이 될것이요 지침서가 될것이다... 혹은 단념에 도움이 될지도... 참 오랜만에 박장대소하며 본 독립영활세~~~ ★',
#   '1'],
#  ['2828148', '슬픈액션영화치고는실망이크다부자간의배신과원망으로끝나는것이너무허무하다', '0'],
#  ['9087701', 'EBS 명화에서 이거보고 움 진짜감동적', '1'],
#  ['8775560',
#   '낰였다 티 프리미엄ㅡㅡ 인간적인 면이 쫌 맘에 들어서 2점줬다 근데 진짜 이선균 정재영 김상중 연기파배우들 불러노코 이딴 쓰레기 영화 찍냐ㅡㅡ 진짜 영화보는데 계쇠 지루하고 괴로웠다ㅡㅡ',
#   '0'],
#  ['2956430', '너무나 따뜻하고 감동적인 영화', '1'],
#  ['6984995', 'C급영화도 안되는...일점도 아깝다... 네이버는 마이너스 점수도 만들어 달라', '0'],
#  ['5875641', '스토리의 부진은 액션의 재미까지 반감시킨다', '0'],
#  ['9674250', '누구나 ㅡ낄수ㅣㅆ느덕을 영화화함...굿,,', '1'],
#  ['9698428', '시종일관 오락가락 말하고자하는게 뭔지 모르겠다 감독자기만의 세계에 빠져 만든것같은 영화..', '0'],
#  ['1956819', '왠지모를 색다른 감동을 주는영화이다....', '1'],
#  ['9352399',
#   '전주영화제에서봤었는데넘늦게개봉한듯... 종교와업에대해한번더생각할수있게만든영화. 저예산으로만들었으나감독의노력이느껴져큰박수를보내고싶다. 화이팅!',
#   '1'],
#  ['10270814', '보는내내 웃었습니다 재밌네요', '1'],
#  ['7117896', '1', '0'],
#  ['5787812', '사랑에 상처받으면 다시 치유될수 있을까? 하는 생각이 드는 영화!', '1'],
#  ['1353144', '극장가서 본영화중 쓰디쓴아픔을 처음으로 느끼게해준 퍼스트', '0'],
#  ['8422811', '최고! 더 무슨평가가 필요한가 ~~탑!', '1'],
#  ['1268778', '자신의삶에대해 다시한번 생각하게하는영화...', '1'],
#  ['9062386', '알바놈들 양심도 없냐...멀보고 십점주는거냐', '0'],
#  ['9589263', '90년도로 돌아가게 해준다는 ㅡㅡ', '0'],
#  ['9589188', '끼워 맞추기 개쩔던데, 반전 하나 보고 와 하는 인간들 이해 불가', '0'],
#  ['8029041', '우웩. 개랑 무슨짓을 했길래. 후세가 태어나. 일본놈들 진짜 정신상태 이상하네.', '0'],
#  ['6478189', '4', '0'],
#  ['8181452', '이 영활 보고나면 흐뭇해진다.. 영화는 한국이 더 잘만든다는 걸 느끼게 되니까..', '0'],
#  ['1633598', '지들이 뭔데 대우를 까냐?', '0'],
#  ['10095078', '재밌고 짠하고 그게 매력입니다', '1'],
#  ['7622143', '와 ㅠㅠ 내머릿속지우개 이후에 진짜 슬픈영화였어요 ㅠㅠ 마지막에 눈물폭발 ㅜㅜ 오늘이후에도 또보고싶네요', '1'],
#  ['9102887', '월요커플 짱짱!! 덕분에 아주 재미있게 보고 있습니당!!', '1'],
#  ['8206148',
#   '007 터키특집..액션은 스키추격이 기억에 남고. 소피의,소피에 의한,소피를 위한 시리즈..로저무어 시절보다 재미는 조금 떨어진다',
#   '1'],
#  ['1509830', '수많은 최루성 멜로는 여기에서...', '1'],
#  ['499334', '내평생 최고의 걸작. 현실 건너편 세계를 잠시 엿본듯한 느낌.', '1'],
#  ['6662535', '내 인생 최고의 영화', '1'],
#  ['4881827', '진짜 추천해요 ^^', '1'],
#  ['9825558',
#   '포스터가 사기. 너무 현실적이어서 배우들은 심각한데 빵빵 터지는 화성남 금성녀. 아 슈발 지는 혼자 내리면서 본전생각에 담배 피는 남편.',
#   '1'],
#  ['5043859', '머가마술이라는거야?나죽기전에외계인만나볼수나있을지?', '0'],
#  ['5409088', '참 재밌는 영화 ㅎㅎ', '1'],
#  ['8962807', '빨리좀 끝나라...으이그 처음엔재밌는줄알았는데이게뭐야!이리재미없다.', '0'],
#  ['5943761', '극에 전혀 몰입안되는 장면 이어붙이기식 단순 진행,연출력이 형편없음.', '0'],
#  ['5536004', '자막제작자가 써놨듯이 막장임.', '0'],
#  ['6932147', '그리 무서운 수도승이 물에 쉽게 떠내려가네', '0'],
#  ['6484469',
#   '이게왜 주온보다 평점이높은지 이해가안간다 이영화 맨처음 여배우가 물대포쏠때부터 웃겻다 포스터가 더무섭다 영화상영시간내내 포스터만보여줘도 충분히지린다',
#   '0'],
#  ['10004793', '진짜 신기하다...라는 말밖에 안나와', '1'],
#  ['9391681', '좋은 배우들을 데리고....;; 작품의 부족함.', '0'],
#  ['8130315',
#   '아니 왜 5점대라니, 근래에 본 다크 히어로무비 중에서 최고였어요. 아주 그냥 고스트라이더에게 걸리면 스치면 사망인거에요.',
#   '1'],
#  ['7392240', '묵직하게 시작해서 우습게 끝남', '0'],
#  ['8772531', '내용 전개가엉성하고지루할정도로 재미가없슴', '0'],
#  ['1367092', '돈뭉치로 싸대기;; 명장면이다ㅋㅋ', '0'],
#  ['8495001', '2.2고고하자 ㅋㅋㅋ', '0'],
#  ['1185788', '쓰레기영화', '0'],
#  ['8824834',
#   '너무일찍슬픔을알게된제제가안쓰럽다..책으로읽고도눈물이났는데..영화도마찬가지다.어린나이의제제는슬픔을너무일찍알아버렸다',
#   '1'],
#  ['14513', '정말 비디오마저 돈주고 보고 아깝다..최악...', '0'],
#  ['4357478', '말그대로 뚝방에서 볼영화', '0'],
#  ['6021189', '내 인생 최고의 영화. 10년이 다되가는데, 아직도 아련하고 애틋한 기억.', '1'],
#  ['7287648', '감독ㅡㅡ다신영화찍지마라', '0'],
#  ['10253977', '육감적인 섹시한 여인들의 존재 자체가 이 영화의 전부', '0'],
#  ['9992205', '영화 첫 도입부 부터 카메라 각도라든지 화질이라든지 겁나 구림.. 영화 아닌줄 알았음', '0'],
#  ['8026930',
#   '진정 좋은 영화란 볼때당시 잼있다... 도 있지만.. 두고두고 기억나고생각나고 또 한번쯤 보고싶은 이런영화가 아닐런지요 ㅋㅋ',
#   '1'],
#  ['8043001', '박사아들 정시현 정말 멋져요', '1'],
#  ['2168829', '1편이 너무좋아서 2편이 너무묻힌다', '0'],
#  ['6377552', '할 말이 없다', '0'],
#  ['129805', '난 별로던데 -_ -', '0'],
#  ['5661543', '이런 영화가 참 좋다.', '1'],
#  ['542441', '곳곳에 번뜩이는 아이디어. 아기자기한 구성이 돋보이는 수작.', '1'],
#  ['4592004', '우아....새벽에보니까 무섭네 ㅠ_ㅠ 미스터리와에로스와 스릴러를 겸비한 영화!', '1'],
#  ['7963429', '짧지만 정말 재밌게 잘봤어요~. 윤계상 능청연기 좋구 잘됬으면 하는 생각을 계속 했네요~ ㅋㅋ', '1'],
#  ['7175213', '에린이 초반에 타던차 현대자동차 프레스토 네요. 보면서 추억이세록세록', '1'],
#  ['9905070', '남들이 철학적인 영화라고도 하지만 단순 액션용으로 봐도 이 정도 점수는 나와야된다', '1'],
#  ['9364602', '4.444.444.444.444.44', '0'],
#  ['529768', '효과음이 기가막혔던 영화', '1'],
#  ['9040274', '솔직히 평점 8점 이상은 되야되는거같다.', '1'],
#  ['3208499', '난강혜정이 일본가서 찍은건가 했네ㅋㅋ닮은것같다는 생각이 들었을 뿐이고...', '0'],
#  ['6731536', '일본영화 좋아한다면 꼭 봐야할 영화!', '1'],
#  ['6615814',
#   '진짜 이건 아님ㅋㅋㅋㅋㅋ액션영화좋아해서 액션영화만 다운받아서 꾸준히 본게 벌써 몇년인 사람임 근데 이건 진짴ㅋㅋㅋㅋㅋㅋ아무리 점수 잘 줘도 100점 만점에 10점?ㅡㅡ돈주고봤는데너무아깝다진짜ㅜㅜ그리고대체 왜 13구역 타이틀을 달고나왔는지 모르겠음 실망',
#   '0'],
#  ['5529456', '가슴이 먹먹하다, 뷰욕을 왜 이제서야 알게됐을까', '1'],
#  ['7393226', '커스틴 때문에 좋겠다', '1'],
#  ['10036253',
#   '보는내내 찝찝하고 영화가 끝나고 나서도 불쾌했다.. 중년의 남성이 이렇게까지 추잡해보일 수가 있을까..',
#   '0'],
#  ['5812647', '진짜 퀵이유로 이렇게 어이없고 재미없는영화는 처음입니다 진짜 돈아까운적은 두번째라', '0'],
#  ['9713238', '진짜재미없다..영화관에삼십분정도늦게들어갔는데사람이한명도없고..그이유를왠지알것같네..^^완전비추요', '0'],
#  ['8717232', '2012년에 본영화인대 솜이랑 키작은남자 살아서 나감', '0'],
#  ['8342710', 'ㅋㅋ 조금은 유치했지만 왕조현 주윤발 이것만으로도 충분히 볼만했다.', '1'],
#  ['8920121', '난 솔직히 재미없었어. 코믹요소가 없어서', '0'],
#  ['6148289', '싸구려 왜색 영화, 키작고 교활한 일본원숭이들의 망상, 사무라이 정신..토나온다...', '0'],
#  ['9208964', '재미있게봄 감동적이고', '1'],
#  ['10095017', '아니 찍어놓고 모니터링 한번 안하나 어떻게 염치 업이 이런걸 극장에 걸수가 있지?', '0'],
#  ['10010400',
#   "영화'산업'이라고 하잖는가? 이딴식으로 홍보 해놓고 속여서 팔았다는 게 소비자 입장에서는 짜증난다. 그나마 다행은 아주 싸구려를 상급품으로 속여판 게 아니라는 점. 그래서 1점. 차라리 연상호 감독 작품 처럼 홍보가 됐다면, 그 비슷하게 만이라도 하지",
#   '0'],
#  ['6486325', '완전 감동이다 ㅠㅠ 박신혜 짱이뻐요 ㅎㅎ', '1'],
#  ['9028463', '절망속에서 결국 빠져나온 눈물겨운 실화', '1'],
#  ['1253368', '국민학교 다닐때 이거 동생이랑 보다가.... 눈물이...ㅋ', '1'],
#  ['297077', '욕망이라는 이름의 전차.', '1'],
#  ['8599155', "'디 워'랑 같은 부류.. 저예산 + 저렴한 CG + 마구잡이연출", '0'],
#  ['8740203', '무기여 잘있거라는 보는 내내 손에 땀을 쥐고본 첫번째 애니', '1'],
#  ['8804100', '배우들 연기력이 아깝다. 별 한 개도 아깝다.', '0'],
#  ['5950829', '딱 90년대코미디영화', '0'],
#  ['3895103', '어릴때 진짜 재미있게 봤음ㅋㅋㅋㅋ', '1'],
#  ['9146695',
#   '정말최고의영화고 마지막 아이들의 노래와 비행기가 정말 잊을수 없는 여운을 남긴다.이런 영화를 이제알게된것자체가 후회될정도로 잔잔하고 깊은 여운이 남는 영화.',
#   '1'],
#  ['4993640', '보면서 어이없어서 헛웃음만 나던....', '0'],
#  ['5794799', '악역인 금단비가 더 주목받았다는것은 주연여배우들의 미스캐스팅을 의미한다', '0'],
#  ['1600635', 'General', '0'],
#  ['1118508', '보고 나서도 내내 여운이 남는 영화..', '1'],
#  ['3488301', '절대로 보지마라 보면 후회한다!!이걸영화라고 만든거냐!볼사람은 뇌를 놓고보아라!', '0'],
#  ['7749595', '무슨 내용인지 도통 모르겠다... 쓸데없이 특별해 보이려는 시도에만 열중이었던 영화.', '0'],
#  ['9804254',
#   '기쁨, 슬픔, 생명 그리고 죽음. 인간의 역사속에 거대한 하나님의 우주적 섭리가 느껴지는 영화. 특별히 어머니의 역을 맡은 여배우의 여성미와 자애로움이 인상적이다. 인생을 살면서 그런 존재가 된다면. 영상미 예술이다!',
#   '1'],
#  ['9109132', '이게뭔가요내용도없고', '0'],
#  ['10136005', '평점 어마어마하게 높네;;;; 빨리 낮춰야 할듯 5점이 적당한 영화.', '0'],
#  ['9272388',
#   '이야기도보통재미있고. 10점정도는아니라고봐요.5점6점정도인데 고릴라제작한거도 잘했긴했고.하지만 감동은 보통..아쉬운결말',
#   '0'],
#  ['9832161',
#   '솔직히 웬만한 공포영화는 다 섭렵할만큼 매니아인데. 주온은 정말 무서웠었다. 아직까지도 샤워하면서 머리감을때 공포를 느낀다. 누가 나를 쳐다보고 있는 느낌이라서... 이 느낌 나말고도 겪어본사람 있을거야. 그만큼 당시에 대단했던 영화다.',
#   '1'],
#  ['6106079', '아름다운 영화였어요', '1'],
#  ['6760555', '정말 광해와 비슷한가?', '1'],
#  ['8658227', '조쉬 하트넷 특유의 여성들을 자극하는 나약한듯하면서도 남성적인 이미지를 작 부각한듯', '1'],
#  ['3284962', '정말 속은느낌이다', '0'],
#  ['9814376', '몸매,베드신 보기좋다고 한사람은 영화 안본사람', '0'],
#  ['9093996',
#   "잘봤어요 외모뿐만이 아니라 여러가지들을 따지며 사랑에 빠지는것이 아니라 '하려고' 하는 요즘 사람들에게 좋은 영화인거 같아요....",
#   '1'],
#  ['8891326', '최악의 쓰레기. 어설프려고 정말 노력했다', '0'],
#  ['8016672', '콜린파렐. 123412341234', '1'],
#  ['9884619', '난이게 제일 재밌었는데..', '1'],
#  ['3095788', '난 좋았는데요..... 괜찮았어요', '1'],
#  ['7008459', '영화보다 댓글이 더 재밌어', '0'],
#  ['8365221', '에라이 미친 사이코 드라마야!!!', '0'],
#  ['7326531', '모든 일본문화가 들어가 있다고 할 수 있을까? 최고의 사극!!', '1'],
#  ['8415974', '엄청나게 기대를 하고 본게 아니라 괜찮았던듯?', '1'],
#  ['8488748', '더빙이 똥이야 ....', '0'],
#  ['5235134', '안타깝네. 이해를 못하는사람들 속출. 불교적이고 철학적인 작품.', '1'],
#  ['7441317',
#   '진짜 이런 개 씨,1바ㄹ OOO 같은 영화 개 시간낭비 의미도없고 무섭지도않고 내가 왠만하면 공포영화는 즐겨보는데 이건 진짜 OOOO같다',
#   '0'],
#  ['7403099', '색다르고 재밌는 영화였음. 실제로도 이런 일이 있다면 참 재밌을 것 같음. 막장 of 막장.', '1'],
#  ['57586', '어캐봐여? 꼬옥~~~~~~~보고싶내여~~~~~~~~~~~~~~~~~~~~', '0'],
#  ['5141238', '정말 식상하다못해 촌스럽기까지 ~~~~~~~~~~', '0'],
#  ['5575615', '종교적 분위기 물씬 풍기는 최루성 가족영화', '0'],
#  ['765033', '재밌다', '1'],
#  ['286680', '그냥 살지 그랬어.. 이성재만 멋짐', '0'],
#  ['9694445',
#   '음악영화라 나에겐 취향저격이지만... 비긴어게인처럼 대중적으로 흥행하긴 힘들 영화네요.. 하지만 여주가 너무 매력적이에요 ㅎㅎ',
#   '1'],
#  ['5256752', '별 0개 선택 왜없어요? 솔직히 별 반개도 아깝다', '0'],
#  ['5316818', '돈에 미친 남편과 .. 아기에 미친 돈 있는 남자 그속에서 갈등 하는 여자 18', '0'],
#  ['4929205', '어린이의 시점에서만 볼만하겠지. 오로지 어린이의 시점.', '0'],
#  ['7764248', '잠을 청할 수 있었다.', '0'],
#  ['5610275', '좋아하는 사람의 뇌가 아니던가?.. 완전 난해함.. 결말 왕실망임', '0'],
#  ['4975754', '전작에 비해서 왠지 허탈하다. 카이사르도 전작이 더 멋있는 듯 하고...', '0'],
#  ['8098297', '김민종 최고! 더 잘되시요', '1'],
#  ['4437772', '공격적인 재미, 유순한 여성성, 일기토, 지략 삼국지의 그것과 맞짱!', '1'],
#  ['8750781', '-점수를 주고 싶다. 2003년에 이정도 밖에 못만들었다는게 충격...', '0'],
#  ['5317808', '비디오테잎으로 좍좍 감아가며 봤던 영화. 가장 슬펐던 영화', '1'],
#  ['7941197',
#   '도입부를 제외하고는 따분.헬기에서 민간인을 마구 쏴 죽이는 미군, 베트공 여성 스나이퍼 등,현실감 없는 극단적인 설정.라이언 일병에서의 업햄 그리고 이 영화 주인공인 조커, 두 넘 모두 내가 싫어하는 캐릭터, 착한척 하면서 주위에 피해를 주는 넘들.',
#   '0'],
#  ['8392485',
#   '재밌는데...나만 그런가? 참고로 우리나라 까거나 하는건 하나도 안나옴 그냥 지들끼리 소설쓰고 지들끼리 자위하고 자위대도 등장하는데 그사람들도 자위나 하고 있음 일본 감정 다 떠나서 과학도로써 과학적으로 볼만한 영화였음 신선함',
#   '1'],
#  ['9551603', '제 취향은 아니네요~~~~', '0'],
#  ['1128434', '평점 조절...', '0'],
#  ['8098523', '1점도 아까운 쓰레기영화 전작이 아까움', '0'],
#  ['9969680',
#   '일편에 비해 삽질하는 브리짓이 쪼~끔 짜증날 때도 있었지만 그래도 여전히 사랑스럽다ㅎ 콜린 퍼스와 휴 그랜트를 한자리에 모아놓은 것 만으로도 10점줘야함!',
#   '1'],
#  ['7467524',
#   '지금까지본 아이리스 시리즈중 최악이다ㅠㅠ 이거해도 너무하는거아닌가...수치스럽다. 연기고자시고 다 떠나 너무도허접합....',
#   '0'],
#  ['9375027',
#   '연기력때문에 할말이 없다. 정우성과 고소영이 왜그토록 흥행작이 없는지 알고싶으면, 비트에서 연기하는거 봐라.',
#   '0'],
#  ['10079804', '전라도 노예 업주 처벌 안받았나요?? 이슈가안됐네요 그러고보니..', '1'],
#  ['4459001', '배우가 아깝다 ,,', '0'],
#  ['1971330', '볼만 한데', '0'],
#  ['8777093',
#   '결말의 의미공자가 자연에 숨어사는 노자에게 말했지. 짐승도 끼리끼리 사는데 사람이라고 따로 사냐고 진정 순수함은 더러운것사이에서도 그 빛을 유지하는것 ·',
#   '1'],
#  ['746383', '크리스 터커 짱이삼! ㅋㅋ', '1'],
#  ['10106046', '믿고보는 덴젤와싱턴. 근데 모레쯔는 왜이렇게 후덕하지...', '1'],
#  ['9456361', '나오코 진짜 집중안된다', '0'],
#  ['2461114', '감독이 밥은 먹고 다니는지 궁금하다. 배틀로얄2 이후로 최고 쓰래기.', '0'],
#  ['4854124', '아 재미 너무 없네요.. 시간 아까워요', '0'],
#  ['3352939', '난 잼있던데..ㅎㅎ', '1'],
#  ['8225461',
#   '어떻게 상류층의 속물근성을 정당화시키면서미화시킨지 모르겠다. 감독이 국회의원이나 사회적 강자한테 아부하고 싶은 가봐요 그리고 얼굴만 예쁘다고 왕되는것은 맞지만 드라마라도 도덕적으로 표현좀 해야되는게 아닌가요 감독님 정신차리세요',
#   '0'],
#  ['4728005', '가만히 보고만 있어도 씨익 웃음나는 행복한 가족의 이야기', '1'],
#  ['8761788', '사고 후 잠시 정상인이 되었던 일탈', '0'],
#  ['7094992', '좋은 영화~', '1'],
#  ['7915590', '이거예전에나온거같은데 재미네', '1'],
#  ['8693853', '샬라샬라 나오다즁자쥬아', '0'],
#  ['6714986', '......감독의 옹졸함과 치졸함이 묻어나는 영화', '0'],
#  ['5073654', '팔빠다 ㅋㅋ', '0'],
#  ['1227060', '재미없음 -_-', '0'],
#  ['8331844', '무슨 생각으로 만든걸까.', '0'],
#  ['9594029', '스토리도 흥미롭고 배우들의 연기도 인상적이다. 충분히 볼만하다!!!', '1'],
#  ['5683859', '내 인생 최고의 미드!!', '1'],
#  ['9907691',
#   "이 영화를 보고 '사랑하고 싶다' 라는 생각을 했습니다. 청소년 관람불가임에도 선정적인 장면은 나오지 않았습니다. 연인 혹은 솔로이신 분들에게 추천합니다.",
#   '1'],
#  ['10103306', '일본공포영화는 링 주온 이후로 망했음', '0'],
#  ['5850503', '지루하다.. 지루해..', '0'],
#  ['10070313',
#   '625를 직접 겪은 어르신들 얘길 들어보면 그당시 잔인한 학살은 대부분 주민들 서로간에 (주로 하층민들의 복수심에서 비롯된) 또는 군/경이 빨치산 학살한다며 벌인 살인이었지 정작 북한군은 민간인들한테는 잘해줬다고 하던데?',
#   '1'],
#  ['6475186', '그냥 다큐일뿐 ..', '0'],
#  ['8058599', '10점짜리 영화는아닌데 개인적으로는 평균평점 7점정도의 가치는 한다고 본다 스타일리쉬한 영화 ㅋ', '1'],
#  ['8217932', '정말 질질끌고 작가님제발좀 적당히하시죠은희수역맡은 사람도 그만 나쁘게 만들지아침드라마가 막장이네', '0'],
#  ['3134317', '으이구 괴물 그래픽이나 좀 다듬지 그게 머니 다 티나게 공포영화보다 웃은 건 첨이다', '0'],
#  ['5725614', '대표적인 쓰레기 김치드라마', '0'],
#  ['1251944', '네이버 별점, 꽤 신뢰도가 높네요.5점 이하는 안보는게 좋을듯..', '0'],
#  ['9836293', '남주 헤어스타일 왜 저래...? 가게분신노찌쯔!!!!', '0'],
#  ['3935543', '이런영화는 두번봐야지 안다 작은 일에도 크게 화를만드는 저나라의 국민이 인상깊다', '0'],
#  ['9329701', '김명민이 약 구해서 차 탔을 때 진짜 설마설마 했음', '0'],
#  ['6987687', '보지말아라 재미있든 재미없든 진짜 찝찝하고 기분 드러운 영화공포영화 싸이코 영화...', '0'],
#  ['4268313', '짝퉁쓰래기', '0'],
#  ['8751084', '이거 시청률이 너무낮은대 명작이고만', '1'],
#  ['9579206',
#   '현실감 제로지만 배우들이 너무 좋았어요. 특히 다니엘헤니를 많이 볼 수 있어 좋았어요. 같은 남자지만 게이는 아닙니당. 다니엘헤니 최고. 설경구 씨두 최고!',
#   '1'],
#  ['6380732', '프레디가 나에게 모욕감을 줬다 그래도 프레디라서4점준다', '0'],
#  ['6730559', '잼없네요넘', '0'],
#  ['10121905',
#   '평점이 너무 높군요. 원작으로 보심이 나을듯. 짧은 러닝타임에 감사하다고 해야하나. 주인공이 썰매를 타고 목적지에 가니 모든 사람들의 기억이 돌아온다는 황당한 설정이고 인간의 감정을 통제한다는건 데몰리션맨, 이퀄리브리엄에서 봤기때문에 신선함도 없음',
#   '0'],
#  ['8822540', '막장 드라마의 원조격인 영화... 근데 이 영화는 확실히 로즈번이 살린듯', '1'],
#  ['9109790', '해군 출신이라 관심있게 본 영화~', '1'],
#  ['9953912', '파란색 슬픔이 영화에..', '0'],
#  ['7298459', '액션 완전 OOO기..차라리 유오성이 나오는 챔프를 보겠다..;;', '0'],
#  ['9355956', '폭풍오열ㅠㅜㅠㅍ퓨ㅠ', '1'],
#  ['4329345', '착한영화... 그리고... 재미없습니다', '0'],
#  ['1504875', '사소한 이야기조차 눈을 뗄수 없게 만들던 거장의 솜씨. 예전 장이모우 그립다', '1'],
#  ['8960254', '내가본영화중 베스트5안에 듬 진짜꼭보세요', '1'],
#  ['7589723', '지금까지 본 페이크다큐영화중 제일 별로...', '0'],
#  ['9797993', '재미도 있고 공감도되는 누구나 즐길수있는 독립영화 !!!', '1'],
#  ['1180080', '"""시미즈레이코의 만화책""""비밀"""".에서 영향받은거 아냐? 똑같애"""', '0'],
#  ['8293622', '기존 한국 영화에서 느끼지 못한 색다른 느낌상업적이기 보다는 새로움에 도전한듯한 ..', '1'],
#  ['4431197', '장난하나--반전같은거 있을 줄 알고 끝까지 다 봤는데 진짜 아오..시간아까워', '0'],
#  ['8937179',
#   '예고편을 왜 하는건지 모르겠음.. 예고편에 나오는건 하나도 안나오고.. 예고편은 대판 쌈질 하는것마냥 나오더니 하하호호 하고 끝남.. 예고편이 무슨 뜻인지를 모르는건지.. 시청자들을 호구로 보는건지..낚시질좀 그만하시고 차라리 시청률 걱정되면 폐지해',
#   '0'],
#  ['8846509', '난 프랑스 영화가 이래서 좋다..', '1'],
#  ['9335640', '쓰레기쓰레기쓰레기쓰레기쓰레기쓰레기쓰레기쓰레기', '0'],
#  ['435623', '참 재밌게 봤는데... 귀여운 지미 +_+', '1'],
#  ['4198269', '시간이 지나서 또 봐도 정말 가슴애린 드라마......ㅠ.ㅠ', '1'],
#  ['5733754', '사촌동생들 때문에 같이 보긴했는데 정말.. 사촌동생들도 재미없다고 하네요', '0'],
#  ['8278608', '설득력없는 꼴통페미니즘. 페미나치적인 마인드.', '0'],
#  ['23653', 'B급을 지향하는 C급 작품.', '0'],
#  ['7813287', '음 잘 모르겠다 뭘 봐야 하는 건지 소녀 가장 이야기인가', '0'],
#  ['5824795', '우리와 틀리다고 생각했던 장애인이 우리와 틀리지않단것을 알려주었다.10403', '1'],
#  ['842944', '재밌고 감각있고 쿨한 영화였는데.마지막 결말이 약간 아쉽지만', '1'],
#  ['7929874',
#   '그냥 재미없네 보던거니까 마저봐야지 이랬는데 갑자기 원주민생활하는건 진짜 어처구니가 없었음이건 그냥 영화가 아니다',
#   '0'],
#  ['10155376',
#   '진짜 언제 90분이 지나갔는지 모를정도로 몰입해서보고 정말 너무 재미있게 봄... 너무 아련해서 영화 평 정말 처음 남겨봄.. 진짜 내가 이 나이에 애니를 보며 이 밤중에 이렇게 울줄이야.. 에몽아ㅠㅠ',
#   '1'],
#  ['8680215', '사과해요, 나한테!!!', '1'],
#  ['7679026', '골목상권에 들어온 대형슈퍼마켓이 생각난다', '0'],
#  ['9989270', '평점 조절이 필요하다 라는 생각이 든다!', '0'],
#  ['8827685', '무협 멜로의 걸작 ... 말해 모해', '1'],
#  ['5524686', '너무재미있게 보았는데요 다시 볼수없을까요', '1'],
#  ['6158788', '오글거리고 유치하고 완전최악이었음...', '0'],
#  ['307912', '절대비추.....', '0'],
#  ['6082188', '한국껀줄알앗는데 일본꺼엿네 ㅋㅋ', '0'],
#  ['9704763', '꽃 한송이 놓고 갑니다ㅋㅋ', '0'],
#  ['9687594',
#   '내 삶의 가장 의미있는 일 중 하나라면 바로 이 영화를 봤다는 것이다. 살면서 죽기 전에 한번 꼭 봐야 할 영화.',
#   '1'],
#  ['9430257', '생각보다 볼만했음ㅋ여주인공이 연기가 좋네여', '1'],
#  ['9073274',
#   '자꾸 뭘 설득할려하고 설교할려고하는게 보기거북하다. 그리고결혼반지를 위해 범죄가담하다니 무슨 개역지설정이냐.',
#   '0'],
#  ['7726829', '와...', '0'],
#  ['8213409', '제발 전문성우를 써주세요 ㅠㅠ', '0'],
#  ['8544691',
#   '살면서 처음 접해본 장르라서 조금 당황스럽다. 솔직히 영화 자체는 100% 자신의 색깔에 충실했고 완성도 역시 뛰어난 편이지만.. 좋아하지도 이해하지도 못하겠다ㅋ',
#   '0'],
#  ['6269046', '오늘 아이데리고 봤는데...아이는 좋아하데요...ㅎㅎ 미취학, 초등 어린이에게 추천~', '1'],
#  ['5934328', '이것을 끝까지 참고 본 내가 제일 자랑스럽습니다.', '0'],
#  ['7668668', '존내재밋습네다', '1'],
#  ['5655827', '안봐도 되는 영화.', '0'],
#  ['4644401', '원작 망쳤네요', '1'],
#  ['9945284', '그냥 주는거다. 5점은 아닌 듯', '1'],
#  ['705362', '나쁘지 않으나 개인적으로는 지루했다는.', '0'],
#  ['5708802', '어의없는 스토리.. 여자죽을때 웃음나옴.. 로맨스영화냐?', '0'],
#  ['9790871', '순수함이 두근거려 좋았다 감독님은 관객들이 뭘원하는지 잘아는듯..여운이 많이 남는다', '1'],
#  ['3810929', '기방난동사건이후 최악의 영화 .재밌다는 사람들 믿고 봤더니 다 알바생인듯 ... ㅜㅜ', '0'],
#  ['6278900', '로맨스와 스릴러 짬뽕놔서 뭘 말하고 싶은건지.. 스토리도 허황된 느낌', '0'],
#  ['4666521', '이건좀 아니잖아...', '0'],
#  ['8894910', '윤아은 안됨!!원작자님 캐스팅에 참여해주세요작품 망치면 안되잖아요', '1'],
#  ['10067891', '지금생각해도 내가본영화중에 이영화는 내생애 최고의영화였던것같다', '1'],
#  ['4656042', '천녀유혼1,2에 비하면, 뭐라 표현하기 힘든 퀭한 영화', '0'],
#  ['9541420',
#   '불륜을 미화한 영화 남은사람들은 어쩌라고 또 돈걱정 따위 안하는 사람들의 이야기를 공감하라고 강요하는 영화 음악이랑 영상미로 3점',
#   '0'],
#  ['6206837', '최고다....... walk like a man 이란 노래는 원곡보다 영화속 노래가 훠~~얼씬 좋아요', '1'],
#  ['8970443', '소재가 굉장히 신선했다', '1'],
#  ['8870035', '내사랑 키아누 ♡.♡ 리브스 ♡.♡', '1'],
#  ['9969587',
#   '두말할 나위없이 최고의 작품.인생에 대해서 생각해보게 하는 깊이있는 영화.전 출연진과 제작진에게 큰박수를 보낸다.',
#   '1'],
#  ['7666606', '솔직히 산만 하기만했다', '0'],
#  ['2176436', '말이필요없지.. 성룡영화에선.....무언가를다른것을느낄수있다', '1'],
#  ['10018117', '화학을 해서 그런지 잼잇게 봣습니닼ㅋ 옆에 친구 중간중간 노이해.... 나중에 해석 ㅠㅠ 잼잇엇숩니다', '1'],
#  ['8033328', '아직 준비되지 않는 젊은영화인들여 함부로 장편에 손대지 마라천천히 공부하고 나와라', '0'],
#  ['7088731',
#   '으엉 간만에 추억돋아서 봤는데사실 원작 자체도 두서없이 전개되는데영화감독은 내용앞뒤도없이 막 잘라서정신없음ㅇ배우들은 책읽고 특히 대사 그대로 살린거 오그리오그링ㅋㅋㅋ간만에 소설로 읽어야지',
#   '0'],
#  ['4883754', '개 쓰레기같은 것들아 감히 파라노말엑티비티를 팔아먹냐', '0'],
#  ['9942955', '기억은 조작되기 마련.. 그사람이 아니고서는 함부러 말하지 말자', '1'],
#  ['9466607',
#   '재밌게 봤습니다,, 그저 문헌에 적힌 문란한 사도세자가 아닌, 정조의 아버지로서 그 그릇이 어느 정도였는지 잘 보여준 작품이 아니었나 싶네요 시나리오도 시나리오지만 배우들 연기가 일품이었습니다',
#   '1'],
#  ['8933491',
#   '휴일낮에 침대에누워서 티비보다가 영화채널에서 틀어주길래 어쩔수 없이 봤는데 나중에는 벌떡 앉아서 봤던 영화.!완전 몰입되고 나름 스토리도 치밀하고 해리슨 포드다운 액션- 좋습니다. 저는 영화광도 영화 평론가도 아니고 영화 자주보는 일반 남자사람임',
#   '1'],
#  ['5844083', '절제의 미학이아니라.. 지루함의 극치가 되버린 안타갑다..', '0'],
#  ['3674831', '영화관에서 보기엔 돈아까웠다;;;;;....... 솔직히 재미없었다 ㅜㅜ', '0'],
#  ['1736999', '인간의 솔직함을 보여 주고 싶었는가..이런 방법말고도 다른 방법이 충분이 있을텐데?', '0'],
#  ['9845902', '정말 사랑에 대해 다시생각한거같습니다 감동이에요', '0'],
#  ['7406758', '내용은 교육적이나 정말지루해서요ㅜ', '0'],
#  ['9121447', '꿀잼! 특히 소유랑 서인영ㅋㅋㅋㅋ매력터져', '1'],
#  ['7988084', '태어나서 본 영화중에 제일 재미없었음', '0'],
#  ['6880550', '화면을 흑백으로 바꾸기만 하면 50년대 작', '0'],
#  ['9759719', '쇼핑몰 안에서만 찍어서 너무 재미없고 답답한..내용도 없다.', '0'],
#  ['2288547', '진짜 쓰레기영화.. 돈아까워 죽는줄 알았다.. 여러분 보지 마세요', '0'],
#  ['468899', '와아오 두근두근~ 익스트림자체', '1'],
#  ['9736192', '폭력영화, 자극적이고 실험적이라고 예술인가?', '0'],
#  ['9304503',
#   '일본영화랑 비슷한건 저만 느끼는건가요??수트입으면 미남으루 변하구 마지막에 평생입으라구 권유받구...창조가 이렇게까지 중복될수 있눈건지...잘 모르겠네여',
#   '0'],
#  ['9231599',
#   '진짜 이렇게 재미도 없고 감동도 없는 영화는 처음이네특히나 박사고 나발이고 모든인물들이 컴퓨터 할때 손찍는데키보드 누르지도 않고 ㅋㅋㅋ컴퓨터 화면들은 똑같은 파트만 무한 반복되고허접해도 너무 허접하네... 배우들 연기도 개떡이고 ...',
#   '0'],
#  ['5657638', '최고의 농촌드라마.', '1'],
#  ['8239718',
#   "독립영화 실력자들의 스타 리그, 옴니버스라는 피로감이 극복되는 수준이다. '얼음강'은 단독 장편으로 만들었어도 좋았을 듯. 주인공이 혹여 - 평소라면 1%도 공감 안되는 - 여호와의 증인이라도 납득이 될 정도로 감정을 설득하는 솜씨가 탁월하다.",
#   '1'],
#  ['9147374', '좀비좀비 그러는데 좀비아닙니다. 우주의 아름다움에 미쳐버린 인간일뿐 충분히 가능한 일이죠', '1'],
#  ['9788286', '개재미없음 막장스토리 어거지 ㅋㅋ', '0'],
#  ['502971', '뭐하나 흠잡을 것이 없다. 최고!', '1'],
#  ['8837036', 'OST가 좋은 영화!!', '1'],
#  ['3059926', '탁재훈나오믄재밌는데와이라지스토리중반부터너무쳐짐약해약해약해~지겨워뒈지는줄알', '0'],
#  ['4009568', '서스펜스도 없고 스릴도 없다.', '0'],
#  ['3044091', '우리나라 정서하고 안맞다`~', '0'],
#  ['4161935', '어디선가 많이 본 흔한 스토리', '0'],
#  ['8535856', '최고의 드라마....', '1'],
#  ['9848292', '우리 모두는 누군가에게 섬머였다!', '1'],
#  ['1389397', '힘알이 하나 없는 주인공들..맥이 다 빠진다.', '0'],
#  ['8014926', '너무너무귀여운영화', '1'],
#  ['518874', '전형적인 일본식 엽기 괴짜 코메디. 그 특이함에 끌리는건 왜지', '0'],
#  ['6428636', '와 이걸 5점 이상 준 사람들은 뭐지. 나루토 극장판 중에 가장 쓰래기', '0'],
#  ['4008401', '정당한 노력이란 보상받게 마련이다.나름 일정 성취가 있고,좋은 결실을 거둔 작품.', '0'],
#  ['7494798', '아씨 울었다.', '1'],
#  ['5954884', '기적은 이미 일어났다.', '1'],
#  ['9718518', '아이들과 함께 보기 좋았지만, 그냥 그래요.', '0'],
#  ['4492202', '전율을 느꼈다.', '1'],
#  ['6940155',
#   '여기저기 지저분한내용에 이기적인 사람들의 역겨운 연애사...마지막으로 갈수록 시청률 안나오니까 막 갈겨쓴내용...',
#   '0'],
#  ['8662240', '별로...완전별로....마지막빼고 넘 유치하고재미없고 ..', '0'],
#  ['9924896', '세월이 지나서 다시 보니 뭔가 먹먹함이 다르더군요. 공감하는 사람이라면 가슴속에 명작으로 남을 듯...', '1'],
#  ['8607739', '아이들이 보기엔 좋을지도?', '0'],
#  ['7081837', '보니까 선정성이 좀 15세 같음:::: 그래도 액션은 좋음', '1'],
#  ['8672382', '카타르시스를 느끼기에 충분한...값진영화였다..', '1'],
#  ['5838594', '여주 린제이 로한 닮았다. 전체적인 분위기나 배경은 좋았지만 내용은 지루했다.', '0'],
#  ['8747250', '당신이 솔로가 아니면 이 영화를 보지마세요.', '0'],
#  ['8893010',
#   '남이 차안에서 전화통화 하는걸 90분 가까이 구경하고 있으라고? 폰부스는 명작이라 생각하지만 이 영화는 진짜 장난하나',
#   '0'],
#  ['4063053', '전형적인 저질영화', '0'],
#  ['1964094', '답을 알려고 하지마라.', '1'],
#  ['3748749', '재미잇음매우~~', '1'],
#  ['7236510', '진짜 잘 만든 수작', '1'],
#  ['10110553', '제발 2좀 찍어주세요. 현기증 난단 말이에요', '1'],
#  ['3889299', '너무나도 따뜻한, 마음이 따뜻해지는... 한번쯤 자신을 되돌아보게 만드는 영화', '1'],
#  ['3551150', '뭔가 조금씩 부족한 영화 놀래킬려면 확! 놀래키던지 어정쩡한 -_-;;', '0'],
#  ['9855967',
#   '이거 참...소재는 참 좋은데 내용전개가 개판...사람수도 많고 총도 있는데 그걸 지들끼리 서로 다 흩어져서 일방적으로 밀리네..거기다 식인종이라면서 표현을 좀비로 해놓으면 어쩌잔거야..식인으로 인해 인성이 말살되고 짐승화 되었다는 표현이라도 있던가',
#   '0'],
#  ['6607633',
#   '포스터만 그럴싸하다. 13구역이라는 이름만 가져다 쓴 영화. 완전 졸작이다. 액션 신도 개허술하고, 스토리도 이상하다.',
#   '0'],
#  ['10263072', '대체 왜 재미없다는거지;;난 존나재밌던데', '1'],
#  ['9135211', '늑대들의 여정이 너무 낭만적이었던 애니 스토리도 좋지만 음악은 일본 애니중에 탑으로 뛰어나다', '1'],
#  ['8676753', '미국 흑인 민권운동사를 완벽하게 요약했다.', '1'],
#  ['9798776', '그가 뛰어내리지 않았다면 어떻게 되었을까', '1'],
#  ['9393658',
#   '8점대는 나와야지. 그냥 단순한 액션공포물이 아닌데도 긴장감 공포감 연출 쩔고 음악도 좋고.. 몇년이 지나도 기억나는 인상적인 좀비물인데. 평점 너무 짜서 10줌',
#   '1'],
#  ['6890985', '아역 연기는 좋았으나 내용은 쓰레기', '0'],
#  ['7060802',
#   '진짜....재미없다 극장에서 볼거없어서 걍 스릴러라길래봤는데ㅋㅋㅋㅋㅋㅋㅋㅋㅋ웃음밖에안나온다 혹시나해서라도 절대보지마라진짜제발',
#   '0'],
#  ['8914565', '평점은 믿지마셈 재밌음', '1'],
#  ['1318078', '이거 좋다는 놈들은 뭐하는 것들이야 ㅡ.ㅡ', '0'],
#  ['6825739', '이게 21c영화냐? 90년도영화냐? 쓰래기들아', '0'],
#  ['9984617', 'ufo를 믿으려는 자들.', '0'],
#  ['9132252', '너무 구식으로 웃길려고 함. 보는 내내 지겨움', '0'],
#  ['9612977', '이런거 좋아하는 사람들 정신 세계가 궁금하다..', '0'],
#  ['8200058', '연예계의 현실을 알리고자 하는 마음은 알겠지만, 영화의 재미는 없었다. 지루해 죽을뻔 했음.', '0'],
#  ['3527577', '아주 재미있고 책으로봐도 정말재미있다~~', '1'],
#  ['3656988', '..........끝내주게 재밌다.', '1'],
#  ['6584219', '유투브동영상을 돈내고 보는게 낫다는 생각이 들게한 영화', '0'],
#  ['4919409', '아쉬운 점도 있지만, 스토리에 맞는 분위기나 배경, 지하철기관사의 삶 등을 잘 묘사', '1'],
#  ['8466409',
#   '스타워즈 1편과 맞아떨어지도록 잘 만든영화 최고의 에피소드 다스베이더의 탄생과 루크,레이어의 운명을 알수있는 레전드',
#   '1'],
#  ['8116113', '소희가 귀엽다 귀엽다 졸귀', '1'],
#  ['3436810', '소문난 잔치(호화 캐스팅)에 먹을 건 없다', '0'],
#  ['2074725', '주성치 영화 최고의 졸작', '0'],
#  ['10181517', '구우우웃~~!!!!', '1'],
#  ['3217546', '딱히 흠잡을 것도 두근거릴 것도 없는 교과서적 플레이.', '0'],
#  ['9841078', '영화의 중심은 역시 스토리인것을. 반전의 반전 너무 재미있다.', '1'],
#  ['9025696', '8.3이 아니라 9.3 이 아닌가?', '1'],
#  ['4276245', '참 재미있었다. 연기를 발로 하는 삼류배우들 얼굴보면서... ㅋㅋㅋ', '0'],
#  ['6020106', '재밌군', '1'],
#  ['8705473', '이것도 재밌는데...ㅋㅋ', '1'],
#  ['9810971', '1점도 아깝다 평쓰는 것도 귀찮다 보는 내내 오글거려서 손발사라지는 줄 알았다', '0'],
#  ['7852536', '기대 안하고 봤는데... 영화 보는 내내 몰입해서 재미있게 봤어요~~', '1'],
#  ['8386647',
#   '유쾌함과 스릴러적인 요소가 잘 어울려진 명작. 후속작 보다 훨씬 매력있음. 두고 두고 간직해두면서 꺼내보고 싶은 영화.',
#   '1'],
#  ['39563', '좋네..괜찮고.', '1'],
#  ['7772563', '명작. 너무 좋았던 드라마. 스토리, 캐스팅, 연기, 음악, 연출 모두 완벽했던.', '1'],
#  ['5725103', '괜찮은영화,,영화도괜찮았지만 나영언니완전머싯고예뻤음ㅠㅠ', '1'],
#  ['7462757',
#   '일단 재미있다 ! 고래 몇마리로 국가적으로 호들갑떠는게 오버스럽겠지만 그런 모습이 우리는 모두가 도와가며 살아야하는 지구의 생명이란 메세지는 참으로 감동적이다.',
#   '1'],
#  ['8868808', '지금 첨봤는데 1회만 봐볼까하고 봤다가 주말 밤새완주하였다. 여운이 많이 남는 드라마', '1'],
#  ['6933426', '애니메이션 뮬란이 아쉽다. 전쟁씬도 그렇고 연기도 그렇고 이야기도 그렇고그저 그래', '0'],
#  ['10111771', '기대않 하고 봣는데 진짜 내용도 좋고 재미도 있네요!!', '1'],
#  ['493092', '좋았다', '1'],
#  ['1132815', '슬픈 맑음. 파문에 주목하라.', '1'],
#  ['10102549', '김윤진 좋아하니깐...♡', '1'],
#  ['2110412', '재밌따!!', '1'],
#  ['10138191', '무리수가 되어버린 코미디 기획상품.', '0'],
#  ['7457162', '나홀로집에와더불어 나의최고의영화..', '1'],
#  ['9167250', '나는 떠올랐다 그옛날 국산애니 (아마겟돈)의 악몽이', '0'],
#  ['8404879', '완전 역겨운 쓰레기 영화다 기술적 수준을 떠나 각본이 무개념', '0'],
#  ['2422271', 'sunday booldy sunday........., 고결한 신사들께서 무슨 짓을 하셧을까?', '1'],
#  ['7530240', '캬.. 개안음..ㅎㅎㅎㅎ', '1'],
#  ['9991915', '보는내내 너무너무 재미있었음', '1'],
#  ['9988760', '김소현 팬됬습니다....너무 재밌음', '1'],
#  ['2615698', '삐에로와 흑인남자와싸웠을때 재미있었다 ㅋㅋㅋ아웃겨', '1'],
#  ['7684164',
#   '유럽영화가 이번정부에 많이 들어와 즐겁긴하다만 그 내용들이 왜 이리 진부한걸까,,,,,,,,,,,,,,,,,,,,,,,,,,,유럽영화를 욕되게 하고있단 소리다,,',
#   '0'],
#  ['10020563', '왠만한 허접영화도 재미있게보는데 이건 도를 넘어섰다', '0'],
#  ['2497690', '어떤 누구도 다른 이의 삶과 죽음에 대해 왈가왈부 할 순 없다.', '1'],
#  ['8906022', '굿굿굿 또해라또해라 제발 ㅠㅠ', '1'],
#  ['4133147', '주님께서 부르셔서 제가 여기 있나이다.', '1'],
#  ['9436392', '미성년자가 돈많은 아저씨에게 순결을 바치고 데인후 결국 정신차리고 공부해거 명문대가는 진부한 결말', '0'],
#  ['9840716', '정말 재밌게 봤고 빈센트도 꼬마도 연기 너무 잘하네요. ㅎ', '1'],
#  ['6170546', '솔직히 원작보다 훨씬낫다 원작 무슨 인간이 말도못하게설정해놨어', '1'],
#  ['5383358', '말이 필요없음,,, 아 진심 개재밌다ㅠㅠ', '1'],
#  ['10208479', '보니까 이양반이 다세포소녀 감독이네', '0'],
#  ['4761480', '굿 잡!!! 친구랑 또 보고 싶네요!', '1'],
#  ['8180877', '재미진짜 흥하네 근데 yang**** 이새끼 관종인가 ㅋㅋㅋ', '1'],
#  ['9320316', '야경꾼보다 엉망지루함', '0'],
#  ['9661317', '예원찡... 그만울어....', '1'],
#  ['9444015', '근 5년동안 본 모든영화 통틀어서 최악의영화..시간이 남아돌때 봐도 시간이 아까운 역대급 쓰레기영화;;', '0'],
#  ['7301394',
#   '감동이다.. 참고로 이 영화 보신분들 마지막엔딩부분에 자막으로나오는부분잇죠? .. 이게 영화상에서 실화라는거지 진짜 레알 현재 실제로 실화라는말이아니에요.. 전지현이 피디잔아요 다큐찍는거 ...그 다큐에서엔딩장면이지 진짜 실제가아니에여.. 쨋든',
#   '1'],
#  ['8059949', '달기지...미니어쳐 티 팍팍 나던데...우뢔매 보는줄 알았다...혹시 특수효과 감독이 심형래?', '0'],
#  ['8051141', '재미 드럽게 없다ㅋㅋㅋ', '0'],
#  ['9146376', '야 세르게이!!! 작은 고추의 매운맛을 보여주마', '0'],
#  ['9413155',
#   '정여립과 정철, 기축옥사까지.. 스토리 탄탄해서 좋습니다. 배우들도 연기 참 잘하고 남녀주인공들 케미도 좋고! 챙겨 볼 수 밖에 없는 드라마ㅠㅠㅠㅠ',
#   '1'],
#  ['8007833', '개OO영화네요....내용도없고 그냥심심해서만든영화가..', '0'],
#  ['8557767', '두개는 줄려고 했는데 알바가 많아서. 아후 볼거없어서 채널 돌려도 다시 다른데로 돌리게만드는구나', '0'],
#  ['9136302', '왜 0점은 줄 수 없나요?', '0'],
#  ['8657974', '영화사에 남을 작품. 실험영화의 완성본', '1'],
#  ['9111762', '자식을 그렇게 때리냐?', '0'],
#  ['8929395', '이게 대체 무슨 내용이야;;', '0'],
#  ['7339744',
#   'ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ옛다 1점이나 처먹어랔ㅋㅋㅋㅋㅋㅋㅋㅋ이게 7점급?이건 1점짜리. 내용도 결말도. 살다 살다 뭐 이딴...',
#   '0'],
#  ['9445949', '감동적이였고 좋았습니다', '1'],
#  ['9830821',
#   '초반에 개재미없었는데 볼수록 점점 재밌어짐! 외계인이 내가 알던 에일리언에 나오던 외계인이 아니야....',
#   '1'],
#  ['9602598', '쇼핑백 잊혀지지 않는다....', '0'],
#  ['4085435', '의도는 좋지만 너무 몰입이 안되는걸 어떡해', '0'],
#  ['7404128', '유치하지만 가볍게 볼만함', '0'],
#  ['7628876',
#   '화려한 색채때문에 눈이 아프지만 그 나름대로 화려연예계여자욕망에대해 표현해냈던거같다 보는내내 진짜 리리코심정가진 연옌들도 있을거같고..나를한번도보지못하고알지못하는사람들이날어떻게사랑하냐그런대사 나왔을때 소름돋더라 연예인들은 많은사랑받으면서도 참 허전할듯',
#   '1'],
#  ['3889736', '본지 수OO이 지나도 아직도 생생함. 고양이 귀신의 복수가 진짜 무서웠지', '1'],
#  ['4070437', '영상이 대학교 졸업작품같아서 그렇지 꽤나 많은걸 담아놓은 영화임에는 분명하다.', '1'],
#  ['9445843', '최강 전차부대 ..,,..', '0'],
#  ['7425748', 'ㅇㅇ', '0'],
#  ['7991350', '진짜 어이없는 소재라고 생각하며 보는데 개 웃겨.... 남자로서는 솔직히 조금은 부러울수도 있는', '1'],
#  ['8825761', 'tv 전기세가 아까웠다!!!', '0'],
#  ['10251900',
#   '초등학교때 선생님이 보여주신 영화 시간이 흘러서 기억나는건 에이즈에 걸렸던 남자아이와 운동화였고 그때 봤던 영화가 뭐였을까? 궁금했었는데 그 영화가 바로 굿바이마이프렌드였다 12년전이나 12년후나 명작은 시간이 흘러도 명작이다',
#   '1'],
#  ['4202224', '넘 재밌었어요/ㅅ/ㅎㅎㅎ', '1'],
#  ['4726967', '설리 94년생인데 93년도 영화에 어떻게 나오져?', '1'],
#  ['5466870', '샷의 연결이 아닌 충돌만큼이나 거룩한 제목 또한 인상적이구려', '1'],
#  ['6077451', 'ㅋㅋㅋ 재미없음', '0'],
#  ['9469311', '오오 난 여태까지 맷데이먼의 최고의영화는 본 얼티메이텀,라이언일병구하기 뿐인줄알았음ㅠ 굿윌헌팅도쩐당', '1'],
#  ['9726724', '이야기 자체가 흥미를 끌지 못하는군', '0'],
#  ['7285074', '날 로그인하게 만들다니.....청춘이여 영원하라....', '1'],
#  ['6236997', '현정언니 짱이죠 완전 잼잇어요 ㅎ', '1'],
#  ['7558359',
#   '영상미 예쁘고 좋지만 러닝타임이 2시간이 넘는데 초반 30분에 줄거리 다 나갔고 엄청 지루한 화보집 보는 기분 일본영화 특유의 그 이해못할 희한함이 있음',
#   '0'],
#  ['7252691', '스토리 연결 전혀 안되고 편집해서 끼워맞춘 드라마 말아먹은 작품', '0'],
#  ['8789344', '여자 주인공이 예뻐서 끝까지 봤다', '0'],
#  ['247661', '지구를 지켜라...혹 이 작품을 보고 만든 건 아닌지...', '1'],
#  ['10263063', '저렇게 힘들게 영화를 만드는데, 왜 한국영화는 다 쓰레기냐?', '0'],
#  ['6831499',
#   '케릭터가 살아있었으며, 미장센이 훌륭했다. 이야기는 몰입도 있었고, 불필요한 샷은 존재하지 않았다. 노인을 위한나라는 없다 먼저 봤지만 코엔감독 매력적인영화를 만드는 멋있는 사람',
#   '1'],
#  ['474835', '마지막이 좀황당했지만 좋은영화', '1'],
#  ['3279841', '우연히 tv를 돌려보다가 사로잡혔다. 최근 10년간 본 코미디 영화 중 최고', '1'],
#  ['8407277', '연 기 굿 화이팅해요누나', '1'],
#  ['9673323',
#   '마이클베이 최근작을 볼때마다 느낀다. 블록버스터 액션장르라도 탄탄한 시나리오는 영화의 필수라는것을. 그리고 당신이 기대하던 메간폭스는 늙었다.',
#   '0'],
#  ['8121444', '0점은없나?1점은 너무 후하네', '0'],
#  ['10275296', '미달이는.. 연예계를 바라보는 태도를 고쳐야 한다.', '0'],
#  ['6473973', '파괴된 관객들.', '0'],
#  ['8417568', '알콜중독자들 덕에 평점이 낮은가?', '1'],
#  ['7126211', '중견배우들이 만들어놓은 긴장감이 나름 긴장감있게 싸워보려했던 도술사들에 의해 헛웃음나온다.', '0'],
#  ['8379556',
#   '남자 주인공 늑대 인간으로 변하고 끝나네유. 평점 보고 안 볼까 하다가 봤는디 재밌네유. CG보다 이런 실물 특수 효과가 더 보는 재미가 있어유. 웃기기까지 하네유. 근디 제목 번역은 어느 바보가 한거여. 그냥 늑대 인간이 아니잖여.',
#   '1'],
#  ...]

# %%
# 데스트셋 셋 로드
with open( test_path, 'r', encoding = 'utf-8') as f:

  result = [i.split('\t') for i in f.read().splitlines()]

# 첫 번쨰 칸 빼고 , 
result = result[1:]

test_tmp = result

# %%
twitter = Twitter()
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
twitter.pos("안녕해", stem = True)
# Out:
# [('안녕하다', 'Adjective')]

# %%
stems = [""] * 40

# 태깅 문장
text = "더이상 정복할 땅이 없자. 시저는 눈물을 흘렸다"

# 현재시제로 만든후 태깅
tagged = twitter.pos(text, stem=True)

stems_index = 0
for i in range(len(tagged)):
    # 태깅 결과
    print("tagged[{}]={}".format(i, tagged[i]))

    # 단어
    print("tagged[{}][0]={}".format(i, tagged[i][0]))

    # 품사
    print("tagged[{}][1]={}".format(i, tagged[i][1]))

    # 명사나 형용사면 추가
    if tagged[i][1]=="Noun" or tagged[i][1]=="Adjective":
        stems[stems_index] =  tagged[i][0]
        print("명사 형용사 라서 stems에 추가")
        stems_index +=1
    print("="*100)
# Out:
# tagged[0]=('더', 'Noun')
# tagged[0][0]=더
# tagged[0][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[1]=('이상', 'Noun')
# tagged[1][0]=이상
# tagged[1][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[2]=('정복', 'Noun')
# tagged[2][0]=정복
# tagged[2][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[3]=('하다', 'Verb')
# tagged[3][0]=하다
# tagged[3][1]=Verb
# ====================================================================================================
# tagged[4]=('땅', 'Noun')
# tagged[4][0]=땅
# tagged[4][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[5]=('이', 'Josa')
# tagged[5][0]=이
# tagged[5][1]=Josa
# ====================================================================================================
# tagged[6]=('없다', 'Adjective')
# tagged[6][0]=없다
# tagged[6][1]=Adjective
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[7]=('.', 'Punctuation')
# tagged[7][0]=.
# tagged[7][1]=Punctuation
# ====================================================================================================
# tagged[8]=('시저', 'Noun')
# tagged[8][0]=시저
# tagged[8][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[9]=('는', 'Josa')
# tagged[9][0]=는
# tagged[9][1]=Josa
# ====================================================================================================
# tagged[10]=('눈물', 'Noun')
# tagged[10][0]=눈물
# tagged[10][1]=Noun
# 명사 형용사 라서 stems에 추가
# ====================================================================================================
# tagged[11]=('을', 'Josa')
# tagged[11][0]=을
# tagged[11][1]=Josa
# ====================================================================================================
# tagged[12]=('흘리다', 'Verb')
# tagged[12][0]=흘리다
# tagged[12][1]=Verb
# ====================================================================================================

# %%
# 함수화
twitter = Twitter()

def getNounAdjective(text):
  # 단어 40개 추가할 리스트
  stems = [""] * 40

  # 인덱스 설정 , 40개 리스트의 마지막 인덱스는 39
  stems_last_index = (len(stems) - 1)

  stems_index = 0
  
  # 문장 품사 태깅
  tagged = twitter.pos(text, stem = True)

  for i in range(0, len(tagged)):
    # 명사나 형용사면 단어 추가
    if (tagged[i][1] == 'Noun') or (tagged[i][1] == 'Adjective'):
      stems[stems_index] = tagged[i][0]

      # 단어 40개 다 추가했으면 멈춤
      if stems_index == stems_last_index:
        break

      stems_index +=1

  # 명사나 형용사가 1개면 리턴 안받기
  if stems_index > 2:
    return stems
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
getNounAdjective("나는 달린다. 공양이가 날아온다 행복하다")
# Out:
# ['나',
#  '달린다',
#  '공양',
#  '행복하다',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
for i in range(len(train_tmp[0:10])):
    print("train_tmp[{}]={}".format(i, train_tmp[i]) )
    print("train_tmp[{}][1]={}".format(i, train_tmp[i][1]) )
    print("train_tmp[{}][2]={}".format(i, train_tmp[i][2]) )
    print("getNounAdjective(train_tmp[i][1])=",getNounAdjective(train_tmp[i][1]))
    print("="*100)
# Out:
# train_tmp[0]=['9976970', '아 더빙.. 진짜 짜증나네요 목소리', '0']
# train_tmp[0][1]=아 더빙.. 진짜 짜증나네요 목소리
# train_tmp[0][2]=0
# getNounAdjective(train_tmp[i][1])= ['더빙', '진짜', '짜증나다', '목소리', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[1]=['3819312', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '1']
# train_tmp[1][1]=흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나
# train_tmp[1][2]=1
# getNounAdjective(train_tmp[i][1])= ['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍다', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[2]=['10265843', '너무재밓었다그래서보는것을추천한다', '0']
# train_tmp[2][1]=너무재밓었다그래서보는것을추천한다
# train_tmp[2][2]=0
# getNounAdjective(train_tmp[i][1])= ['무재', '밓었', '다그', '래서', '추천', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[3]=['9045019', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '0']
# train_tmp[3][1]=교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정
# train_tmp[3][2]=0
# getNounAdjective(train_tmp[i][1])= ['교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[4]=['6483659', '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다', '1']
# train_tmp[4][1]=사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다
# train_tmp[4][2]=1
# getNounAdjective(train_tmp[i][1])= ['몬페', '의', '익살스럽다', '연기', '영화', '스파이더맨', '커스틴', '던스트', '이쁘다', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[5]=['5403919', '막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.', '0']
# train_tmp[5][1]=막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.
# train_tmp[5][2]=0
# getNounAdjective(train_tmp[i][1])= ['막', '걸음', '마', '세', '초등학교', '학년', '생인', '영화', '반개', '아깝다', '움', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[6]=['7797314', '원작의 긴장감을 제대로 살려내지못했다.', '0']
# train_tmp[6][1]=원작의 긴장감을 제대로 살려내지못했다.
# train_tmp[6][2]=0
# getNounAdjective(train_tmp[i][1])= ['원작', '긴장감', '제대로', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[7]=['9443947', '별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네', '0']
# train_tmp[7][1]=별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네
# train_tmp[7][2]=0
# getNounAdjective(train_tmp[i][1])= ['별', '반개', '아깝다', '욕', '이응경', '길용우', '생활', '년', '정말', '발', '해도', '그것', '납치', '감금', '반복', '반복', '드라마', '가족', '없다', '연기', '사람', '네', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[8]=['7156791', '액션이 없는데도 재미 있는 몇안되는 영화', '1']
# train_tmp[8][1]=액션이 없는데도 재미 있는 몇안되는 영화
# train_tmp[8][2]=1
# getNounAdjective(train_tmp[i][1])= ['액션', '없다', '재미', '있다', '몇', '안되다', '영화', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================
# train_tmp[9]=['5912145', '왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?', '1']
# train_tmp[9][1]=왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?
# train_tmp[9][2]=1
# getNounAdjective(train_tmp[i][1])= ['왜케', '평점', '낮다', '꽤', '볼', '데', '헐리우드', '화려하다', '있다', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ====================================================================================================

# %%
def kor_movie():

  # 학습 데이터로 사용할 리뷰데이터 저장 리스트
  train_x = []

  # 정답 데이터로 사용할 0,1 을 저장 리스트
  train_y = []
  for i in tqdm(range(len(train_tmp))):
    # getNounAdjective 함수 써서 명사랑 형용사만 리턴
    noun_adjective = getNounAdjective(train_tmp[i][1])

    # None값이 아니면
    if noun_adjective is not None:

      # 리스트에 추가
      train_x.append(noun_adjective)

      # 0,1 ,값을 정수로 변환해서 저장
      train_y.append(int(train_tmp[i][2]))

  # 검증 데이터로 사용할 리뷰데이터 저장 리스트
  test_x = []

  # 검증 데이터의 정답 리스트
  test_y = []
  for i in tqdm(range(len(test_tmp))):
    # getNounAdjective 함수 써서 명사랑 형용사만 리턴
    noun_adjective = getNounAdjective(test_tmp[i][1])

    # None값이 아니면
    if noun_adjective is not None:

      # 리스트에 추가
      test_x.append(noun_adjective)

      # 0,1 ,값을 정수로 변환해서 저장
      test_y.append(int(train_tmp[i][2]))
  return (train_x, train_y), (test_x, test_y)

# %%
(X_train, y_train) , (X_test, y_test) = kor_movie()
# Out:
#   0%|          | 0/150000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
X_train

# %%
word2vector = Word2Vec(X_train, size = 20)

# %%
word2vector.wv.vocab
# Out:
# {'더빙': <gensim.models.keyedvectors.Vocab at 0x7fcc8babb8d0>,
#  '진짜': <gensim.models.keyedvectors.Vocab at 0x7fccbe742a90>,
#  '짜증나다': <gensim.models.keyedvectors.Vocab at 0x7fccbe742d90>,
#  '목소리': <gensim.models.keyedvectors.Vocab at 0x7fccbe742890>,
#  '': <gensim.models.keyedvectors.Vocab at 0x7fcc91dca990>,
#  '흠': <gensim.models.keyedvectors.Vocab at 0x7fcc9968c1d0>,
#  '포스터': <gensim.models.keyedvectors.Vocab at 0x7fcc9968cb90>,
#  '보고': <gensim.models.keyedvectors.Vocab at 0x7fcc9968c9d0>,
#  '초딩': <gensim.models.keyedvectors.Vocab at 0x7fcc91dcacd0>,
#  '영화': <gensim.models.keyedvectors.Vocab at 0x7fcc92574850>,
#  '줄': <gensim.models.keyedvectors.Vocab at 0x7fcc8ba51ed0>,
#  '오버': <gensim.models.keyedvectors.Vocab at 0x7fcc8ba51c10>,
#  '연기': <gensim.models.keyedvectors.Vocab at 0x7fcc8ba51f10>,
#  '가볍다': <gensim.models.keyedvectors.Vocab at 0x7fcc8ba51e90>,
#  '무재': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3edd0>,
#  '다그': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ef90>,
#  '래서': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3eb90>,
#  '추천': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3efd0>,
#  '교도소': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3eb50>,
#  '이야기': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ee50>,
#  '구먼': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ee90>,
#  '솔직하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ef50>,
#  '재미': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ef10>,
#  '없다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3eed0>,
#  '평점': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ec10>,
#  '조정': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ebd0>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ec90>,
#  '익살스럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ec50>,
#  '스파이더맨': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ea50>,
#  '이쁘다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ea10>,
#  '막': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ea90>,
#  '걸음': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ead0>,
#  '마': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3e9d0>,
#  '세': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3e990>,
#  '초등학교': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3eb10>,
#  '학년': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ecd0>,
#  '생인': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ed10>,
#  '반개': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ee10>,
#  '아깝다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f3ed90>,
#  '움': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17510>,
#  '원작': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17310>,
#  '긴장감': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17350>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x7fcc96f172d0>,
#  '별': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17250>,
#  '욕': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17190>,
#  '이응경': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17dd0>,
#  '생활': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17a90>,
#  '년': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17e50>,
#  '정말': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17c90>,
#  '발': <gensim.models.keyedvectors.Vocab at 0x7fcc96f17ad0>,
#  '해도': <gensim.models.keyedvectors.Vocab at 0x7fcc96f171d0>,
#  '그것': <gensim.models.keyedvectors.Vocab at 0x7fcc990de890>,
#  '납치': <gensim.models.keyedvectors.Vocab at 0x7fcc990def90>,
#  '감금': <gensim.models.keyedvectors.Vocab at 0x7fcc96ff1950>,
#  '반복': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0590>,
#  '드라마': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0250>,
#  '가족': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee05d0>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0d90>,
#  '네': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0210>,
#  '액션': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0050>,
#  '있다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0090>,
#  '몇': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0650>,
#  '안되다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0cd0>,
#  '왜케': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0f90>,
#  '낮다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0f50>,
#  '꽤': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0d50>,
#  '볼': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0fd0>,
#  '데': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0dd0>,
#  '헐리우드': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0e10>,
#  '화려하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0c90>,
#  '인피니트': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0e90>,
#  '짱': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0710>,
#  '볼때': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0e50>,
#  '향수': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0d10>,
#  '자극': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0410>,
#  '허진호': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0150>,
#  '감성': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0ad0>,
#  '절제': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee00d0>,
#  '멜로': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0b90>,
#  '달인': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee04d0>,
#  '울면': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0ed0>,
#  '손': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0f10>,
#  '때': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0b10>,
#  '뻔': <gensim.models.keyedvectors.Vocab at 0x7fcc96ee0110>,
#  '이범수': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2050>,
#  '드럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2090>,
#  '담백하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef20d0>,
#  '깔끔하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2110>,
#  '좋다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2150>,
#  '로만': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2190>,
#  '자꾸': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef21d0>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2210>,
#  '것': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2250>,
#  '취향': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2290>,
#  '존중': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef22d0>,
#  '다지': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2310>,
#  '내생': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2350>,
#  '극장': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2390>,
#  '가장': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef23d0>,
#  '노잼': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2410>,
#  '노': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2450>,
#  '감동': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2490>,
#  '임': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef24d0>,
#  '스토리': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2510>,
#  '어거지': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2550>,
#  '냥': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2590>,
#  '매번': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef25d0>,
#  '긴장': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2610>,
#  '재밋음': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2650>,
#  '바스코': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2690>,
#  '이기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef26d0>,
#  '락스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2710>,
#  '코': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2750>,
#  '바비': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2790>,
#  '아이돌': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef27d0>,
#  '그냥': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2810>,
#  '안달': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2850>,
#  '굿바이': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2890>,
#  '레닌': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef28d0>,
#  '표절': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2910>,
#  '이해': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2950>,
#  '왜': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2990>,
#  '뒤': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef29d0>,
#  '갈수록': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2a10>,
#  '이건': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2a50>,
#  '깨알': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2a90>,
#  '캐스팅': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2ad0>,
#  '산뜻하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2b10>,
#  '용구성': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2b50>,
#  '일드': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2b90>,
#  '위': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2bd0>,
#  '변명': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2c10>,
#  '놈': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2c50>,
#  '착하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2c90>,
#  '절대': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2cd0>,
#  '아니다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2d10>,
#  '걸': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2d50>,
#  '나름': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2d90>,
#  '심오하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2dd0>,
#  '뜻': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2e10>,
#  '듯': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2e50>,
#  '학생': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2e90>,
#  '선생': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2ed0>,
#  '재미없다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2f10>,
#  '지루하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2f50>,
#  '같다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2f90>,
#  '음식': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef2fd0>,
#  '도': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5050>,
#  '만찬': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5090>,
#  '별로': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5110>,
#  '핀란드': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5150>,
#  '풍경': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef50d0>,
#  '평범하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5190>,
#  '수작': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef51d0>,
#  '는걸': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5210>,
#  '주제': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5250>,
#  '중반': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5290>,
#  '납득': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef52d0>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5310>,
#  '그렇다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5350>,
#  '꼭': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef53d0>,
#  '카밀라': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5410>,
#  '벨': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5390>,
#  '발연기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5450>,
#  '센스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5490>,
#  '연출': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef54d0>,
#  '탁월하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5510>,
#  '점': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5550>,
#  '위력': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5590>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef55d0>,
#  '한번': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5610>,
#  '적': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5690>,
#  '남': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef56d0>,
#  '꽃': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5650>,
#  '검사': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5710>,
#  '완전': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5750>,
#  '명품': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5790>,
#  '졸': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef57d0>,
#  '쓰레기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5810>,
#  '진부하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5850>,
#  '도안': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5890>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef58d0>,
#  '재밌다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5910>,
#  '기대하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5990>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef59d0>,
#  '죄인': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5950>,
#  '이다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5a10>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5a50>,
#  '인생': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5a90>,
#  '최고': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5ad0>,
#  '패션': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5b10>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5b50>,
#  '열정': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5b90>,
#  '안나': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5bd0>,
#  '윈': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5c10>,
#  '투어': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5c90>,
#  '키이라': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5cd0>,
#  '나이틀리': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5c50>,
#  '대체': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5d10>,
#  '정신': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5d50>,
#  '유령': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5d90>,
#  '재미있다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5dd0>,
#  '관객': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5e10>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5e50>,
#  '평가': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5e90>,
#  '단순하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5ed0>,
#  '은은하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5f10>,
#  '매력': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5f90>,
#  '알바생': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5fd0>,
#  '내용': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef5f50>,
#  '무섭다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8050>,
#  '하나': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8090>,
#  '싱겁다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef80d0>,
#  '낚임': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8110>,
#  '맘': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8150>,
#  '또': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8190>,
#  '방법': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef81d0>,
#  '윤제문': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8210>,
#  '멋지다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8250>,
#  '배우': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8290>,
#  '발견': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef82d0>,
#  '소소하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8310>,
#  '탈': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8350>,
#  '잔잔하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8390>,
#  '미소': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef83d0>,
#  '머금': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8410>,
#  '음악': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8450>,
#  '조금': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8490>,
#  '아쉽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef84d0>,
#  '속지': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8510>,
#  '낭비': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8550>,
#  '돈': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8590>,
#  '리얼리티': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef85d0>,
#  '뛰어나다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8610>,
#  '공감': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8650>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8690>,
#  '간다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef86d0>,
#  '이민기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8710>,
#  '캐릭터': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8750>,
#  '분노조절': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8790>,
#  '장애': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef87d0>,
#  '초기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8810>,
#  '툭하면': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8850>,
#  '패': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8890>,
#  '물건': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef88d0>,
#  '바': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8910>,
#  '초반': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8950>,
#  '신선하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8990>,
#  '가면': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef89d0>,
#  '상태': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8a10>,
#  '불가': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8a50>,
#  '마이너스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8a90>,
#  '뮤비': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8ad0>,
#  '수준': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8b10>,
#  '알': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8b50>,
#  '북한': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8b90>,
#  '이렇다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8bd0>,
#  '난': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8c10>,
#  '우리': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8c50>,
#  '사랑': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8c90>,
#  '리스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8cd0>,
#  '타르': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8d10>,
#  '용의': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8d50>,
#  '주인': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8d90>,
#  '누': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8dd0>,
#  '근친상간': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8e10>,
#  '소설': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8e50>,
#  '속': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8e90>,
#  '제일': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8ed0>,
#  '자': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8f10>,
#  '메': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8f50>,
#  '니스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8f90>,
#  '터': <gensim.models.keyedvectors.Vocab at 0x7fcc96ef8fd0>,
#  '드래곤': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb050>,
#  '용': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb090>,
#  '웃음': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb0d0>,
#  '감독': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb110>,
#  '토르': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb150>,
#  '다크': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb190>,
#  '월드': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb1d0>,
#  '말': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb210>,
#  '기본': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb250>,
#  '영혼': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb290>,
#  '수도': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb2d0>,
#  '상사': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb310>,
#  '잠시': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb350>,
#  '동화': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb390>,
#  '행복하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb3d0>,
#  '세르게이': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb410>,
#  '작다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb450>,
#  '고추': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb490>,
#  '맵다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb4d0>,
#  '맛': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb510>,
#  '저그': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb550>,
#  '콩': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb590>,
#  '진호': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb5d0>,
#  '가슴': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb610>,
#  '시리': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb650>,
#  '자체': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb690>,
#  '난또': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb6d0>,
#  '저': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb710>,
#  '꼬마': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb750>,
#  '애가': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb790>,
#  '무슨': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb7d0>,
#  '원한': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb810>,
#  '깊다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb850>,
#  '혼자': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb890>,
#  '충격': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb8d0>,
#  '기분': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb910>,
#  '완전하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb950>,
#  '푹': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb990>,
#  '느낌': <gensim.models.keyedvectors.Vocab at 0x7fcc96efb9d0>,
#  '활': <gensim.models.keyedvectors.Vocab at 0x7fcc96efba10>,
#  '무겁다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efba50>,
#  '지독하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efba90>,
#  '차갑다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbad0>,
#  '무자비하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbb10>,
#  '일본인': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbb50>,
#  '상상력': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbb90>,
#  '대단하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbbd0>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbc10>,
#  '그대로': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbc50>,
#  '예측': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbc90>,
#  '카리스마': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbcd0>,
#  '악역': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbd10>,
#  '당황': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbd50>,
#  '중간': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbd90>,
#  '일상': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbdd0>,
#  '밋밋하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbe10>,
#  '계속': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbe50>,
#  '전개도': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbe90>,
#  '느리다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbed0>,
#  '주인공': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbf10>,
#  '은희': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbf50>,
#  '컷': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbf90>,
#  '극적': <gensim.models.keyedvectors.Vocab at 0x7fcc96efbfd0>,
#  '모습': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe050>,
#  '짜증': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe090>,
#  '언제': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe0d0>,
#  '대만': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe110>,
#  '전개': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe150>,
#  '좀': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe190>,
#  '가슴속': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe1d0>,
#  '감정': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe210>,
#  '많다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe250>,
#  '다큐': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe290>,
#  '우리나라': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe2d0>,
#  '슬프다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe310>,
#  '현대': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe350>,
#  '사의': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe390>,
#  '단면': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe3d0>,
#  '대해': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe410>,
#  '깊이': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe450>,
#  '사죄': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe490>,
#  '바로': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe4d0>,
#  '잡기': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe510>,
#  '위해': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe550>,
#  '노력': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe590>,
#  '말로': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe5d0>,
#  '보도': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe610>,
#  '민간인': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe650>,
#  '학살': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe690>,
#  '이정': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe6d0>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe710>,
#  '명백하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe750>,
#  '살인': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe790>,
#  '살인자': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe7d0>,
#  '어디': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe810>,
#  '예전': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe850>,
#  '작품': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe890>,
#  '에피소드': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe8d0>,
#  '재탕': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe910>,
#  '탕': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe950>,
#  '사골': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe990>,
#  '우려': <gensim.models.keyedvectors.Vocab at 0x7fcc96efe9d0>,
#  '먹듯': <gensim.models.keyedvectors.Vocab at 0x7fcc96efea10>,
#  '산': <gensim.models.keyedvectors.Vocab at 0x7fcc96efea50>,
#  '시청률': <gensim.models.keyedvectors.Vocab at 0x7fcc96efea90>,
#  '아예': <gensim.models.keyedvectors.Vocab at 0x7fcc96efead0>,
#  '이제': <gensim.models.keyedvectors.Vocab at 0x7fcc96efeb10>,
#  '부작': <gensim.models.keyedvectors.Vocab at 0x7fcc96efeb50>,
#  '김남길': <gensim.models.keyedvectors.Vocab at 0x7fcc96efeb90>,
#  '연기력': <gensim.models.keyedvectors.Vocab at 0x7fcc96efebd0>,
#  '몰입도': <gensim.models.keyedvectors.Vocab at 0x7fcc96efec10>,
#  '불구': <gensim.models.keyedvectors.Vocab at 0x7fcc96efec50>,
#  '손예진': <gensim.models.keyedvectors.Vocab at 0x7fcc96efec90>,
#  '비슷하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efecd0>,
#  '분': <gensim.models.keyedvectors.Vocab at 0x7fcc96efed10>,
#  '노래실력': <gensim.models.keyedvectors.Vocab at 0x7fcc96efed50>,
#  '박시환': <gensim.models.keyedvectors.Vocab at 0x7fcc96efed90>,
#  '망신': <gensim.models.keyedvectors.Vocab at 0x7fcc96efedd0>,
#  '일본': <gensim.models.keyedvectors.Vocab at 0x7fcc96efee10>,
#  '건가': <gensim.models.keyedvectors.Vocab at 0x7fcc96efee50>,
#  '유치하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96efee90>,
#  '이틀': <gensim.models.keyedvectors.Vocab at 0x7fcc96efeed0>,
#  '차': <gensim.models.keyedvectors.Vocab at 0x7fcc96efef10>,
#  '조작': <gensim.models.keyedvectors.Vocab at 0x7fcc96efef50>,
#  '안이': <gensim.models.keyedvectors.Vocab at 0x7fcc96efef90>,
#  '집': <gensim.models.keyedvectors.Vocab at 0x7fcc96efefd0>,
#  '활짝': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02050>,
#  '아무나': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02090>,
#  '문자': <gensim.models.keyedvectors.Vocab at 0x7fcc96f020d0>,
#  '건': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02110>,
#  '억지스럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02150>,
#  '재밋네': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02190>,
#  '달팽이': <gensim.models.keyedvectors.Vocab at 0x7fcc96f021d0>,
#  '빨': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02210>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02250>,
#  '어설프다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02290>,
#  '어이없다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f022d0>,
#  '결말': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02310>,
#  '부패하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02350>,
#  '기리': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02390>,
#  '뭣같': <gensim.models.keyedvectors.Vocab at 0x7fcc96f023d0>,
#  '온몸': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02410>,
#  '러시아': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02450>,
#  '민중': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02490>,
#  '폭도': <gensim.models.keyedvectors.Vocab at 0x7fcc96f024d0>,
#  '무난': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02510>,
#  '한국영': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02550>,
#  '흥행': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02590>,
#  '코드': <gensim.models.keyedvectors.Vocab at 0x7fcc96f025d0>,
#  '갈등': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02610>,
#  '계': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02650>,
#  '화해': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02690>,
#  '남발': <gensim.models.keyedvectors.Vocab at 0x7fcc96f026d0>,
#  '뻔하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02710>,
#  '뭐': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02750>,
#  '시작': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02790>,
#  '사진': <gensim.models.keyedvectors.Vocab at 0x7fcc96f027d0>,
#  '불안하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02810>,
#  '럼': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02850>,
#  '뭘': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02890>,
#  '엉망': <gensim.models.keyedvectors.Vocab at 0x7fcc96f028d0>,
#  '진창': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02910>,
#  '개': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02950>,
#  '우뢰매': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02990>,
#  '진정': <gensim.models.keyedvectors.Vocab at 0x7fcc96f029d0>,
#  '위대하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02a10>,
#  '조미': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02a50>,
#  '좋아하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02a90>,
#  '가요': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02ad0>,
#  '눈': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02b10>,
#  '성룡': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02b50>,
#  '최악': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02b90>,
#  '골': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02bd0>,
#  '인공': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02c10>,
#  '강추': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02c50>,
#  '클라라': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02c90>,
#  '볼라': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02cd0>,
#  '화신': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02d10>,
#  '설정': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02d50>,
#  '새롭다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02d90>,
#  '메인': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02dd0>,
#  '마코토': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02e10>,
#  '작화': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02e50>,
#  '밉다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02e90>,
#  '유': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02ed0>,
#  '대박': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02f10>,
#  '진심': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02f50>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02f90>,
#  '노골': <gensim.models.keyedvectors.Vocab at 0x7fcc96f02fd0>,
#  '술': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05050>,
#  '광고': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05090>,
#  '어떻다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f050d0>,
#  '행복': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05110>,
#  '요': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05150>,
#  '쫌': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05190>,
#  '산만하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f051d0>,
#  '처음': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05210>,
#  '불륜': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05250>,
#  '로맨스': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05290>,
#  '왕': <gensim.models.keyedvectors.Vocab at 0x7fcc96f052d0>,
#  '아주': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05310>,
#  '짬뽕': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05350>,
#  '믹스': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05390>,
#  '음향': <gensim.models.keyedvectors.Vocab at 0x7fcc96f053d0>,
#  '기준': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05410>,
#  '패널': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05450>,
#  '가구': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05490>,
#  '머': <gensim.models.keyedvectors.Vocab at 0x7fcc96f054d0>,
#  '명작': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05510>,
#  '망치': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05550>,
#  '서운하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05590>,
#  '몬스터': <gensim.models.keyedvectors.Vocab at 0x7fcc96f055d0>,
#  '주식회사': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05610>,
#  '소재': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05650>,
#  '흥미': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05690>,
#  '끌': <gensim.models.keyedvectors.Vocab at 0x7fcc96f056d0>,
#  '투': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05710>,
#  '박하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05750>,
#  '몰입': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05790>,
#  '중국인': <gensim.models.keyedvectors.Vocab at 0x7fcc96f057d0>,
#  '특유': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05810>,
#  '과장': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05850>,
#  '허풍': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05890>,
#  '가상하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f058d0>,
#  '고증': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05910>,
#  '실감': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05950>,
#  '거북': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05990>,
#  '스럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f059d0>,
#  '도대체': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05a10>,
#  '스스로': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05a50>,
#  '과대': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05a90>,
#  '포장': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05ad0>,
#  '불법체류자': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05b10>,
#  '미국': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05b50>,
#  '따뜻하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05b90>,
#  '뭥미': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05bd0>,
#  '삶속': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05c10>,
#  '생애': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05c50>,
#  '전부': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05c90>,
#  '지난': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05cd0>,
#  '후': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05d10>,
#  '지나': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05d50>,
#  '순수하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05d90>,
#  '숀펜': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05dd0>,
#  '또한': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05e10>,
#  '올레': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05e50>,
#  '공짜': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05e90>,
#  '문제': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05ed0>,
#  '연기자': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05f10>,
#  '전혀': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05f50>,
#  '배역': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05f90>,
#  '상대': <gensim.models.keyedvectors.Vocab at 0x7fcc96f05fd0>,
#  '보아': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89050>,
#  '라미란': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89090>,
#  '아들': <gensim.models.keyedvectors.Vocab at 0x7fcc96e890d0>,
#  '젤': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89110>,
#  '욕심': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89150>,
#  '쪽': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89190>,
#  '베댓': <gensim.models.keyedvectors.Vocab at 0x7fcc96e891d0>,
#  '도둑': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89210>,
#  '뫼비우스': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89250>,
#  '나라': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89290>,
#  '짜릿': <gensim.models.keyedvectors.Vocab at 0x7fcc96e892d0>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89310>,
#  '용기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89350>,
#  '교훈': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89390>,
#  '화이': <gensim.models.keyedvectors.Vocab at 0x7fcc96e893d0>,
#  '당시': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89410>,
#  '상황': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89450>,
#  '주입': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89490>,
#  '식이': <gensim.models.keyedvectors.Vocab at 0x7fcc96e894d0>,
#  '전하': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89510>,
#  '다르덴': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89550>,
#  '채': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89590>,
#  '그릇': <gensim.models.keyedvectors.Vocab at 0x7fcc96e895d0>,
#  '여군': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89610>,
#  '잼': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89650>,
#  '엠비씨': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89690>,
#  '한석규': <gensim.models.keyedvectors.Vocab at 0x7fcc96e896d0>,
#  '김혜수': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89710>,
#  '어딘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89750>,
#  '바이러스': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89790>,
#  '해': <gensim.models.keyedvectors.Vocab at 0x7fcc96e897d0>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89810>,
#  '년전': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89850>,
#  '보기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89890>,
#  '힘들다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e898d0>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89910>,
#  '마지막': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89950>,
#  '후반': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89990>,
#  '부가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e899d0>,
#  '살짝': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89a10>,
#  '용가리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89a50>,
#  '짱짱맨': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89a90>,
#  '감히': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89ad0>,
#  '하나로': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89b10>,
#  '꼽': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89b50>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89b90>,
#  '야하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89bd0>,
#  '고민': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89c10>,
#  '모건': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89c50>,
#  '프리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89c90>,
#  '멀다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89cd0>,
#  '나이': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89d10>,
#  '여전하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89d50>,
#  '섹시하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89d90>,
#  '작가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89dd0>,
#  '용이': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89e10>,
#  '기대': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89e50>,
#  '재방송': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89e90>,
#  '혹': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89ed0>,
#  '시나': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89f10>,
#  '답': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89f50>,
#  '여운': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89f90>,
#  '왠만하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e89fd0>,
#  '상업': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c050>,
#  '퀄리티': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c090>,
#  '질': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c0d0>,
#  '충분하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c110>,
#  '개인': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c150>,
#  '잔인하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c190>,
#  '노출씬': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c1d0>,
#  '화끈하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c210>,
#  '국산': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c250>,
#  '보임': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c290>,
#  '끝내': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c2d0>,
#  '지겹다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c310>,
#  '역시': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c350>,
#  '드니': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c390>,
#  '일품': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c3d0>,
#  '맥스': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c410>,
#  '샘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c450>,
#  '바랬다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c490>,
#  '괜찮다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c4d0>,
#  '실망': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c510>,
#  '지네': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c550>,
#  '면상': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c590>,
#  '자신': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c5d0>,
#  '어린이': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c610>,
#  '동심': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c650>,
#  '멀리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c690>,
#  '무술': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c6d0>,
#  '크리스토퍼': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c710>,
#  '왈츠': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c750>,
#  '타란티노': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c790>,
#  '조합': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c7d0>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c810>,
#  '유명': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c850>,
#  '한편': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c890>,
#  '외국': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c8d0>,
#  '상상': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c910>,
#  '초월': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c950>,
#  '유명하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c990>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8c9d0>,
#  '재밋': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ca10>,
#  '종방': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ca50>,
#  '오늘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ca90>,
#  '방도': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cad0>,
#  '방송': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cb10>,
#  '대본': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cb50>,
#  '완성': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cb90>,
#  '요즘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cbd0>,
#  '막장': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cc10>,
#  '수백향': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cc50>,
#  '심하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cc90>,
#  '화이팅': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ccd0>,
#  '조절': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cd10>,
#  '위원회': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cd50>,
#  '김혜선': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cd90>,
#  '내일': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cdd0>,
#  '김': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ce10>,
#  '순정': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ce50>,
#  '역할': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ce90>,
#  '팜므파탈': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8ced0>,
#  '로써': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cf10>,
#  '의외': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cf50>,
#  '사극': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cf90>,
#  '그녀': <gensim.models.keyedvectors.Vocab at 0x7fcc96e8cfd0>,
#  '논란': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90050>,
#  '코미디': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90090>,
#  '장면': <gensim.models.keyedvectors.Vocab at 0x7fcc96e900d0>,
#  '끝': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90110>,
#  '멍하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90150>,
#  '한마디': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90190>,
#  '상쾌': <gensim.models.keyedvectors.Vocab at 0x7fcc96e901d0>,
#  '발랄하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90210>,
#  '성': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90250>,
#  '유쾌하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90290>,
#  '해설': <gensim.models.keyedvectors.Vocab at 0x7fcc96e902d0>,
#  '소파': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90310>,
#  '죽': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90350>,
#  '이유': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90390>,
#  '타겟': <gensim.models.keyedvectors.Vocab at 0x7fcc96e903d0>,
#  '일반': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90410>,
#  '논리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90450>,
#  '통': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90490>,
#  '게임': <gensim.models.keyedvectors.Vocab at 0x7fcc96e904d0>,
#  '흥미롭다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90510>,
#  '요원': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90550>,
#  '무능력하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90590>,
#  '배경': <gensim.models.keyedvectors.Vocab at 0x7fcc96e905d0>,
#  '뮤지컬': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90610>,
#  '사운드': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90650>,
#  '녹음': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90690>,
#  '춤': <gensim.models.keyedvectors.Vocab at 0x7fcc96e906d0>,
#  '어제': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90710>,
#  '말리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90750>,
#  '영국': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90790>,
#  '예산': <gensim.models.keyedvectors.Vocab at 0x7fcc96e907d0>,
#  '뮤지컬영화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90810>,
#  '맘마미아': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90850>,
#  '로맨틱코미디': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90890>,
#  '머임': <gensim.models.keyedvectors.Vocab at 0x7fcc96e908d0>,
#  '알고싶다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90910>,
#  '스텝': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90950>,
#  '꼭두각시': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90990>,
#  '아름답다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e909d0>,
#  '현대인': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90a10>,
#  '힘드다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90a50>,
#  '뻑': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90a90>,
#  '볼걸': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90ad0>,
#  '당하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90b10>,
#  '극치': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90b50>,
#  '굉장하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90b90>,
#  '뚱뚱하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90bd0>,
#  '남자': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90c10>,
#  '애': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90c50>,
#  '시종일관': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90c90>,
#  '고역': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90cd0>,
#  '클래식': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90d10>,
#  '듣기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90d50>,
#  '싫다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90d90>,
#  '상당하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90dd0>,
#  '주기도': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90e10>,
#  '얼마나': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90e50>,
#  '죄송하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90e90>,
#  '화가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90ed0>,
#  '아무': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90f10>,
#  '보지': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90f50>,
#  '티비': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90f90>,
#  '판': <gensim.models.keyedvectors.Vocab at 0x7fcc96e90fd0>,
#  '거': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93050>,
#  '돼지': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93090>,
#  '피': <gensim.models.keyedvectors.Vocab at 0x7fcc96e930d0>,
#  '우웩': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93110>,
#  '무당': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93150>,
#  '잠': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93190>,
#  '류': <gensim.models.keyedvectors.Vocab at 0x7fcc96e931d0>,
#  '판타지': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93210>,
#  '복귀': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93250>,
#  '참가자': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93290>,
#  '실력': <gensim.models.keyedvectors.Vocab at 0x7fcc96e932d0>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93310>,
#  '심사': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93350>,
#  '위원': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93390>,
#  '인격': <gensim.models.keyedvectors.Vocab at 0x7fcc96e933d0>,
#  '어': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93410>,
#  '광장': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93450>,
#  '옛날': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93490>,
#  '생': <gensim.models.keyedvectors.Vocab at 0x7fcc96e934d0>,
#  '어린시절': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93510>,
#  '추억': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93550>,
#  '판타지영화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93590>,
#  '나쁘다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e935d0>,
#  '금물': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93610>,
#  '지옥': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93650>,
#  '기존': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93690>,
#  '멜로영화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e936d0>,
#  '형식': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93710>,
#  '탈피': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93750>,
#  '쏙': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93790>,
#  '후회': <gensim.models.keyedvectors.Vocab at 0x7fcc96e937d0>,
#  '이영화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93810>,
#  '보': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93850>,
#  '주네': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93890>,
#  '싸이코': <gensim.models.keyedvectors.Vocab at 0x7fcc96e938d0>,
#  '물': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93910>,
#  '개봉': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93950>,
#  '접해': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93990>,
#  '사랑스럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e939d0>,
#  '귀엽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93a10>,
#  '청춘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93a50>,
#  '넘치다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93a90>,
#  '순간': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93ad0>,
#  '무한': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93b10>,
#  '젊음': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93b50>,
#  '건담': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93b90>,
#  '시리즈': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93bd0>,
#  '중': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93c10>,
#  '최고봉': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93c50>,
#  '개콘': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93c90>,
#  '코너': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93cd0>,
#  '이안': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93d10>,
#  '사다코': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93d50>,
#  '서린': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93d90>,
#  '우물': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93dd0>,
#  '펀치': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93e10>,
#  '후세': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93e50>,
#  '결정': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93e90>,
#  '계기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93ed0>,
#  '표현': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93f10>,
#  '람': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93f50>,
#  '생명': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93f90>,
#  '등': <gensim.models.keyedvectors.Vocab at 0x7fcc96e93fd0>,
#  '출현': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97050>,
#  '연극': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97090>,
#  '로': <gensim.models.keyedvectors.Vocab at 0x7fcc96e970d0>,
#  '본능': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97110>,
#  '면서': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97150>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97190>,
#  '새벽': <gensim.models.keyedvectors.Vocab at 0x7fcc96e971d0>,
#  '졸작': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97210>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97250>,
#  '강수연': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97290>,
#  '신음': <gensim.models.keyedvectors.Vocab at 0x7fcc96e972d0>,
#  '신': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97310>,
#  '예쁘다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97350>,
#  '여정': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97390>,
#  '재밋어': <gensim.models.keyedvectors.Vocab at 0x7fcc96e973d0>,
#  '배두나': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97410>,
#  '성적': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97450>,
#  '호기심': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97490>,
#  '필요': <gensim.models.keyedvectors.Vocab at 0x7fcc96e974d0>,
#  '닥치고': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97510>,
#  '각기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97550>,
#  '다른': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97590>,
#  '파워': <gensim.models.keyedvectors.Vocab at 0x7fcc96e975d0>,
#  '미묘하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97610>,
#  '응답': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97650>,
#  '하라': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97690>,
#  '은지원': <gensim.models.keyedvectors.Vocab at 0x7fcc96e976d0>,
#  '웃기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97710>,
#  '배꼽': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97750>,
#  '컴': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97790>,
#  '구성': <gensim.models.keyedvectors.Vocab at 0x7fcc96e977d0>,
#  '부실하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97810>,
#  '네이버': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97850>,
#  '장끌': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97890>,
#  '로드': <gensim.models.keyedvectors.Vocab at 0x7fcc96e978d0>,
#  '몰락': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97910>,
#  '오우삼': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97950>,
#  '제적': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97990>,
#  '영웅본색': <gensim.models.keyedvectors.Vocab at 0x7fcc96e979d0>,
#  '현실': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97a10>,
#  '제로': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97a50>,
#  '설레다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97a90>,
#  '학창시절': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97ad0>,
#  '그때': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97b10>,
#  '대사': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97b50>,
#  '배경음악': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97b90>,
#  '높다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97bd0>,
#  '화남': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97c10>,
#  '더럽다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97c50>,
#  '형태': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97c90>,
#  '허무하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97cd0>,
#  '완벽하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97d10>,
#  '영양가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97d50>,
#  '이승기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97d90>,
#  '조연': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97dd0>,
#  '꿈': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97e10>,
#  '특집': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97e50>,
#  '프로': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97e90>,
#  '매우': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97ed0>,
#  '훌륭하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97f10>,
#  '미로': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97f50>,
#  '급': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97f90>,
#  '제대': <gensim.models.keyedvectors.Vocab at 0x7fcc96e97fd0>,
#  '마음': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a050>,
#  '휴가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a090>,
#  '소박하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a0d0>,
#  '햇살': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a110>,
#  '가득하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a150>,
#  '비': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a190>,
#  '이의': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a1d0>,
#  '요리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a210>,
#  '인상': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a250>,
#  '코믹': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a290>,
#  '짜임새': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a2d0>,
#  '신현준': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a310>,
#  '황': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a350>,
#  '장군': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a390>,
#  '음': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a3d0>,
#  '대가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a410>,
#  '일단': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a450>,
#  '재생': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a490>,
#  '괴물': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a4d0>,
#  '서스펜스': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a510>,
#  '귀신': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a550>,
#  '흡입': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a590>,
#  '댓글': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a5d0>,
#  '기': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a610>,
#  '게': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a650>,
#  '버킷리스트': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a690>,
#  '직전': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a6d0>,
#  '소원': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a710>,
#  '란': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a750>,
#  '발톱': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a790>,
#  '완존': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a7d0>,
#  '긍정': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a810>,
#  '역': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a850>,
#  '이그': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a890>,
#  '기도': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a8d0>,
#  '시원하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a910>,
#  '답답하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a950>,
#  '낼': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a990>,
#  '월요일': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9a9d0>,
#  '해피': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9aa10>,
#  '정치인': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9aa50>,
#  '모순': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9aa90>,
#  '어렵다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9aad0>,
#  '전쟁': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ab10>,
#  '묘사': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ab50>,
#  '주년': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ab90>,
#  '극장판': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9abd0>,
#  '재개': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ac10>,
#  '봉하': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ac50>,
#  '개그콘서트': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ac90>,
#  '전화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9acd0>,
#  '간': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ad10>,
#  '서양': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ad50>,
#  '두': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ad90>,
#  '푸하하하': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9add0>,
#  '세계': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ae10>,
#  '최초': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ae50>,
#  '반공': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ae90>,
#  '애니매이션': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9aed0>,
#  '역사': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9af10>,
#  '가치': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9af50>,
#  '감각': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9af90>,
#  '시각': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9afd0>,
#  '색다르다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e050>,
#  '문학': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e090>,
#  '엄마': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e0d0>,
#  '무고': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e110>,
#  '딸': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e150>,
#  '제발': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e190>,
#  '책': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e1d0>,
#  '미치다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e210>,
#  '날': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e250>,
#  '신나다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e290>,
#  '아이스': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e2d0>,
#  '큐브': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e310>,
#  '뿐': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e350>,
#  '건데': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e390>,
#  '생생하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e3d0>,
#  '이상하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e410>,
#  '옥소리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e450>,
#  '프로필': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e490>,
#  '아우': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e4d0>,
#  '짱짱': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e510>,
#  '시절': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e550>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e590>,
#  '이적': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e5d0>,
#  '액션영화': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e610>,
#  '범죄': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e650>,
#  '느와르': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e690>,
#  '영화롭다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e6d0>,
#  '실패': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e710>,
#  '작': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e750>,
#  '뭔가': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e790>,
#  '모녀': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e7d0>,
#  '토막': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e810>,
#  '살해': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e850>,
#  '부': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e890>,
#  '본인': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e8d0>,
#  '피해자': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e910>,
#  '필름': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e950>,
#  '값': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e990>,
#  '매미': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9e9d0>,
#  '드': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ea10>,
#  '안습': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ea50>,
#  '혀': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ea90>,
#  '짧다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ead0>,
#  '소리': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9eb10>,
#  '매니저': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9eb50>,
#  '역활': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9eb90>,
#  '훨': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ebd0>,
#  '적당하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ec10>,
#  '스릴러': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ec50>,
#  '스릴': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ec90>,
#  '이구': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ecd0>,
#  '전달': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ed10>,
#  '할머니': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ed50>,
#  '월': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ed90>,
#  '익숙하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9edd0>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ee10>,
#  '부족하다': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ee50>,
#  '쇼': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ee90>,
#  '기억': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9eed0>,
#  '이름': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ef10>,
#  '정은지': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ef50>,
#  '언니': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9ef90>,
#  '노래': <gensim.models.keyedvectors.Vocab at 0x7fcc96e9efd0>,
#  '회': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1050>,
#  '즐겁다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1090>,
#  '트로트': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea10d0>,
#  '연인': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1110>,
#  '아이': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1150>,
#  '시선': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1190>,
#  '내내': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea11d0>,
#  '레알': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1210>,
#  '함': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1250>,
#  '여자애': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1290>,
#  '복': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea12d0>,
#  '순이': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1310>,
#  '굳이': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1350>,
#  '어색': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1390>,
#  '연속극': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea13d0>,
#  '인터뷰': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1410>,
#  '킬링타임': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1450>,
#  '박스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1490>,
#  '오피스': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea14d0>,
#  '싸움': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1510>,
#  '다르다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1550>,
#  '여자': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1590>,
#  '기량': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea15d0>,
#  '울': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1610>,
#  '개연': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1650>,
#  '조디': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1690>,
#  '개막': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea16d0>,
#  '계시다': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1710>,
#  '당신': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1750>,
#  '호구': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1790>,
#  '두기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea17d0>,
#  '쌀': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1810>,
#  '세기': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1850>,
#  '명대사': <gensim.models.keyedvectors.Vocab at 0x7fcc96ea1890>,
#  ...}

# %%
word_vector_keys = word2vector.wv.vocab.keys()
word_vector_keys
# Out:
# dict_keys(['더빙', '진짜', '짜증나다', '목소리', '', '흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍다', '무재', '다그', '래서', '추천', '교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정', '의', '익살스럽다', '스파이더맨', '이쁘다', '막', '걸음', '마', '세', '초등학교', '학년', '생인', '반개', '아깝다', '움', '원작', '긴장감', '제대로', '별', '욕', '이응경', '생활', '년', '정말', '발', '해도', '그것', '납치', '감금', '반복', '드라마', '가족', '사람', '네', '액션', '있다', '몇', '안되다', '왜케', '낮다', '꽤', '볼', '데', '헐리우드', '화려하다', '인피니트', '짱', '볼때', '향수', '자극', '허진호', '감성', '절제', '멜로', '달인', '울면', '손', '때', '뻔', '이범수', '드럽다', '담백하다', '깔끔하다', '좋다', '로만', '자꾸', '그', '것', '취향', '존중', '다지', '내생', '극장', '가장', '노잼', '노', '감동', '임', '스토리', '어거지', '냥', '매번', '긴장', '재밋음', '바스코', '이기', '락스', '코', '바비', '아이돌', '그냥', '안달', '굿바이', '레닌', '표절', '이해', '왜', '뒤', '갈수록', '이건', '깨알', '캐스팅', '산뜻하다', '용구성', '일드', '위', '변명', '놈', '착하다', '절대', '아니다', '걸', '나름', '심오하다', '뜻', '듯', '학생', '선생', '재미없다', '지루하다', '같다', '음식', '도', '만찬', '별로', '핀란드', '풍경', '평범하다', '수작', '는걸', '주제', '중반', '납득', '수', '그렇다', '꼭', '카밀라', '벨', '발연기', '센스', '연출', '탁월하다', '점', '위력', '다시', '한번', '적', '남', '꽃', '검사', '완전', '명품', '졸', '쓰레기', '진부하다', '도안', '시간', '재밌다', '기대하다', '내', '죄인', '이다', '이', '인생', '최고', '패션', '대한', '열정', '안나', '윈', '투어', '키이라', '나이틀리', '대체', '정신', '유령', '재미있다', '관객', '명', '평가', '단순하다', '은은하다', '매력', '알바생', '내용', '무섭다', '하나', '싱겁다', '낚임', '맘', '또', '방법', '윤제문', '멋지다', '배우', '발견', '소소하다', '탈', '잔잔하다', '미소', '머금', '음악', '조금', '아쉽다', '속지', '낭비', '돈', '리얼리티', '뛰어나다', '공감', '안', '간다', '이민기', '캐릭터', '분노조절', '장애', '초기', '툭하면', '패', '물건', '바', '초반', '신선하다', '가면', '상태', '불가', '마이너스', '뮤비', '수준', '알', '북한', '이렇다', '난', '우리', '사랑', '리스', '타르', '용의', '주인', '누', '근친상간', '소설', '속', '제일', '자', '메', '니스', '터', '드래곤', '용', '웃음', '감독', '토르', '다크', '월드', '말', '기본', '영혼', '수도', '상사', '잠시', '동화', '행복하다', '세르게이', '작다', '고추', '맵다', '맛', '저그', '콩', '진호', '가슴', '시리', '자체', '난또', '저', '꼬마', '애가', '무슨', '원한', '깊다', '혼자', '충격', '기분', '완전하다', '푹', '느낌', '활', '무겁다', '지독하다', '차갑다', '무자비하다', '일본인', '상상력', '대단하다', '생각', '그대로', '예측', '카리스마', '악역', '당황', '중간', '일상', '밋밋하다', '계속', '전개도', '느리다', '주인공', '은희', '컷', '극적', '모습', '짜증', '언제', '대만', '전개', '좀', '가슴속', '감정', '많다', '다큐', '우리나라', '슬프다', '현대', '사의', '단면', '대해', '깊이', '사죄', '바로', '잡기', '위해', '노력', '말로', '보도', '민간인', '학살', '이정', '일', '명백하다', '살인', '살인자', '어디', '예전', '작품', '에피소드', '재탕', '탕', '사골', '우려', '먹듯', '산', '시청률', '아예', '이제', '부작', '김남길', '연기력', '몰입도', '불구', '손예진', '비슷하다', '분', '노래실력', '박시환', '망신', '일본', '건가', '유치하다', '이틀', '차', '조작', '안이', '집', '활짝', '아무나', '문자', '건', '억지스럽다', '재밋네', '달팽이', '빨', '더', '어설프다', '어이없다', '결말', '부패하다', '기리', '뭣같', '온몸', '러시아', '민중', '폭도', '무난', '한국영', '흥행', '코드', '갈등', '계', '화해', '남발', '뻔하다', '뭐', '시작', '사진', '불안하다', '럼', '뭘', '엉망', '진창', '개', '우뢰매', '진정', '위대하다', '조미', '좋아하다', '가요', '눈', '성룡', '최악', '골', '인공', '강추', '클라라', '볼라', '화신', '설정', '새롭다', '메인', '마코토', '작화', '밉다', '유', '대박', '진심', '못', '노골', '술', '광고', '어떻다', '행복', '요', '쫌', '산만하다', '처음', '불륜', '로맨스', '왕', '아주', '짬뽕', '믹스', '음향', '기준', '패널', '가구', '머', '명작', '망치', '서운하다', '몬스터', '주식회사', '소재', '흥미', '끌', '투', '박하다', '몰입', '중국인', '특유', '과장', '허풍', '가상하다', '고증', '실감', '거북', '스럽다', '도대체', '스스로', '과대', '포장', '불법체류자', '미국', '따뜻하다', '뭥미', '삶속', '생애', '전부', '지난', '후', '지나', '순수하다', '숀펜', '또한', '올레', '공짜', '문제', '연기자', '전혀', '배역', '상대', '보아', '라미란', '아들', '젤', '욕심', '쪽', '베댓', '도둑', '뫼비우스', '나라', '짜릿', '나', '용기', '교훈', '화이', '당시', '상황', '주입', '식이', '전하', '다르덴', '채', '그릇', '여군', '잼', '엠비씨', '한석규', '김혜수', '어딘', '바이러스', '해', '면', '년전', '보기', '힘들다', '정도', '마지막', '후반', '부가', '살짝', '용가리', '짱짱맨', '감히', '하나로', '꼽', '살', '야하다', '고민', '모건', '프리', '멀다', '나이', '여전하다', '섹시하다', '작가', '용이', '기대', '재방송', '혹', '시나', '답', '여운', '왠만하다', '상업', '퀄리티', '질', '충분하다', '개인', '잔인하다', '노출씬', '화끈하다', '국산', '보임', '끝내', '지겹다', '역시', '드니', '일품', '맥스', '샘', '바랬다', '괜찮다', '실망', '지네', '면상', '자신', '어린이', '동심', '멀리', '무술', '크리스토퍼', '왈츠', '타란티노', '조합', '한국', '유명', '한편', '외국', '상상', '초월', '유명하다', '만', '재밋', '종방', '오늘', '방도', '방송', '대본', '완성', '요즘', '막장', '수백향', '심하다', '화이팅', '조절', '위원회', '김혜선',  ...

# %%
# 영화와 비슷한 단어와 유사도
word2vector.wv.most_similar("영화")
# Out:
# [('영화로', 0.889551043510437),
#  ('애니메이션', 0.7982966899871826),
#  ('재난영화', 0.7862777709960938),
#  ('전쟁영화', 0.7797781229019165),
#  ('일본사람', 0.7719219326972961),
#  ('롤링', 0.7713843584060669),
#  ('액션영화', 0.7632489800453186),
#  ('다큐', 0.7630776166915894),
#  ('비디오영화', 0.7614374756813049),
#  ('연화', 0.7571612000465393)]

# %%
# 배우와 비슷한 단어와 유사도
word2vector.wv.most_similar("배우")
# Out:
# [('연기자', 0.9448115825653076),
#  ('조연', 0.8836774826049805),
#  ('배역', 0.8646745085716248),
#  ('진과', 0.8491079211235046),
#  ('외모', 0.8277369737625122),
#  ('주연', 0.8185327649116516),
#  ('개발', 0.8177402019500732),
#  ('송강호', 0.8169464468955994),
#  ('신인', 0.8157616853713989),
#  ('배우진', 0.8092398643493652)]

# %%
# 영화의 벡터값
word2vector['영화']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([ 2.9870124e+00, -5.0440139e-01,  3.6639923e-01,  1.4068604e+00,
#        -2.4765465e+00,  1.1199456e+00,  4.9149400e-01, -1.1885792e-03,
#        -3.1621959e+00,  4.2544193e+00,  1.6605721e-01, -7.9890746e-01,
#        -7.2618979e-01,  8.6117029e-01, -4.9819517e+00, -2.9227027e-01,
#        -2.8989666e+00, -2.0066266e-01,  1.7274566e+00, -1.5639291e+00],
#       dtype=float32)

# %%
print("영화" in word_vector_keys)

# 빈도수가 최소 5여야하는데 아닌 경우는 벡터값 안찾아줌
print("밓었" in word_vector_keys)
# Out:
# True
# False

# %%
# 학습할때 "영화"라는 단어를 학습 못함 따라서 위와 같은 벡터값으로 변경
for index in range(3):
    print("X_train[{}]={}".format(index, X_train[index]))
    for word in X_train[index]:
        print("word=",word)
        if word in word_vector_keys:
            print("word2vector[{}]={}".format(word, word2vector[word]))
        else:
            print("word2vector['']={}".format(word2vector['']))

        print("*"*100)
        
    print("="*100)
# Out:
# X_train[0]=['더빙', '진짜', '짜증나다', '목소리', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# word= 더빙
# word2vector[더빙]=[-0.9693797   1.3657986   3.2104177  -1.3626442  -0.87579054  2.490588
#  -0.89543176 -3.0370746  -1.9731306   1.1572696   0.69912    -2.5723429
#   1.0157431  -1.3525244  -2.4263432  -2.326604    2.7599125  -0.33703858
#   1.8072277  -0.59209013]
# ****************************************************************************************************
# word= 진짜
# word2vector[진짜]=[ 2.8361839e-01 -2.4064088e-01  1.3616796e+00 -3.9816496e-01
#  -1.7294580e+00  4.1059456e+00 -1.9039174e+00 -2.9861531e+00
#  -2.3257107e-01 -7.2961114e-04 -1.5945076e+00 -3.1590500e+00
#   1.0896116e+00 -1.5457357e+00 -4.7104836e+00  2.9972785e+00
#   1.2170788e-01 -4.3172574e-01  2.1163130e+00  2.7623949e+00]
# ****************************************************************************************************
# word= 짜증나다
# word2vector[짜증나다]=[-0.2872931   0.6276337   2.0338757  -0.02333199 -0.7032464   1.0595409
#  -0.605759   -4.3611674  -2.7880793  -0.8298785  -2.3916886  -3.4828205
#  -1.7561741  -0.08234203 -0.23371905 -1.4477612   1.7662683   0.20144866
#  -0.2542645   3.3423553 ]
# ****************************************************************************************************
# word= 목소리
# word2vector[목소리]=[ 0.9127096   0.91352254  3.9357426  -0.7075404   0.6420449   1.3272396
#  -0.46037784 -0.7056909  -0.6748232   0.57452166 -1.1212786  -2.0697043
#   1.3797566  -0.97007835 -0.5923544  -1.7002403   0.9616765  -0.89484775
#   0.9272278   1.6078603 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# ====================================================================================================
# X_train[1]=['흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍다', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# word= 흠
# word2vector[흠]=[ 1.2222049  -0.2897579  -0.05740624 -0.29926705  0.16221023  0.8343199
#  -0.94122    -0.8062333  -1.6376998   0.9808002   0.509669   -0.9043161
#  -0.13688006 -0.71734875 -1.1779405  -1.256158    0.21565256 -0.846306
#   1.0932461   0.89846665]
# ****************************************************************************************************
# word= 포스터
# word2vector[포스터]=[ 1.1582274  -0.34171435  0.64788985 -1.4589615  -0.0288794   1.8629034
#  -0.24732912 -1.8429097  -1.2715446   1.2141058  -0.40563422 -2.1567302
#  -0.2350306  -0.2069016  -2.4644728   0.0497417   0.9542233  -0.4151273
#   2.1394992   0.0696968 ]
# ****************************************************************************************************
# word= 보고
# word2vector[보고]=[ 2.3305414  -1.3734157   1.4689603  -1.9862648  -0.58127254  2.6598303
#  -0.9050224  -3.8408313  -4.45639    -0.97300637  0.32878256 -1.5249891
#  -0.31049928  0.859332   -0.77932376  4.7340407  -1.8293942   0.15188506
#   2.4281552  -0.4668368 ]
# ****************************************************************************************************
# word= 초딩
# word2vector[초딩]=[-0.81743336  0.0116549   0.5554993  -2.1593792  -0.23358166  1.4947544
#  -0.82678694 -3.0590022  -1.1365514   0.54150414 -0.34761202 -2.1869023
#  -1.5427027  -0.4668926  -2.1859694   0.40812287 -0.27602792  0.3347419
#   1.7498238  -0.8328438 ]
# ****************************************************************************************************
# word= 영화
# word2vector[영화]=[ 2.9870124e+00 -5.0440139e-01  3.6639923e-01  1.4068604e+00
#  -2.4765465e+00  1.1199456e+00  4.9149400e-01 -1.1885792e-03
#  -3.1621959e+00  4.2544193e+00  1.6605721e-01 -7.9890746e-01
#  -7.2618979e-01  8.6117029e-01 -4.9819517e+00 -2.9227027e-01
#  -2.8989666e+00 -2.0066266e-01  1.7274566e+00 -1.5639291e+00]
# ****************************************************************************************************
# word= 줄
# word2vector[줄]=[ 1.4935899  -0.24119422 -0.7637323  -1.3919429  -0.21414739 -0.31663823
#  -0.85495365 -3.6340795  -1.7234638   1.70244     1.6674337  -2.8102162
#  -0.57744056 -1.0631056  -0.7810219  -0.7644149  -0.95364875  1.1595067
#   1.4931984  -1.0663582 ]
# ****************************************************************************************************
# word= 오버
# word2vector[오버]=[ 1.6851171   0.49717623  0.52647924  0.13519235  0.08182742  1.0596017
#   0.2814893  -0.962291   -0.53787184  0.61647594 -0.24555731 -1.5573515
#   0.6133927  -1.3591268  -0.66970116 -1.1833804  -0.12478281 -0.8598882
#   1.0362785   1.3684794 ]
# ****************************************************************************************************
# word= 연기
# word2vector[연기]=[ 1.7703     -0.77490646  5.4549804  -0.41128698 -0.6057659   0.77830887
#   0.30144227 -1.0114199  -1.2810032   5.220254   -2.609849   -0.7724824
#   5.896      -0.6816706   0.87613434 -4.427186   -1.3167623   2.2799006
#   1.1348017   3.2245228 ]
# ****************************************************************************************************
# word= 가볍다
# word2vector[가볍다]=[ 3.5631573   0.527025    0.14150068 -0.5434429   0.9807079   0.66902673
#   0.2637481  -0.49337012 -1.51848     0.91772395  1.476288   -3.0720782
#   0.5589692  -0.06105173 -1.4933897  -0.23861414 -1.9099822  -0.94255686
#   0.86348665  0.84010375]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# ====================================================================================================
# X_train[2]=['무재', '밓었', '다그', '래서', '추천', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# word= 무재
# word2vector[무재]=[ 0.22064693  0.37090674  1.2808831  -1.0413829  -0.17038056  0.8851487
#  -0.6348577  -0.3103088  -0.43537083 -0.1707707  -0.8049095  -0.6658352
#  -0.04173113 -0.77202547 -0.499085    0.20420389 -0.8824727  -0.11693107
#   0.39032477  1.091848  ]
# ****************************************************************************************************
# word= 밓었
# word2vector['']=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word= 다그
# word2vector[다그]=[ 0.44187874  0.2391669   0.23347148 -0.20253265 -0.1486523   0.40504068
#  -0.05870429 -0.16524841 -0.24173543  0.39280137 -0.20743588 -0.31076503
#  -0.12861827 -0.4121177  -0.28525952  0.00402703 -0.32053876 -0.06853625
#   0.3019053   0.22263706]
# ****************************************************************************************************
# word= 래서
# word2vector[래서]=[ 0.12114698 -0.10622156  0.25690964 -0.2554277   0.07286263  0.33917683
#   0.02865642 -0.25514725 -0.40510154  0.32587647  0.10701986 -0.45926458
#  -0.39557695 -0.41107306 -0.3611345   0.18285707 -0.25685468  0.13113202
#   0.3585468   0.1812706 ]
# ****************************************************************************************************
# word= 추천
# word2vector[추천]=[ 1.038451   -0.01060033  1.3342866  -2.1820679   2.2935054   0.36068296
#  -1.6562076  -1.7909487  -0.9102645   1.1816512   0.9447585  -2.1242378
#  -1.5362124   0.644846   -0.70135725  3.1973898  -2.194282   -1.6742831
#   2.4147093   0.44312188]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# word=
# word2vector[]=[ 0.7995605   0.13340706 -0.1807313  -0.93127596  1.1055499   2.0073955
#   0.25752684  0.42016193 -1.2064086   0.57442605  0.18000641 -0.21277471
#  -0.00219649 -1.1856656  -1.6287998   1.0619525   0.23512098 -0.28200266
#   1.1603652   1.8240999 ]
# ****************************************************************************************************
# ====================================================================================================

# %%
X_train_vector=[]
for index in tqdm(range(len(X_train))):
    input =[]

    for word in X_train[index]:
        # print("word = ", word)
        if word in word_vector_keys:
            input.append(word2vector[word].tolist())
        else:
            input.append(word2vector[""].tolist())
    
    # print("input=",input)
    X_train_vector.append(input)
# Out:
#   0%|          | 0/125008 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# 타입 변경
X_train_vector = np.array(X_train_vector, dtype="float32")

# %%
X_train_vector[0].shape
# Out:
# (40, 20)

# %%
# 모델 
model = Sequential()

# input_shape (단어 갯수(40단어) , 단어 당 칸수(20칸, 단어 벡터))
model.add(LSTM(units = 128, input_shape=(40, 20)))

#
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               76288
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 76,417
# Trainable params: 76,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = np.array(y_train, dtype = np.float32)

# %%
model.compile(
               loss="binary_crossentropy",
               optimizer=Adam(lr=1e-3),
               metrics=["acc"]
              )
model.fit(X_train_vector, y_train, batch_size =1000, epochs = 100 )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 126/126 [==============================] - 73s 547ms/step - loss: 0.5203 - acc: 0.7317
# Epoch 2/100
#  81/126 [==================>...........] - ETA: 24s - loss: 0.4617 - acc: 0.7856

# %% [markdown]
# # 실습

# %% [markdown]
# ## WordVector를 이용한 네이버 영화평 감정 분석
# - 194~218

# %% [markdown]
# 단계
# 1. 데이터 로드 : read_data() 함수
# 2. 태깅 품사 중 명사랑 형용사만 리스트에 추가 하는 함수 : getNounAdjective
# 3. 전체 데이터 40개씩 품사 태깅하고 (X_train)리스트에 추가
# 4. X_train을 벡터로 변환하기위해 빈도수 체크하고 디폴트값(5) 5번 이상 나온것들만 리스트에 추가, 5이하인것들은 공백으로 처리
# 5. 모델 학습

# %%
# !pip install konlpy

# %%
from konlpy.tag import Twitter
from tqdm.notebook import tqdm
from gensim.models import Word2Vec
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# %%
train_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_train.txt'
test_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_test.txt'

# %%
def read_data(filename):
  with open(filename, 'r', encoding = 'utf-8') as f:
    # 한문장씩 끊어서 탭 기준으로 분리해서 리스트에 추가
    result = [line.split('\t') for line in f.read().splitlines()]

    # 칸 이름 뺴고 저장
    result = result[1:]
  return result

# %%
train_tmp = read_data(train_path)
test_tmp = read_data(test_path)

# %%
train_tmp[0:10]
# Out:
# [['9976970', '아 더빙.. 진짜 짜증나네요 목소리', '0'],
#  ['3819312', '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나', '1'],
#  ['10265843', '너무재밓었다그래서보는것을추천한다', '0'],
#  ['9045019', '교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정', '0'],
#  ['6483659',
#   '사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 던스트가 너무나도 이뻐보였다',
#   '1'],
#  ['5403919', '막 걸음마 뗀 3세부터 초등학교 1학년생인 8살용영화.ㅋㅋㅋ...별반개도 아까움.', '0'],
#  ['7797314', '원작의 긴장감을 제대로 살려내지못했다.', '0'],
#  ['9443947',
#   '별 반개도 아깝다 욕나온다 이응경 길용우 연기생활이몇년인지..정말 발로해도 그것보단 낫겟다 납치.감금만반복반복..이드라마는 가족도없다 연기못하는사람만모엿네',
#   '0'],
#  ['7156791', '액션이 없는데도 재미 있는 몇안되는 영화', '1'],
#  ['5912145', '왜케 평점이 낮은건데? 꽤 볼만한데.. 헐리우드식 화려함에만 너무 길들여져 있나?', '1']]

# %%
# 함수화
twitter = Twitter()

def getNounAdjective(text):
  # 단어 40개 추가할 리스트
  stems = [""] * 40

  # 인덱스 설정 , 40개 리스트의 마지막 인덱스는 39
  stems_last_index = (len(stems) - 1)

  stems_index = 0
  
  # 문장 품사 태깅
  tagged = twitter.pos(text, stem = True)

  for i in range(0, len(tagged)):
    # 명사나 형용사면 단어 추가
    if (tagged[i][1] == 'Noun') or (tagged[i][1] == 'Adjective'):
      stems[stems_index] = tagged[i][0]
      stems_index +=1

    # 단어 40개 다 추가했으면 멈춤
    if stems_index == stems_last_index:
        break

  # 명사나 형용사가 1개면 리턴 안받기
  if stems_index > 2:
    return stems
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
getNounAdjective(train_tmp[0][1])
# Out:
# ['더빙',
#  '진짜',
#  '짜증나다',
#  '목소리',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
train_tmp[1][1]
# Out:
# '흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나'

# %%
getNounAdjective(train_tmp[1][1])
# Out:
# ['흠',
#  '포스터',
#  '보고',
#  '초딩',
#  '영화',
#  '줄',
#  '오버',
#  '연기',
#  '가볍다',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
def kor_movie():

  # 학습 데이터로 사용할 리뷰데이터 저장 리스트
  train_x = []

  # 정답 데이터로 사용할 0,1 을 저장 리스트
  train_y = []
  for i in tqdm(range(len(train_tmp))):
    
    # getNounAdjective 함수 써서 명사랑 형용사만 리턴
    noun_adjective = getNounAdjective(train_tmp[i][1])

    # None값이 아니면
    if noun_adjective is not None:

      # 리스트에 추가
      train_x.append(noun_adjective)

      # 0,1 ,값을 정수로 변환해서 저장
      train_y.append(int(train_tmp[i][2]))

  # 검증 데이터로 사용할 리뷰데이터 저장 리스트
  test_x = []

  # 검증 데이터의 정답 리스트
  test_y = []
  for i in tqdm(range(len(test_tmp))):
    # getNounAdjective 함수 써서 명사랑 형용사만 리턴
    noun_adjective = getNounAdjective(test_tmp[i][1])

    # None값이 아니면
    if noun_adjective is not None:

      # 리스트에 추가
      test_x.append(noun_adjective)

      # 0,1 ,값을 정수로 변환해서 저장
      test_y.append(int(train_tmp[i][2]))
  return (train_x, train_y), (test_x, test_y)

# %%
(X_train, y_train) , (X_test, y_test) = kor_movie()
# Out:
#   0%|          | 0/150000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
X_train[1]
# Out:
# ['흠',
#  '포스터',
#  '보고',
#  '초딩',
#  '영화',
#  '줄',
#  '오버',
#  '연기',
#  '가볍다',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
del train_tmp
del test_tmp

# %%
# X_train 단어를 워드 벡터로 변환
# size = 20 , 20 개 칸수
word2vector = Word2Vec(X_train, size =20)

# 워드벡터 계산할때 사용한 변수들을 메모리에서삭제
word2vector.init_sims(replace = True)

# %%
# word2vector에 저장된 단어들을 딕셔너리 객체로 리턴후 키값 리턴
word_vector_keys =  word2vector.wv.vocab.keys()
word_vector_keys
# Out:
# dict_keys(['더빙', '진짜', '짜증나다', '목소리', '', '흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍다', '무재', '다그', '래서', '추천', '교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정', '의', '익살스럽다', '스파이더맨', '이쁘다', '막', '걸음', '마', '세', '초등학교', '학년', '생인', '반개', '아깝다', '움', '원작', '긴장감', '제대로', '별', '욕', '이응경', '생활', '년', '정말', '발', '해도', '그것', '납치', '감금', '반복', '드라마', '가족', '사람', '네', '액션', '있다', '몇', '안되다', '왜케', '낮다', '꽤', '볼', '데', '헐리우드', '화려하다', '인피니트', '짱', '볼때', '향수', '자극', '허진호', '감성', '절제', '멜로', '달인', '울면', '손', '때', '뻔', '이범수', '드럽다', '담백하다', '깔끔하다', '좋다', '로만', '자꾸', '그', '것', '취향', '존중', '다지', '내생', '극장', '가장', '노잼', '노', '감동', '임', '스토리', '어거지', '냥', '매번', '긴장', '재밋음', '바스코', '이기', '락스', '코', '바비', '아이돌', '그냥', '안달', '굿바이', '레닌', '표절', '이해', '왜', '뒤', '갈수록', '이건', '깨알', '캐스팅', '산뜻하다', '용구성', '일드', '위', '변명', '놈', '착하다', '절대', '아니다', '걸', '나름', '심오하다', '뜻', '듯', '학생', '선생', '재미없다', '지루하다', '같다', '음식', '도', '만찬', '별로', '핀란드', '풍경', '평범하다', '수작', '는걸', '주제', '중반', '납득', '수', '그렇다', '꼭', '카밀라', '벨', '발연기', '센스', '연출', '탁월하다', '점', '위력', '다시', '한번', '적', '남', '꽃', '검사', '완전', '명품', '졸', '쓰레기', '진부하다', '도안', '시간', '재밌다', '기대하다', '내', '죄인', '이다', '이', '인생', '최고', '패션', '대한', '열정', '안나', '윈', '투어', '키이라', '나이틀리', '대체', '정신', '유령', '재미있다', '관객', '명', '평가', '단순하다', '은은하다', '매력', '알바생', '내용', '무섭다', '하나', '싱겁다', '낚임', '맘', '또', '방법', '윤제문', '멋지다', '배우', '발견', '소소하다', '탈', '잔잔하다', '미소', '머금', '음악', '조금', '아쉽다', '속지', '낭비', '돈', '리얼리티', '뛰어나다', '공감', '안', '간다', '이민기', '캐릭터', '분노조절', '장애', '초기', '툭하면', '패', '물건', '바', '초반', '신선하다', '가면', '상태', '불가', '마이너스', '뮤비', '수준', '알', '북한', '이렇다', '난', '우리', '사랑', '리스', '타르', '용의', '주인', '누', '근친상간', '소설', '속', '제일', '자', '메', '니스', '터', '드래곤', '용', '웃음', '감독', '토르', '다크', '월드', '말', '기본', '영혼', '수도', '상사', '잠시', '동화', '행복하다', '세르게이', '작다', '고추', '맵다', '맛', '저그', '콩', '진호', '가슴', '시리', '자체', '난또', '저', '꼬마', '애가', '무슨', '원한', '깊다', '혼자', '충격', '기분', '완전하다', '푹', '느낌', '활', '무겁다', '지독하다', '차갑다', '무자비하다', '일본인', '상상력', '대단하다', '생각', '그대로', '예측', '카리스마', '악역', '당황', '중간', '일상', '밋밋하다', '계속', '전개도', '느리다', '주인공', '은희', '컷', '극적', '모습', '짜증', '언제', '대만', '전개', '좀', '가슴속', '감정', '많다', '다큐', '우리나라', '슬프다', '현대', '사의', '단면', '대해', '깊이', '사죄', '바로', '잡기', '위해', '노력', '말로', '보도', '민간인', '학살', '이정', '일', '명백하다', '살인', '살인자', '어디', '예전', '작품', '에피소드', '재탕', '탕', '사골', '우려', '먹듯', '산', '시청률', '아예', '이제', '부작', '김남길', '연기력', '몰입도', '불구', '손예진', '비슷하다', '분', '노래실력', '박시환', '망신', '일본', '건가', '유치하다', '이틀', '차', '조작', '안이', '집', '활짝', '아무나', '문자', '건', '억지스럽다', '재밋네', '달팽이', '빨', '더', '어설프다', '어이없다', '결말', '부패하다', '기리', '뭣같', '온몸', '러시아', '민중', '폭도', '무난', '한국영', '흥행', '코드', '갈등', '계', '화해', '남발', '뻔하다', '뭐', '시작', '사진', '불안하다', '럼', '뭘', '엉망', '진창', '개', '우뢰매', '진정', '위대하다', '조미', '좋아하다', '가요', '눈', '성룡', '최악', '골', '인공', '강추', '클라라', '볼라', '화신', '설정', '새롭다', '메인', '마코토', '작화', '밉다', '유', '대박', '진심', '못', '노골', '술', '광고', '어떻다', '행복', '요', '쫌', '산만하다', '처음', '불륜', '로맨스', '왕', '아주', '짬뽕', '믹스', '음향', '기준', '패널', '가구', '머', '명작', '망치', '서운하다', '몬스터', '주식회사', '소재', '흥미', '끌', '투', '박하다', '몰입', '중국인', '특유', '과장', '허풍', '가상하다', '고증', '실감', '거북', '스럽다', '도대체', '스스로', '과대', '포장', '불법체류자', '미국', '따뜻하다', '뭥미', '삶속', '생애', '전부', '지난', '후', '지나', '순수하다', '숀펜', '또한', '올레', '공짜', '문제', '연기자', '전혀', '배역', '상대', '보아', '라미란', '아들', '젤', '욕심', '쪽', '베댓', '도둑', '뫼비우스', '나라', '짜릿', '나', '용기', '교훈', '화이', '당시', '상황', '주입', '식이', '전하', '다르덴', '채', '그릇', '여군', '잼', '엠비씨', '한석규', '김혜수', '어딘', '바이러스', '해', '면', '년전', '보기', '힘들다', '정도', '마지막', '후반', '부가', '살짝', '용가리', '짱짱맨', '감히', '하나로', '꼽', '살', '야하다', '고민', '모건', '프리', '멀다', '나이', '여전하다', '섹시하다', '작가', '용이', '기대', '재방송', '혹', '시나', '답', '여운', '왠만하다', '상업', '퀄리티', '질', '충분하다', '개인', '잔인하다', '노출씬', '화끈하다', '국산', '보임', '끝내', '지겹다', '역시', '드니', '일품', '맥스', '샘', '바랬다', '괜찮다', '실망', '지네', '면상', '자신', '어린이', '동심', '멀리', '무술', '크리스토퍼', '왈츠', '타란티노', '조합', '한국', '유명', '한편', '외국', '상상', '초월', '유명하다', '만', '재밋', '종방', '오늘', '방도', '방송', '대본', '완성', '요즘', '막장', '수백향', '심하다', '화이팅', '조절', '위원회', '김혜선',  ...

# %%
# X_train 문자열을 word2vector로 변환해서 저장할 배열
X_train_vector = []

for index in tqdm(range(len(X_train))):
    input = []

    for word in X_train[index]:
        # X_train의 단어가 word_vector_keys에 있으면 추가
        # 없는 경우는 빈도수가 낮은 경우 없음
        if word in word_vector_keys:
         input.append(word2vector[word].tolist())
        else:
         input.append(word2vector[""].tolist())
    
    X_train_vector.append(input)

# 타입 변환
X_train_vector = np.array(X_train_vector, dtype = np.float32)

# 삭제
del X_train
# Out:
#   0%|          | 0/125008 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]

# %%
# X_train 문자열을 word2vector로 변환해서 저장할 배열
X_test_vector = []

for index in tqdm(range(len(X_test))):
    input = []

    for word in X_test[index]:
        # X_train의 단어가 word_vector_keys에 있으면 추가
        # 없는 경우는 빈도수가 낮은 경우 없음
        if word in word_vector_keys:
         input.append(word2vector[word].tolist())
        else:
         input.append(word2vector[""].tolist())
    
    X_test_vector.append(input)

# 타입 변환
X_test_vector = np.array(X_test_vector, dtype = np.float32)

# 삭제
del X_test
# Out:
#   0%|          | 0/41727 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]

# %%
# 모델 
model = Sequential()

# input_shape (단어 갯수(40단어) , 단어 당 칸수(20칸, 단어 벡터))
model.add(LSTM(units = 128, input_shape=(40, 20)))

#
model.add(Dense(1, activation="sigmoid"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 128)               76288
# _________________________________________________________________
# dense (Dense)                (None, 1)                 129
# =================================================================
# Total params: 76,417
# Trainable params: 76,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
y_train = np.array(y_train, dtype = np.float32)
y_test = np.array(y_test, dtype = np.float32)

# %%
model.compile(
               loss="binary_crossentropy",
               optimizer=Adam(lr=1e-3),
               metrics=["acc"]
              )
model.fit(X_train_vector, y_train, batch_size =1000, epochs = 100 )
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/100
# 126/126 [==============================] - 13s 34ms/step - loss: 0.5420 - acc: 0.6970
# Epoch 2/100
# 126/126 [==============================] - 5s 33ms/step - loss: 0.4439 - acc: 0.7947
# Epoch 3/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4424 - acc: 0.7953
# Epoch 4/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4411 - acc: 0.7946
# Epoch 5/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4402 - acc: 0.7962
# Epoch 6/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4355 - acc: 0.7984
# Epoch 7/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4294 - acc: 0.8013
# Epoch 8/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.4284 - acc: 0.8007
# Epoch 9/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4296 - acc: 0.8009
# Epoch 10/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4211 - acc: 0.8050
# Epoch 11/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4215 - acc: 0.8048
# Epoch 12/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4259 - acc: 0.8019
# Epoch 13/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.4289 - acc: 0.8018
# Epoch 14/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4173 - acc: 0.8080
# Epoch 15/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4129 - acc: 0.8098
# Epoch 16/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4402 - acc: 0.7965
# Epoch 17/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4142 - acc: 0.8090
# Epoch 18/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4152 - acc: 0.8079
# Epoch 19/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4121 - acc: 0.8102
# Epoch 20/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4081 - acc: 0.8119
# Epoch 21/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4082 - acc: 0.8119
# Epoch 22/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4058 - acc: 0.8131
# Epoch 23/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4051 - acc: 0.8142
# Epoch 24/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4059 - acc: 0.8133
# Epoch 25/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4052 - acc: 0.8143
# Epoch 26/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4069 - acc: 0.8122
# Epoch 27/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4039 - acc: 0.8134
# Epoch 28/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4091 - acc: 0.8125
# Epoch 29/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4031 - acc: 0.8139
# Epoch 30/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4013 - acc: 0.8154
# Epoch 31/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4018 - acc: 0.8149
# Epoch 32/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3993 - acc: 0.8166
# Epoch 33/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3976 - acc: 0.8183
# Epoch 34/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3973 - acc: 0.8169
# Epoch 35/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3998 - acc: 0.8175
# Epoch 36/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3996 - acc: 0.8160
# Epoch 37/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3979 - acc: 0.8168
# Epoch 38/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4001 - acc: 0.8159
# Epoch 39/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3942 - acc: 0.8191
# Epoch 40/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3984 - acc: 0.8161
# Epoch 41/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3982 - acc: 0.8165
# Epoch 42/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3930 - acc: 0.8198
# Epoch 43/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3919 - acc: 0.8201
# Epoch 44/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3942 - acc: 0.8202
# Epoch 45/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3971 - acc: 0.8171
# Epoch 46/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3898 - acc: 0.8211
# Epoch 47/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3943 - acc: 0.8186
# Epoch 48/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3880 - acc: 0.8223
# Epoch 49/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3938 - acc: 0.8186
# Epoch 50/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3891 - acc: 0.8217
# Epoch 51/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3866 - acc: 0.8225
# Epoch 52/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3856 - acc: 0.8232
# Epoch 53/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3894 - acc: 0.8214
# Epoch 54/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3868 - acc: 0.8224
# Epoch 55/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3841 - acc: 0.8242
# Epoch 56/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3944 - acc: 0.8201
# Epoch 57/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3849 - acc: 0.8248
# Epoch 58/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3853 - acc: 0.8237
# Epoch 59/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3833 - acc: 0.8246
# Epoch 60/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3836 - acc: 0.8243
# Epoch 61/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3830 - acc: 0.8253
# Epoch 62/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3788 - acc: 0.8275
# Epoch 63/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3799 - acc: 0.8266
# Epoch 64/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3770 - acc: 0.8278
# Epoch 65/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3825 - acc: 0.8251
# Epoch 66/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3874 - acc: 0.8218
# Epoch 67/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3801 - acc: 0.8267
# Epoch 68/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3757 - acc: 0.8293
# Epoch 69/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3763 - acc: 0.8286
# Epoch 70/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3769 - acc: 0.8275
# Epoch 71/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3744 - acc: 0.8299
# Epoch 72/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3809 - acc: 0.8263
# Epoch 73/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3786 - acc: 0.8265
# Epoch 74/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3711 - acc: 0.8309
# Epoch 75/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3701 - acc: 0.8307
# Epoch 76/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3693 - acc: 0.8314
# Epoch 77/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3691 - acc: 0.8317
# Epoch 78/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3781 - acc: 0.8275
# Epoch 79/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3726 - acc: 0.8304
# Epoch 80/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3699 - acc: 0.8311
# Epoch 81/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3744 - acc: 0.8293
# Epoch 82/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3736 - acc: 0.8295
# Epoch 83/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3663 - acc: 0.8329
# Epoch 84/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3647 - acc: 0.8337
# Epoch 85/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3693 - acc: 0.8316
# Epoch 86/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3628 - acc: 0.8344
# Epoch 87/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3652 - acc: 0.8335
# Epoch 88/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3682 - acc: 0.8313
# Epoch 89/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3606 - acc: 0.8363
# Epoch 90/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3629 - acc: 0.8347
# Epoch 91/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3588 - acc: 0.8371
# Epoch 92/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3581 - acc: 0.8378
# Epoch 93/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3571 - acc: 0.8382
# Epoch 94/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3559 - acc: 0.8381
# Epoch 95/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3606 - acc: 0.8360
# Epoch 96/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3587 - acc: 0.8364
# Epoch 97/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3543 - acc: 0.8393
# Epoch 98/100
# 126/126 [==============================] - 4s 34ms/step - loss: 0.3567 - acc: 0.8374
# Epoch 99/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3519 - acc: 0.8403
# Epoch 100/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3569 - acc: 0.8377

# %%
model.evaluate(X_test_vector, y_test)
# Out:
# 1304/1304 [==============================] - 8s 5ms/step - loss: 1.3604 - acc: 0.4979
# [1.360398530960083, 0.4978790581226349]

# %%
# !pip install konlpy

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.python.keras.preprocessing.text import Tokenizer
from konlpy.tag import Twitter
from gensim.models import Word2Vec
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
#filename의 경로의 파일을 읽어서 리턴
def read_data(filename):
    #filename에 해당하는 파일을 열어서 파일을 읽을수 있는 f를 생성해서 리턴
    with open(filename, 'r', encoding='utf8') as f:
        #f.read() : 파일 끝까지 읽음
        #splitlines() : 파일의 한줄씩 잘라서 리스트로 리턴
        #line 파일의 한줄이 저장되 있음
        #line.split("\t") : 파일의 한줄이 저장된 line에서 tab을 기준으로 잘라서 리스트로 리턴
        #탭을 기준으로 아이디,영화평,점수가 저장되 있음
        result = [line.split('\t') for line in f.read().splitlines() ]
        #result에 저장된 데이터에서 0번째 줄을 제외한 첫번째 줄부터 리턴
        #0번째 줄은 각 칸의 제목임
        result = result[1:] #header 제외
    return result

# %%
train_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_train.txt'
test_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/15주차 RNN_LSTM/datasets/ratings_test.txt'

# %%
#ratings_train.txt 파일을 읽어서 train_tmp 에 대입
train_tmp = read_data(train_path)

#ratings_test 파일을 읽어서 test_tmp 에 대입
test_tmp = read_data(test_path)

# %%
#한국어 문자열을 단어로 나누고 품사를 리턴하는 Twitter()객체 생성
twitter=Twitter()

#안녕 하십니까 좋은 아침입니다. 반가워" 를 단어와 품사로 분리
twitter.pos("안녕 하십니까 좋은 아침입니다. 반가워")
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#안녕하세요 좋은 아침입니다. 반가워" 를 단어와 품사로 분리 
#stem=True : 동사인 하십니까 반가워는 기본 동사형 안녕하다와 반갑다 로 변환
twitter.pos("안녕하세요 좋은 아침입니다. 반가워",stem=True)
# Out:
# [('안녕하다', 'Adjective'),
#  ('좋다', 'Adjective'),
#  ('아침', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation'),
#  ('반갑다', 'Adjective')]

# %%
#한글 품사 태깅을 할 객체
twitter = Twitter()
#영화 감상 평에서 명사와 형용사만 리턴하는 함수
#text: 영화 감상평 1줄이 대입되는 매개 변수
def getNounAdjective(text):
    #"" 가 40개인 리스트 생성
    stems = [""]*40
    #stems 의 마지막 인덱스를 stems_last_index에 저장
    stems_last_index = (len(stems)-1)
    #stems에 데이터를 추가할 인덱스
    stems_index=0

    #text(영화평이 대입될것임) 에서 단어와 품사를 리턴
    #예를 들어서 text="홍길동 간다"이면 
    #twitter.post(text,stem=True) 는 [["홍길동",Noun],["간다","Verb"]] 리턴해서 tagged에 저장
    tagged = twitter.pos(text, stem=True)
    #tagged의 줄수 만큼 반복
    for i in range (0, len(tagged)):
        #품사는 tagged의 1번째 칸에 저장
        #품사가 명사(Noun)  혹은 형용사 (Adjective) 일때
        if (tagged[i][1]=='Noun' or tagged[i][1]=='Adjective') :
            #stems에 단어 추가 단어는 tagged 각줄의 0번째 칸에 저장
            stems[stems_index]=tagged[i][0]
            #데이터를 추가 했으니 stems_index 1증가
            stems_index+=1
        
        #stems_index 가 stems_last_index 이면 반복 종료
        if stems_index == stems_last_index:
            break
    #stems_index는 리스트 stem에 저장된 단어의 개수임
    # stem에 저장된 단어가 2개 초과이면 stems 리턴
    if stems_index > 2 :    
        #리스트인 stems 리턴       
        return stems
# Out:
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
#문장에서 명사와 형용사만 리턴됨
getNounAdjective("홍길동이 길을 걸어 갔다. 길동이 아버지는 방에 들어 가셨다. 그래서 길동은 슬퍼서 눈물을 흘렸다")
# Out:
# ['홍길동',
#  '길',
#  '길동',
#  '아버지',
#  '방',
#  '길동',
#  '슬프다',
#  '눈물',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
#문장에서 명사와 형용사만 리턴됨
#문장에 저장된 명사와 형용사 개수가 2이하이므로 리턴되는 데이터 None (없음)
getNounAdjective("홍길동 아버지")

# %%
#반복문의 진행 상태를 나타내는 객체
from tqdm.notebook import tqdm

sum=0
#tqdm 을 사용하였기 때문에 반복문의 진행 상태를 
#진행 바로 나타냄
for i in tqdm(range(10000000)):
  sum=sum+i
# Out:
#   0%|          | 0/10000000 [00:00<?, ?it/s]

# %%
#학습데이터(train_tmp) 에서 ID를 삭제하고 리뷰데이터와 감성 라벨만 리턴
#테스트데이터(test_tmp) 에서 ID를 삭제하고 리뷰데이터와 감성 라벨만 리턴

def kor_movie():
    # 데이터 구조 : ID | 리뷰데이터 | 감성라벨
    # 필요없는 id를 제외하고 리뷰데이터과 감성라벨로만 이루어진 데이터를 만든다.
    # 학습 데이터의 리뷰 데이터를 저장할 리스트
    train_x = []
    #학습 데이터의 감성 라벨을 저장할 리스트
    train_y = []
    
    #len(train_tmp):학습데이터(train_tmp)의 줄의 수
    #학습 데이터의 줄의 수만큼 반복
    for i in tqdm(range(len(train_tmp))):
        #train_tmp[i][1]: 학습데이터의 i번째 줄의 1번째 칸 (영화 리뷰가 저장)을
        #getNounAdjective(): 함수를 실행-> 명사와 형용사만 리턴
        noun_adjective = getNounAdjective(train_tmp[i][1])
        
        #noun_adjective 가 None 이 아니면
        if noun_adjective is not None:
            #train_x에 명사와 형용사 추가
            train_x.append(noun_adjective)
            #train_tmp[i][1]: 학습데이터의 i번째 줄의 2번째 칸 (긍정 1 부정 0)을
            #int(): 정수로 변환 해서
            #train_y에 추가
            train_y.append(int(train_tmp[i][2]))

    # 테스트용
    test_x = []
    test_y = []
    #len(test_tmp):테스트 데이터(test_tmp)의 줄의 수
    #테스트 데이터의 줄의 수만큼 반복
    for i in tqdm(range(len(test_tmp))):
        #test_tmp[i][1]: 테스트 데이터의 i번째 줄의 1번째 칸 (영화 리뷰가 저장)을
        #getNounAdjective(): 함수를 실행-> 명사와 형용사만 리턴
        noun_adjective = getNounAdjective(test_tmp[i][1])
        #noun_adjective 가 None 이 아니면
        if noun_adjective is not None:
            #test_x에 명사와 형용사 추가
            test_x.append(noun_adjective)
            #test_tmp[i][1]: 테스트 데이터의 i번째 줄의 2번째 칸 (긍정 1 부정 0)을
            #int(): 정수로 변환 해서
            #test_y에 추가
            test_y.append(int(test_tmp[i][2]))
    #학습데이터(train_x:영화 리뷰, train_y: 긍정 (1) 부정 (0) 여부)
    #테스트 데이터(test_x:영화 리뷰, test_y: 긍정 (1) 부정 (0) 여부)
    return (train_x, train_y) , (test_x, test_y)

# %%
print('...전처리하기...')
(X_train, y_train),(X_test,y_test) = kor_movie()
# Out:
# ...전처리하기...
#   0%|          | 0/150000 [00:00<?, ?it/s]
#   0%|          | 0/50000 [00:00<?, ?it/s]

# %%
#메모리에서 train_tmp 삭제
del train_tmp

#메모리에서 test_temp 삭제
del test_tmp

# %%
#학습데이터를 조회
X_train
# Out:
# [['더빙',
#   '진짜',
#   '짜증나다',
#   '목소리',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['흠',
#   '포스터',
#   '보고',
#   '초딩',
#   '영화',
#   '줄',
#   '오버',
#   '연기',
#   '가볍다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['무재',
#   '밓었',
#   '다그',
#   '래서',
#   '추천',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['교도소',
#   '이야기',
#   '구먼',
#   '솔직하다',
#   '재미',
#   '없다',
#   '평점',
#   '조정',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['몬페',
#   '의',
#   '익살스럽다',
#   '연기',
#   '영화',
#   '스파이더맨',
#   '커스틴',
#   '던스트',
#   '이쁘다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['막',
#   '걸음',
#   '마',
#   '세',
#   '초등학교',
#   '학년',
#   '생인',
#   '영화',
#   '반개',
#   '아깝다',
#   '움',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['원작',
#   '긴장감',
#   '제대로',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['별',
#   '반개',
#   '아깝다',
#   '욕',
#   '이응경',
#   '길용우',
#   '생활',
#   '년',
#   '정말',
#   '발',
#   '해도',
#   '그것',
#   '납치',
#   '감금',
#   '반복',
#   '반복',
#   '드라마',
#   '가족',
#   '없다',
#   '연기',
#   '사람',
#   '네',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['액션',
#   '없다',
#   '재미',
#   '있다',
#   '몇',
#   '안되다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['왜케',
#   '평점',
#   '낮다',
#   '꽤',
#   '볼',
#   '데',
#   '헐리우드',
#   '화려하다',
#   '있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['인피니트',
#   '짱',
#   '진짜',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['볼때',
#   '향수',
#   '자극',
#   '허진호',
#   '감성',
#   '절제',
#   '멜로',
#   '달인',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['울면',
#   '손',
#   '횡단보도',
#   '때',
#   '뻔',
#   '이범수',
#   '연기',
#   '드럽다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['담백하다',
#   '깔끔하다',
#   '좋다',
#   '로만',
#   '자꾸',
#   '그',
#   '사람',
#   '것',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['취향',
#   '존중',
#   '다지',
#   '진짜',
#   '내생',
#   '극장',
#   '영화',
#   '가장',
#   '노잼',
#   '노',
#   '감동',
#   '임',
#   '스토리',
#   '어거지',
#   '감동',
#   '어거지',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['냥',
#   '매번',
#   '긴장',
#   '재밋음',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['사람',
#   '바스코',
#   '이기',
#   '락스',
#   '코',
#   '바비',
#   '이기',
#   '아이돌',
#   '그냥',
#   '안달',
#   '것',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['굿바이',
#   '레닌',
#   '표절',
#   '것',
#   '이해',
#   '왜',
#   '뒤',
#   '갈수록',
#   '재미',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이건',
#   '정말',
#   '깨알',
#   '캐스팅',
#   '질퍽',
#   '산뜻하다',
#   '용구성',
#   '버무러진',
#   '깨알',
#   '일드',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['약탈',
#   '위',
#   '변명',
#   '놈',
#   '착하다',
#   '놈',
#   '절대',
#   '아니다',
#   '걸',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나름',
#   '심오하다',
#   '뜻',
#   '있다',
#   '듯',
#   '그냥',
#   '학생',
#   '선생',
#   '영화',
#   '절대',
#   '아니다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재미없다',
#   '지루하다',
#   '같다',
#   '음식',
#   '영화',
#   '도',
#   '바베트',
#   '만찬',
#   '바베트',
#   '만찬',
#   '이야기',
#   '있다',
#   '음식',
#   '재미',
#   '있다',
#   '이건',
#   '볼',
#   '없다',
#   '음식',
#   '별로',
#   '핀란드',
#   '풍경',
#   '할랫',
#   '그것',
#   '별로',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['절대',
#   '평범하다',
#   '영화',
#   '아니다',
#   '수작',
#   '는걸',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['주제',
#   '좋다',
#   '중반',
#   '지루하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['짤랐을꺼',
#   '납득',
#   '수',
#   '없다',
#   '그렇다',
#   '꼭',
#   '그렇다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['카밀라',
#   '벨',
#   '발연기',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['센스',
#   '있다',
#   '연출',
#   '탁월하다',
#   '캐스팅',
#   '향수',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['엄포스',
#   '위력',
#   '다시',
#   '한번',
#   '적',
#   '남',
#   '꽃',
#   '검사',
#   '연기',
#   '정말',
#   '좋다',
#   '완전',
#   '명품',
#   '드라마',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['졸',
#   '쓰레기',
#   '진부하다',
#   '도안',
#   '시간',
#   '아깝다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재밌다',
#   '점',
#   '왜',
#   '낮다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['기대하다',
#   '내',
#   '죄인',
#   '이다',
#   '죄인',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '드라마',
#   '인생',
#   '최고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['패션',
#   '대한',
#   '열정',
#   '안나',
#   '윈',
#   '투어',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['키이라',
#   '나이틀리',
#   '연기',
#   '대체',
#   '정신장애',
#   '틱장애',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['원작',
#   '정신',
#   '유령',
#   '재미있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['포스터',
#   '있다',
#   '관객',
#   '명',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '영화',
#   '왜',
#   '평가',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['단순하다',
#   '은은하다',
#   '매력',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['알바생',
#   '내용',
#   '없다',
#   '무섭다',
#   '없다',
#   '하나',
#   '없다',
#   '완전',
#   '별',
#   '싱겁다',
#   '영화',
#   '내',
#   '시간',
#   '아깝다',
#   '움',
#   '완전',
#   '낚임',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '맘',
#   '또',
#   '또',
#   '방법',
#   '없다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['윤제문',
#   '멋지다',
#   '배우',
#   '발견',
#   '소소하다',
#   '탈',
#   '잔잔하다',
#   '미소',
#   '머금',
#   '음악',
#   '조금',
#   '아쉽다',
#   '점',
#   '평점',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['평점',
#   '속지',
#   '시간',
#   '낭비',
#   '돈',
#   '낭비',
#   '임',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['리얼리티',
#   '뛰어나다',
#   '공감',
#   '안',
#   '간다',
#   '이민기',
#   '캐릭터',
#   '정신의학',
#   '분노조절',
#   '장애',
#   '초기',
#   '증상',
#   '툭하면',
#   '사람',
#   '패',
#   '욕',
#   '물건',
#   '파손',
#   '조금',
#   '바',
#   '초반',
#   '신선하다',
#   '가면',
#   '갈수록',
#   '이민기',
#   '정신',
#   '상태',
#   '공감',
#   '불가',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['마이너스',
#   '왜',
#   '없다',
#   '뮤비',
#   '보고',
#   '영화',
#   '수준',
#   '알',
#   '북한',
#   '이렇다',
#   '돈',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['난',
#   '우리',
#   '영화',
#   '사랑',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['데',
#   '리스',
#   '타르',
#   '용의',
#   '주인',
#   '누',
#   '근친상간',
#   '소설',
#   '속',
#   '제일',
#   '멋지다',
#   '놈',
#   '자',
#   '메',
#   '니스',
#   '터',
#   '드라마',
#   '속',
#   '드래곤',
#   '용',
#   '이',
#   '제일',
#   '멋지다',
#   '웃음',
#   '감독',
#   '토르',
#   '다크',
#   '월드',
#   '말',
#   '기본',
#   '선방',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '사람',
#   '영혼',
#   '줄',
#   '수도',
#   '있다',
#   '상사',
#   '잠시',
#   '동화',
#   '같다',
#   '영화',
#   '행복하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['세르게이',
#   '작다',
#   '고추',
#   '맵다',
#   '맛',
#   '포퐁',
#   '저그',
#   '콩',
#   '진호',
#   '간다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['가슴',
#   '시리',
#   '드라마',
#   '또',
#   '있다',
#   '감동',
#   '그',
#   '자체',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['난또',
#   '저',
#   '꼬마',
#   '애가',
#   '무슨',
#   '원한',
#   '깊다',
#   '그냥',
#   '혼자',
#   '걸',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['충격',
#   '기분',
#   '완전하다',
#   '푹',
#   '느낌',
#   '활',
#   '하나',
#   '없다',
#   '무겁다',
#   '지독하다',
#   '차갑다',
#   '무자비하다',
#   '일본인',
#   '상상력',
#   '정말',
#   '대단하다',
#   '같다',
#   '생각',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['그대로',
#   '예측',
#   '카리스마',
#   '없다',
#   '악역',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['불알',
#   '당황',
#   '영화',
#   '중간',
#   '느낌',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['평범하다',
#   '속',
#   '평범하다',
#   '일상',
#   '조금',
#   '밋밋하다',
#   '흠',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['계속',
#   '전개도',
#   '느리다',
#   '주인공',
#   '은희',
#   '컷',
#   '극적',
#   '모습',
#   '짜증',
#   '언제',
#   '대만',
#   '있다',
#   '전개',
#   '좀',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['사랑',
#   '가슴속',
#   '감정',
#   '영화',
#   '정말',
#   '최고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['많다',
#   '사람',
#   '이',
#   '다큐',
#   '보고',
#   '우리나라',
#   '슬프다',
#   '현대',
#   '사의',
#   '단면',
#   '대해',
#   '깊이',
#   '생각',
#   '사죄',
#   '바로',
#   '잡기',
#   '위해',
#   '노력',
#   '말로',
#   '보도',
#   '연맹',
#   '그',
#   '민간인',
#   '학살',
#   '이정',
#   '일',
#   '줄',
#   '이건',
#   '명백하다',
#   '살인',
#   '이다',
#   '살인자',
#   '어디',
#   '있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['예전',
#   '작품',
#   '캐릭터',
#   '에피소드',
#   '재탕',
#   '탕',
#   '사골',
#   '우려',
#   '먹듯',
#   '우리',
#   '내용',
#   '산',
#   '시청률',
#   '아예',
#   '이제',
#   '부작',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['김남길',
#   '점',
#   '연기력',
#   '초반',
#   '몰입도',
#   '불구',
#   '지루하다',
#   '손예진',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재밌다',
#   '비슷하다',
#   '영화',
#   '분',
#   '재미있다',
#   '듯',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['노래실력',
#   '박시환',
#   '진짜',
#   '망신',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['일본',
#   '영화',
#   '건가',
#   '유치하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이틀',
#   '재밌다',
#   '차',
#   '안',
#   '물건',
#   '조작',
#   '차',
#   '안이',
#   '집',
#   '안이',
#   '활짝',
#   '아무나',
#   '문자',
#   '조작',
#   '비번',
#   '안',
#   '그렇다',
#   '건',
#   '억지스럽다',
#   '내용',
#   '자체',
#   '좋다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재밋네',
#   '달팽이',
#   '빨',
#   '더',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['어설프다',
#   '전개',
#   '어이없다',
#   '결말',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['부패하다',
#   '로마노프',
#   '왕조',
#   '기리',
#   '뭣같',
#   '영화',
#   '온몸',
#   '항거',
#   '러시아',
#   '민중',
#   '폭도',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['내용',
#   '전개',
#   '무난',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['한국영',
#   '흥행',
#   '코드',
#   '갈등',
#   '갈등',
#   '계',
#   '속',
#   '갈등',
#   '화해',
#   '감동',
#   '평점',
#   '점',
#   '남발',
#   '흥행',
#   '뻔하다',
#   '뭐',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['아햏햏',
#   '아햏햏',
#   '아햏햏',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['뭐',
#   '시작',
#   '리플릿',
#   '사진',
#   '불안하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['감독',
#   '럼',
#   '영화',
#   '관객',
#   '뭘',
#   '말',
#   '엉망',
#   '진창',
#   '개',
#   '진창',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이건',
#   '뭐',
#   '우뢰매',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '쓰레기',
#   '영화',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진정',
#   '위대하다',
#   '영화',
#   '최고',
#   '임',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['조미',
#   '막문위',
#   '좋아하다',
#   '가요',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진짜',
#   '골깜',
#   '눈',
#   '때',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['성룡',
#   '영화',
#   '최악',
#   '듯',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['골',
#   '걸스데이',
#   '이혜리',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['완전',
#   '재밌다',
#   '인공',
#   '주귀',
#   '움',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['어내스트',
#   '셀레스틴',
#   '완전',
#   '강추',
#   '정말',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재미있다',
#   '영화',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['클라라',
#   '볼라',
#   '화신',
#   '아니다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진짜',
#   '슬프다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['설정',
#   '재밌다',
#   '새롭다',
#   '에피소드',
#   '내',
#   '메인',
#   '스토리',
#   '차차',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['신카이',
#   '마코토',
#   '작화',
#   '밉다',
#   '유',
#   '하나',
#   '카나',
#   '연기',
#   '더',
#   '대박',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재미없다',
#   '진심',
#   '이훨',
#   '캐스팅',
#   '못',
#   '듯',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['잔잔하다',
#   '생각',
#   '볼',
#   '영화',
#   '같다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['감독',
#   '고은님',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '속',
#   '억지스럽다',
#   '노골',
#   '술',
#   '광고',
#   '좀',
#   '은은하다',
#   '센스',
#   '있다',
#   '어떻다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재미있다',
#   '매력',
#   '행복',
#   '요',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['음악',
#   '완전하다',
#   '볼',
#   '수',
#   '있다',
#   '영화',
#   '쫌',
#   '산만하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['처음',
#   '영화',
#   '중간',
#   '불륜',
#   '로맨스',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['왕',
#   '짜증',
#   '아주',
#   '전개',
#   '짬뽕',
#   '믹스',
#   '음향',
#   '무섭다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['솔직하다',
#   '난',
#   '별루더',
#   '시간',
#   '낭비',
#   '느낌',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['시청률',
#   '기준',
#   '패널',
#   '가구',
#   '머',
#   '명작',
#   '드라마',
#   '망치',
#   '내',
#   '서운하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['몬스터',
#   '주식회사',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['내용',
#   '전개',
#   '느리다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['소재',
#   '흥미',
#   '끌',
#   '이야기',
#   '전개',
#   '투',
#   '박하다',
#   '몰입',
#   '안되다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['절대',
#   '쓰레기',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['중국인',
#   '특유',
#   '과장',
#   '허풍',
#   '있다',
#   '안간힘',
#   '노력',
#   '가상하다',
#   '고증',
#   '실감',
#   '설정',
#   '거북',
#   '스럽다',
#   '도대체',
#   '그',
#   '왜',
#   '스스로',
#   '과대',
#   '포장',
#   '것',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['그냥',
#   '불법체류자',
#   '영화',
#   '좋다',
#   '무슨',
#   '우상화',
#   '미국',
#   '따뜻하다',
#   '설정',
#   '이건',
#   '뭥미',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['삶속',
#   '주인공',
#   '생애',
#   '전부',
#   '듯',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['꽤',
#   '지난',
#   '후',
#   '재미있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['아니다',
#   '이',
#   '왜',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['지나',
#   '다시',
#   '영화',
#   '다시',
#   '그',
#   '순수하다',
#   '사랑',
#   '감동',
#   '숀펜',
#   '연기',
#   '또한',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['올레',
#   '공짜',
#   '있다',
#   '스토리',
#   '문제',
#   '아니다',
#   '연기자',
#   '전혀',
#   '배역',
#   '상대',
#   '배우',
#   '같다',
#   '이건',
#   '연기자',
#   '문제',
#   '있다',
#   '보아',
#   '진심',
#   '완전',
#   '별로',
#   '임',
#   '라미란',
#   '아들',
#   '젤',
#   '볼',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['욕심',
#   '많다',
#   '영화',
#   '쪽',
#   '제대로',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['베댓',
#   '말',
#   '아주',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '도둑',
#   '뫼비우스',
#   '같다',
#   '나라',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['온몸',
#   '찌릿',
#   '짜릿',
#   '나',
#   '용기',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '재미있다',
#   '교훈',
#   '화이',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['당시',
#   '상황',
#   '주제',
#   '주입',
#   '식이',
#   '아니다',
#   '긴장감',
#   '있다',
#   '재밌다',
#   '전하',
#   '작품',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['다르덴',
#   '투',
#   '차이밍량',
#   '하나',
#   '채',
#   '짬뽕',
#   '그릇',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['여군',
#   '잼',
#   '없다',
#   '뭐',
#   '잼',
#   '없다',
#   '엠비씨',
#   '잼',
#   '없다',
#   '이제',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['한석규',
#   '김혜수',
#   '연기',
#   '영화',
#   '어딘',
#   '어설프다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['솔직하다',
#   '에볼라',
#   '바이러스',
#   '해',
#   '영화',
#   '작품',
#   '면',
#   '년전',
#   '영화',
#   '보기',
#   '힘들다',
#   '정도',
#   '정말',
#   '마지막',
#   '후반',
#   '부가',
#   '살짝',
#   '아쉽다',
#   '정도',
#   '수작',
#   '시간',
#   '아깝다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['용가리',
#   '진짜',
#   '짱짱맨',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '영화',
#   '이제',
#   '감히',
#   '내',
#   '인생',
#   '최고',
#   '영화',
#   '하나로',
#   '꼽',
#   '수',
#   '있다',
#   '작품',
#   '어떻다',
#   '살',
#   '야하다',
#   '위',
#   '고민',
#   '한번',
#   '더',
#   '시간',
#   '모건',
#   '프리',
#   '멀다',
#   '나이',
#   '여전하다',
#   '섹시하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['작가',
#   '별로',
#   '용이',
#   '진짜',
#   '별로',
#   '임',
#   '기대',
#   '재방송',
#   '혹',
#   '시나',
#   '답',
#   '없다',
#   '진짜',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['명작',
#   '이렇다',
#   '명작',
#   '있다',
#   '보고',
#   '또',
#   '여운',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진짜',
#   '조금',
#   '더',
#   '손',
#   '좀',
#   '왠만하다',
#   '상업',
#   '영화',
#   '못',
#   '퀄리티',
#   '질',
#   '수',
#   '있다',
#   '아쉽다',
#   '충분하다',
#   '재미있다',
#   '개인',
#   '조금',
#   '더',
#   '잔인하다',
#   '더',
#   '자극',
#   '노출씬',
#   '화끈하다',
#   '어떻다',
#   '국산',
#   '영화',
#   '듯',
#   '보임',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['좀',
#   '끌',
#   '이제',
#   '끝내',
#   '지겹다',
#   '지겹다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['역시',
#   '드니',
#   '의',
#   '연기',
#   '일품',
#   '맥스',
#   '샘',
#   '바랬다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나름',
#   '괜찮다',
#   '작품',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '실망',
#   '스러웟음',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['배우',
#   '지네',
#   '영화',
#   '찍을껀데',
#   '왜',
#   '진짜',
#   '면상',
#   '왜',
#   '지네',
#   '자신',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['어린이',
#   '좋아하다',
#   '내',
#   '적',
#   '동심',
#   '멀리',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['무술',
#   '왜',
#   '총을드',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['크리스토퍼',
#   '왈츠',
#   '타란티노',
#   '조합',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['한국',
#   '유명',
#   '한편',
#   '아니다',
#   '외국',
#   '상상',
#   '초월',
#   '유명하다',
#   '영화',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['만',
#   '재밋',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['종방',
#   '아쉽다',
#   '오늘',
#   '막',
#   '방도',
#   '방송',
#   '대본',
#   '꽤',
#   '완성',
#   '있다',
#   '느낌',
#   '요즘',
#   '드라마',
#   '막장',
#   '수백향',
#   '정말',
#   '드라마',
#   '해',
#   '악역',
#   '심하다',
#   '어이없다',
#   '화이팅',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['평점',
#   '조절',
#   '위원회',
#   '웃음',
#   '김혜선',
#   '내일',
#   '의',
#   '김',
#   '순정',
#   '순정',
#   '역할',
#   '제일',
#   '팜므파탈',
#   '로써',
#   '그',
#   '정도',
#   '줄',
#   '정말',
#   '의외',
#   '연기',
#   '사람',
#   '요즘',
#   '사극',
#   '있다',
#   '그녀',
#   '대한',
#   '논란',
#   '코미디',
#   '장면',
#   '같다',
#   '웃음',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '끝',
#   '때',
#   '멍하다',
#   '한마디',
#   '임',
#   '같다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['상쾌',
#   '발랄하다',
#   '영화',
#   '말',
#   '껄끄런',
#   '성',
#   '소재',
#   '유쾌하다',
#   '해설',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['소파',
#   '죽',
#   '볼',
#   '이유',
#   '없다',
#   '작품',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['타겟',
#   '어린이',
#   '일반',
#   '논리',
#   '통',
#   '건',
#   '게임',
#   '흥미롭다',
#   '요원',
#   '주인공',
#   '무능력하다',
#   '별로',
#   '재미없다',
#   '배경',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['뮤지컬',
#   '영화',
#   '사운드',
#   '녹음',
#   '엉망',
#   '춤',
#   '내용',
#   '뻔하다',
#   '뻔',
#   '주인공',
#   '목소리',
#   '어제',
#   '진심',
#   '말리',
#   '영국',
#   '예산',
#   '용',
#   '영화',
#   '뮤지컬영화',
#   '아니다',
#   '맘마미아',
#   '도',
#   '안되다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['꽤',
#   '좋아하다',
#   '로맨틱코미디',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '영화',
#   '머임',
#   '내',
#   '왜',
#   '그것',
#   '알고싶다',
#   '이',
#   '영화',
#   '배우',
#   '스텝',
#   '감독',
#   '꼭두각시',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '아름답다',
#   '영화',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['자극',
#   '것',
#   '현대인',
#   '눈',
#   '힘드다',
#   '연출',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['뻑',
#   '뻑',
#   '볼걸',
#   '당하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '짜증',
#   '극치',
#   '영화',
#   '굉장하다',
#   '언밸러스',
#   '느낌',
#   '뚱뚱하다',
#   '남자',
#   '애',
#   '발연기',
#   '시종일관',
#   '고역',
#   '듯',
#   '잔잔하다',
#   '클래식',
#   '의',
#   '음악',
#   '듣기',
#   '싫다',
#   '짜증나다',
#   '정도',
#   '상당하다',
#   '싫다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['감동',
#   '감동',
#   '정말',
#   '최고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['점',
#   '주기도',
#   '아깝다',
#   '얼마나',
#   '내용',
#   '진부하다',
#   '욕',
#   '보고',
#   '재밌다',
#   '사람',
#   '초딩',
#   '죄송하다',
#   '화가',
#   '아무',
#   '것',
#   '볼',
#   '없다',
#   '보지',
#   '그냥',
#   '티비',
#   '판',
#   '거',
#   '같다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나',
#   '왠만하다',
#   '짜증',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['돼지',
#   '피',
#   '닭목',
#   '장면',
#   '우웩',
#   '역시',
#   '무당',
#   '아무나',
#   '아니다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['유치하다',
#   '지루하다',
#   '잠',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['류',
#   '판타지',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['윤종신',
#   '복귀',
#   '좋다',
#   '이하늘',
#   '도대체',
#   '왜',
#   '없다',
#   '참가자',
#   '실력',
#   '전',
#   '심사',
#   '위원',
#   '인격',
#   '실력',
#   '어',
#   '좀',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['광장',
#   '작품',
#   '옛날',
#   '것',
#   '보고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['내',
#   '생',
#   '최고',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['어린시절',
#   '무섭다',
#   '재미있다',
#   '추억',
#   '판타지영화',
#   '절대',
#   '나쁘다',
#   '금물',
#   '지옥',
#   '가요',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['기존',
#   '멜로영화',
#   '형식',
#   '탈피',
#   '감정',
#   '절제',
#   '담백하다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['난',
#   '사랑비',
#   '서준',
#   '쏙',
#   '쏙',
#   '난',
#   '절대',
#   '후회',
#   '도안',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이영화',
#   '보',
#   '교훈',
#   '주네',
#   '인생',
#   '화려하다',
#   '말',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나름',
#   '추억',
#   '좋다',
#   '생각',
#   '가볍다',
#   '추천',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['단순하다',
#   '싸이코',
#   '물',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '가요',
#   '아니다',
#   '예전',
#   '다시',
#   '개봉',
#   '건가',
#   '접해',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['사랑스럽다',
#   '영화',
#   '보고',
#   '이',
#   '귀엽다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['청춘',
#   '영화',
#   '줄',
#   '수',
#   '있다',
#   '감성',
#   '넘치다',
#   '이',
#   '순간',
#   '다시',
#   '그',
#   '순간',
#   '무한',
#   '젊음',
#   '줄',
#   '수',
#   '있다',
#   '그렇다',
#   '감성',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['용',
#   '건담',
#   '시리즈',
#   '중',
#   '최고봉',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['개콘',
#   '요즘',
#   '갈수록',
#   '코너',
#   '노잼',
#   '웃음',
#   '이안',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['사다코',
#   '이',
#   '서린',
#   '우물',
#   '펀치',
#   '감동',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['후세',
#   '사랑',
#   '결정',
#   '계기',
#   '시간',
#   '표현',
#   '람',
#   '생명',
#   '이유',
#   '등',
#   '노',
#   '출현',
#   '연극',
#   '로',
#   '더',
#   '생각',
#   '또한',
#   '노',
#   '얼마나',
#   '본능',
#   '절제',
#   '면서',
#   '시',
#   '노력',
#   '더',
#   '좋다',
#   '뻔하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['새벽',
#   '시간',
#   '일본',
#   '영화',
#   '전부',
#   '개',
#   '졸작',
#   '영화',
#   '다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['강수연',
#   '최정원',
#   '신음',
#   '신',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '김혜성',
#   '예쁘다',
#   '이현진',
#   '거',
#   '정말',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['화려하다',
#   '여정',
#   '이인상',
#   '깊다',
#   '재밋어',
#   '배두나',
#   '정말',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['위',
#   '성적',
#   '호기심',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이건',
#   '말',
#   '필요',
#   '없다',
#   '그냥',
#   '닥치고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['각기',
#   '다른',
#   '사람',
#   '재밌다',
#   '멋지다',
#   '사랑',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['역시',
#   '미국드라마',
#   '파워',
#   '정말',
#   '없다',
#   '그',
#   '미묘하다',
#   '최고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['거',
#   '응답',
#   '하라',
#   '은지원',
#   '스스로',
#   '욕',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['웃기',
#   '배꼽',
#   '뻔하다',
#   '내',
#   '컴',
#   '이',
#   '영화',
#   '있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['구성',
#   '상당하다',
#   '부실하다',
#   '영화',
#   '역시',
#   '네이버',
#   '평점',
#   '없다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['장끌',
#   '로드',
#   '몰락',
#   '오우삼',
#   '헐리우드',
#   '작품',
#   '가장',
#   '재미없다',
#   '졸작',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['제적',
#   '영웅본색',
#   '연출',
#   '현실',
#   '제로',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['작다',
#   '하나',
#   '설레다',
#   '학창시절',
#   '그때',
#   '느낌',
#   '다시',
#   '시간',
#   '장면',
#   '하나',
#   '하나',
#   '대사',
#   '하나',
#   '하나',
#   '배경음악',
#   '하나',
#   '하나',
#   '없다',
#   '드라마',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진심',
#   '재미',
#   '없다',
#   '평점',
#   '높다',
#   '화남',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['더럽다',
#   '재미없다',
#   '어떻다',
#   '형태',
#   '도',
#   '허무하다',
#   '완벽하다',
#   '지루하다',
#   '영화',
#   '영양가',
#   '하나',
#   '없다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이승기',
#   '정말',
#   '연기',
#   '조연',
#   '연기',
#   '정말',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['현실',
#   '꿈',
#   '꿈',
#   '현실',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['오늘',
#   '현충일',
#   '특집',
#   '프로',
#   '매우',
#   '훌륭하다',
#   '작품',
#   '이다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
# ...
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['어째서',
#   '틴토',
#   '계',
#   '거장',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이렇다',
#   '영화',
#   '없다',
#   '번은',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['원작',
#   '소설',
#   '사람',
#   '진짜',
#   '답답하다',
#   '엔딩',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['꿀잼',
#   '영화',
#   '추억',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['급',
#   '영화',
#   '찬사',
#   '타란티노',
#   '로드리게즈',
#   '찬사',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['더',
#   '이상',
#   '자세하다',
#   '설명',
#   '생략',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['촬영',
#   '감독',
#   '초보',
#   '장비',
#   '후진',
#   '영상',
#   '화면',
#   '매우',
#   '불',
#   '안정',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['조금',
#   '재밌다',
#   '마지막',
#   '가슴',
#   '만약',
#   '걸',
#   '찰흙',
#   '아니다',
#   '진짜',
#   '사람',
#   '연기',
#   '난',
#   '정말',
#   '눈물',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['말',
#   '재미없다',
#   '내',
#   '이상하다',
#   '건가',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['재밌다',
#   '만하',
#   '생각',
#   '눈물',
#   '크리',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['것',
#   '영화',
#   '속편',
#   '낼',
#   '생각',
#   '있다',
#   '미치다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['시간',
#   '아깝다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이렇다',
#   '대작',
#   '접',
#   '이',
#   '말',
#   '필요없다',
#   '짦',
#   '정도',
#   '대작',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['송혜교',
#   '이쁘다',
#   '점',
#   '감독',
#   '의도',
#   '표현',
#   '느낌',
#   '더',
#   '생각',
#   '말',
#   '정도',
#   '점',
#   '엉망',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['거',
#   '구제불',
#   '능이',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['출가',
#   '후',
#   '이',
#   '영화',
#   '김해',
#   '은하사',
#   '좋다',
#   '액션',
#   '코미디',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['스티플러',
#   '연기',
#   '정말',
#   '정말',
#   '배우',
#   '사랑',
#   '존경',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '영화',
#   '자체',
#   '고통',
#   '순간',
#   '난',
#   '죄인',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['하하',
#   '그렇다',
#   '전무송',
#   '괴',
#   '노인',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['완전',
#   '재밋음',
#   '역시',
#   '짱구',
#   '최고',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['씨',
#   '리즈',
#   '건너',
#   '것',
#   '재미있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['걸',
#   '조폭',
#   '미화',
#   '평가',
#   '사람',
#   '이',
#   '영화',
#   '한참',
#   '잘못',
#   '거',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['진짜',
#   '머',
#   '경우',
#   '있다',
#   '진짜',
#   '지금',
#   '봣음',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['화면',
#   '예쁘다',
#   '그거',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['옛날',
#   '영화',
#   '그렇다',
#   '연출',
#   '웃음',
#   '정도',
#   '갖가지',
#   '사건',
#   '연관',
#   '성도',
#   '없다',
#   '기',
#   '승전',
#   '결',
#   '식임',
#   '군대',
#   '욕',
#   '보지',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['완전',
#   '짱',
#   '박대동',
#   '길',
#   '홍도',
#   '쾌',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이야기',
#   '스토리',
#   '없다',
#   '같다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이영화',
#   '정말',
#   '별로',
#   '니콜라스',
#   '케이',
#   '볼',
#   '함',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['결승전',
#   '공정하다',
#   '말',
#   '많다',
#   '것',
#   '또한',
#   '장동민',
#   '게임',
#   '라운드',
#   '지금',
#   '결과물',
#   '생각',
#   '장동민',
#   '게임',
#   '뿐',
#   '아니다',
#   '게임',
#   '사람',
#   '관계도',
#   '온',
#   '것',
#   '같다',
#   '오현민',
#   '멋',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['거',
#   '완전',
#   '재밌다',
#   '한번',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['솔직하다',
#   '내',
#   '잡스',
#   '인간성',
#   '대해',
#   '없다',
#   '없다',
#   '잡스',
#   '지금',
#   '산업',
#   '개념',
#   '처음',
#   '앱스토어',
#   '개념',
#   '애플',
#   '먼저',
#   '안드로이드',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['흔하다',
#   '범죄자',
#   '미화',
#   '감성',
#   '이물',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['케이블',
#   '드라마',
#   '나인',
#   '넘사벽',
#   '모든',
#   '지상파',
#   '드라마',
#   '지상파',
#   '제발',
#   '드라마',
#   '마르다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['왜',
#   '평점',
#   '낮다',
#   '재밌다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['초등학교',
#   '때',
#   '부터',
#   '내',
#   '맘속',
#   '최고',
#   '드라마',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['드라마',
#   '일요일',
#   '아침',
#   '푹',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['같다',
#   '동족',
#   '걸',
#   '같다',
#   '인간',
#   '도울',
#   '수',
#   '없다',
#   '안타깝다',
#   '장성택',
#   '사건',
#   '그렇다',
#   '머',
#   '북한',
#   '체제',
#   '자멸',
#   '날',
#   '멀다',
#   '같다',
#   '중국',
#   '호시탐탐',
#   '노리',
#   '있다',
#   '북한',
#   '땅',
#   '중국',
#   '또',
#   '것',
#   '같다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['동민',
#   '역시',
#   '기대',
#   '저',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나이',
#   '다섯',
#   '수지',
#   '아저씨',
#   '집',
#   '라면',
#   '갈래',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '지루하다',
#   '연출',
#   '감독',
#   '야유',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '진짜',
#   '감동',
#   '점',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '이정우',
#   '다미',
#   '김푸른',
#   '것',
#   '제일',
#   '심하다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['엄기준',
#   '연기',
#   '짱',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['최',
#   '근본',
#   '영화',
#   '최악',
#   '듯',
#   '처음',
#   '흥미진진',
#   '갈수록',
#   '지루하다',
#   '허무하다',
#   '짜증',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['팔',
#   '절단',
#   '씬',
#   '이후',
#   '의',
#   '이',
#   '순간',
#   '넘치다',
#   '카타르',
#   '시스',
#   '미치다',
#   '소름',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['현실',
#   '건',
#   '갑자기',
#   '폭력',
#   '앞',
#   '무력하다',
#   '모습',
#   '순',
#   '어거지',
#   '없다',
#   '영화',
#   '거',
#   '보지',
#   '나오미',
#   '왓츠',
#   '앨리',
#   '파커',
#   '를',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정준호',
#   '떄문',
#   '점',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['평점',
#   '오류',
#   '있다',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['쇼생크탈출',
#   '분명하다',
#   '명작',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['오역',
#   '연기',
#   '조금',
#   '어색하다',
#   '클린트',
#   '이스트',
#   '우드',
#   '정말',
#   '대단하다',
#   '영화',
#   '중',
#   '그',
#   '동화',
#   '영화',
#   '절정',
#   '부분',
#   '그',
#   '슬픔',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['그냥',
#   '여자',
#   '이중성',
#   '뿐',
#   '의미',
#   '없다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['짱',
#   '또',
#   '보고',
#   '똘볼수',
#   '있다',
#   '누가',
#   '좀',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['언론',
#   '맹점',
#   '군중심리',
#   '개인',
#   '심리',
#   '재미',
#   '균형',
#   '멋',
#   '진영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['이',
#   '평점',
#   '보고',
#   '감독',
#   '행복하다',
#   '얼굴',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['기대',
#   '안',
#   '반전',
#   '있다',
#   '재미있다',
#   '연인',
#   '가족',
#   '끼리',
#   '좋다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['야동',
#   '극장',
#   '개봉',
#   '있다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['나',
#   '캣우먼',
#   '이렇다',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['정말',
#   '좋다',
#   '영화',
#   '진정하다',
#   '사랑',
#   '무엇',
#   '인지',
#   '말',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['대박',
#   '꼭',
#   '스릴',
#   '감',
#   '액션',
#   '굿',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['영화',
#   '있다',
#   '강우석',
#   '답',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['에이브',
#   '럼스',
#   '발견',
#   '영화',
#   '미션임파서블',
#   '더',
#   '긴장감',
#   '있다',
#   '재밌다',
#   '훌륭하다',
#   '오락',
#   '영화',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['제목',
#   '심',
#   '상치',
#   '영화',
#   '옥주현',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ...]

# %%
#X_train의 단어를 Word2Vector로 생성
# size=20 : 워드벡터로 변환한 데이터의 칸수
word2vector = Word2Vec(X_train, size=20)

# %%
#word2vector.init_sims(replace=True) : Word2Vector를 계산할때 사용한 변수들을 메모리에서 삭제
word2vector.init_sims(replace=True)

# %%
#영화와 가장 가까운 거리의 단어 조회
word2vector.wv.most_similar("영화")
# Out:
# [('영화로', 0.8424920439720154),
#  ('무라카미', 0.7767491936683655),
#  ('애니메이션', 0.7461503744125366),
#  ('재난영화', 0.7455440759658813),
#  ('공포물', 0.7322407364845276),
#  ('가을동화', 0.7227115035057068),
#  ('공포영화', 0.7208267450332642),
#  ('만화영화', 0.7115954756736755),
#  ('화란', 0.7113921046257019),
#  ('애니', 0.7075731754302979)]

# %%
#배우와 가장 가까운 거리의 단어 조회
word2vector.wv.most_similar("배우")
# Out:
# [('연기자', 0.9476362466812134),
#  ('조연', 0.8877931833267212),
#  ('배역', 0.8712071180343628),
#  ('주연', 0.854213297367096),
#  ('송강호', 0.8459872603416443),
#  ('신인', 0.8366875052452087),
#  ('차승원', 0.8277773857116699),
#  ('안성기', 0.8253532648086548),
#  ('외모', 0.8243128657341003),
#  ('김창완', 0.8225927352905273)]

# %%
#word2vector 가 벡터로 만든 단어 조회
word2vector.wv.vocab
# Out:
# {'더빙': <gensim.models.keyedvectors.Vocab at 0x7f5354c2d810>,
#  '진짜': <gensim.models.keyedvectors.Vocab at 0x7f535a265b90>,
#  '짜증나다': <gensim.models.keyedvectors.Vocab at 0x7f535a265750>,
#  '목소리': <gensim.models.keyedvectors.Vocab at 0x7f5354ebab10>,
#  '': <gensim.models.keyedvectors.Vocab at 0x7f5367c14ad0>,
#  '흠': <gensim.models.keyedvectors.Vocab at 0x7f535a260410>,
#  '포스터': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd590>,
#  '보고': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd910>,
#  '초딩': <gensim.models.keyedvectors.Vocab at 0x7f535c95b250>,
#  '영화': <gensim.models.keyedvectors.Vocab at 0x7f5367c14dd0>,
#  '줄': <gensim.models.keyedvectors.Vocab at 0x7f5354bdda90>,
#  '오버': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd990>,
#  '연기': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd950>,
#  '가볍다': <gensim.models.keyedvectors.Vocab at 0x7f5354bddad0>,
#  '무재': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd890>,
#  '다그': <gensim.models.keyedvectors.Vocab at 0x7f5354bddb50>,
#  '래서': <gensim.models.keyedvectors.Vocab at 0x7f5354bddb90>,
#  '추천': <gensim.models.keyedvectors.Vocab at 0x7f5354bddc50>,
#  '교도소': <gensim.models.keyedvectors.Vocab at 0x7f5354bddcd0>,
#  '이야기': <gensim.models.keyedvectors.Vocab at 0x7f5354bddd50>,
#  '구먼': <gensim.models.keyedvectors.Vocab at 0x7f5354bddd90>,
#  '솔직하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bdddd0>,
#  '재미': <gensim.models.keyedvectors.Vocab at 0x7f5354bdde10>,
#  '없다': <gensim.models.keyedvectors.Vocab at 0x7f5354bdde50>,
#  '평점': <gensim.models.keyedvectors.Vocab at 0x7f5354bdded0>,
#  '조정': <gensim.models.keyedvectors.Vocab at 0x7f5354bddf10>,
#  '의': <gensim.models.keyedvectors.Vocab at 0x7f5354bdde90>,
#  '익살스럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354bddf50>,
#  '스파이더맨': <gensim.models.keyedvectors.Vocab at 0x7f5354bddf90>,
#  '이쁘다': <gensim.models.keyedvectors.Vocab at 0x7f5354bddfd0>,
#  '막': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd9d0>,
#  '걸음': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd7d0>,
#  '마': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd710>,
#  '세': <gensim.models.keyedvectors.Vocab at 0x7f5354bdda50>,
#  '초등학교': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd8d0>,
#  '학년': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd810>,
#  '생인': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd750>,
#  '반개': <gensim.models.keyedvectors.Vocab at 0x7f5354bddbd0>,
#  '아깝다': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd790>,
#  '움': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd6d0>,
#  '원작': <gensim.models.keyedvectors.Vocab at 0x7f5354bddb10>,
#  '긴장감': <gensim.models.keyedvectors.Vocab at 0x7f5354bddc10>,
#  '제대로': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd650>,
#  '별': <gensim.models.keyedvectors.Vocab at 0x7f5354bddc90>,
#  '욕': <gensim.models.keyedvectors.Vocab at 0x7f5354bddd10>,
#  '이응경': <gensim.models.keyedvectors.Vocab at 0x7f5354bdda10>,
#  '생활': <gensim.models.keyedvectors.Vocab at 0x7f5354bdd690>,
#  '년': <gensim.models.keyedvectors.Vocab at 0x7f5354be8050>,
#  '정말': <gensim.models.keyedvectors.Vocab at 0x7f5354be8090>,
#  '발': <gensim.models.keyedvectors.Vocab at 0x7f5354be8110>,
#  '해도': <gensim.models.keyedvectors.Vocab at 0x7f5354be8150>,
#  '그것': <gensim.models.keyedvectors.Vocab at 0x7f5354be80d0>,
#  '납치': <gensim.models.keyedvectors.Vocab at 0x7f5354be8190>,
#  '감금': <gensim.models.keyedvectors.Vocab at 0x7f5354be81d0>,
#  '반복': <gensim.models.keyedvectors.Vocab at 0x7f5354be8210>,
#  '드라마': <gensim.models.keyedvectors.Vocab at 0x7f5354be8250>,
#  '가족': <gensim.models.keyedvectors.Vocab at 0x7f5354be8290>,
#  '사람': <gensim.models.keyedvectors.Vocab at 0x7f5354be82d0>,
#  '네': <gensim.models.keyedvectors.Vocab at 0x7f5354be8310>,
#  '액션': <gensim.models.keyedvectors.Vocab at 0x7f5354be8350>,
#  '있다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8390>,
#  '몇': <gensim.models.keyedvectors.Vocab at 0x7f5354be8410>,
#  '안되다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8450>,
#  '왜케': <gensim.models.keyedvectors.Vocab at 0x7f5354be83d0>,
#  '낮다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8490>,
#  '꽤': <gensim.models.keyedvectors.Vocab at 0x7f5354be84d0>,
#  '볼': <gensim.models.keyedvectors.Vocab at 0x7f5354be8510>,
#  '데': <gensim.models.keyedvectors.Vocab at 0x7f5354be8550>,
#  '헐리우드': <gensim.models.keyedvectors.Vocab at 0x7f5354be8590>,
#  '화려하다': <gensim.models.keyedvectors.Vocab at 0x7f5354be85d0>,
#  '인피니트': <gensim.models.keyedvectors.Vocab at 0x7f5354be8610>,
#  '짱': <gensim.models.keyedvectors.Vocab at 0x7f5354be8650>,
#  '볼때': <gensim.models.keyedvectors.Vocab at 0x7f5354be8690>,
#  '향수': <gensim.models.keyedvectors.Vocab at 0x7f5354be8710>,
#  '자극': <gensim.models.keyedvectors.Vocab at 0x7f5354be8750>,
#  '허진호': <gensim.models.keyedvectors.Vocab at 0x7f5354be86d0>,
#  '감성': <gensim.models.keyedvectors.Vocab at 0x7f5354be8790>,
#  '절제': <gensim.models.keyedvectors.Vocab at 0x7f5354be87d0>,
#  '멜로': <gensim.models.keyedvectors.Vocab at 0x7f5354be8810>,
#  '달인': <gensim.models.keyedvectors.Vocab at 0x7f5354be8850>,
#  '울면': <gensim.models.keyedvectors.Vocab at 0x7f5354be8890>,
#  '손': <gensim.models.keyedvectors.Vocab at 0x7f5354be88d0>,
#  '때': <gensim.models.keyedvectors.Vocab at 0x7f5354be8910>,
#  '뻔': <gensim.models.keyedvectors.Vocab at 0x7f5354be8950>,
#  '이범수': <gensim.models.keyedvectors.Vocab at 0x7f5354be8990>,
#  '드럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8a10>,
#  '담백하다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8a50>,
#  '깔끔하다': <gensim.models.keyedvectors.Vocab at 0x7f5354be89d0>,
#  '좋다': <gensim.models.keyedvectors.Vocab at 0x7f5354be8a90>,
#  '로만': <gensim.models.keyedvectors.Vocab at 0x7f5354be8ad0>,
#  '자꾸': <gensim.models.keyedvectors.Vocab at 0x7f5354be8b10>,
#  '그': <gensim.models.keyedvectors.Vocab at 0x7f5354be8b50>,
#  '것': <gensim.models.keyedvectors.Vocab at 0x7f5354be8b90>,
#  '취향': <gensim.models.keyedvectors.Vocab at 0x7f5354be8bd0>,
#  '존중': <gensim.models.keyedvectors.Vocab at 0x7f5354be8c10>,
#  '다지': <gensim.models.keyedvectors.Vocab at 0x7f5354be8c50>,
#  '내생': <gensim.models.keyedvectors.Vocab at 0x7f5354be8cd0>,
#  '극장': <gensim.models.keyedvectors.Vocab at 0x7f5354be8d10>,
#  '가장': <gensim.models.keyedvectors.Vocab at 0x7f5354be8c90>,
#  '노잼': <gensim.models.keyedvectors.Vocab at 0x7f5354be8d50>,
#  '노': <gensim.models.keyedvectors.Vocab at 0x7f5354be8d90>,
#  '감동': <gensim.models.keyedvectors.Vocab at 0x7f5354be8dd0>,
#  '임': <gensim.models.keyedvectors.Vocab at 0x7f5354be8e10>,
#  '스토리': <gensim.models.keyedvectors.Vocab at 0x7f5354be8e50>,
#  '어거지': <gensim.models.keyedvectors.Vocab at 0x7f5354be8e90>,
#  '냥': <gensim.models.keyedvectors.Vocab at 0x7f5354be8ed0>,
#  '매번': <gensim.models.keyedvectors.Vocab at 0x7f5354be8f10>,
#  '긴장': <gensim.models.keyedvectors.Vocab at 0x7f5354be8f90>,
#  '재밋음': <gensim.models.keyedvectors.Vocab at 0x7f5354be8fd0>,
#  '바스코': <gensim.models.keyedvectors.Vocab at 0x7f5354be8f50>,
#  '이기': <gensim.models.keyedvectors.Vocab at 0x7f5354bea050>,
#  '락스': <gensim.models.keyedvectors.Vocab at 0x7f5354bea090>,
#  '코': <gensim.models.keyedvectors.Vocab at 0x7f5354bea0d0>,
#  '바비': <gensim.models.keyedvectors.Vocab at 0x7f5354bea110>,
#  '아이돌': <gensim.models.keyedvectors.Vocab at 0x7f5354bea150>,
#  '그냥': <gensim.models.keyedvectors.Vocab at 0x7f5354bea190>,
#  '안달': <gensim.models.keyedvectors.Vocab at 0x7f5354bea1d0>,
#  '굿바이': <gensim.models.keyedvectors.Vocab at 0x7f5354bea210>,
#  '레닌': <gensim.models.keyedvectors.Vocab at 0x7f5354bea250>,
#  '표절': <gensim.models.keyedvectors.Vocab at 0x7f5354bea290>,
#  '이해': <gensim.models.keyedvectors.Vocab at 0x7f5354bea2d0>,
#  '왜': <gensim.models.keyedvectors.Vocab at 0x7f5354bea310>,
#  '뒤': <gensim.models.keyedvectors.Vocab at 0x7f5354bea350>,
#  '갈수록': <gensim.models.keyedvectors.Vocab at 0x7f5354bea390>,
#  '이건': <gensim.models.keyedvectors.Vocab at 0x7f5354bea3d0>,
#  '깨알': <gensim.models.keyedvectors.Vocab at 0x7f5354bea410>,
#  '캐스팅': <gensim.models.keyedvectors.Vocab at 0x7f5354bea450>,
#  '산뜻하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea490>,
#  '용구성': <gensim.models.keyedvectors.Vocab at 0x7f5354bea4d0>,
#  '일드': <gensim.models.keyedvectors.Vocab at 0x7f5354bea510>,
#  '위': <gensim.models.keyedvectors.Vocab at 0x7f5354bea550>,
#  '변명': <gensim.models.keyedvectors.Vocab at 0x7f5354bea590>,
#  '놈': <gensim.models.keyedvectors.Vocab at 0x7f5354bea5d0>,
#  '착하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea610>,
#  '절대': <gensim.models.keyedvectors.Vocab at 0x7f5354bea650>,
#  '아니다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea690>,
#  '걸': <gensim.models.keyedvectors.Vocab at 0x7f5354bea6d0>,
#  '나름': <gensim.models.keyedvectors.Vocab at 0x7f5354bea710>,
#  '심오하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea750>,
#  '뜻': <gensim.models.keyedvectors.Vocab at 0x7f5354bea790>,
#  '듯': <gensim.models.keyedvectors.Vocab at 0x7f5354bea7d0>,
#  '학생': <gensim.models.keyedvectors.Vocab at 0x7f5354bea810>,
#  '선생': <gensim.models.keyedvectors.Vocab at 0x7f5354bea850>,
#  '재미없다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea890>,
#  '지루하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea8d0>,
#  '같다': <gensim.models.keyedvectors.Vocab at 0x7f5354bea910>,
#  '음식': <gensim.models.keyedvectors.Vocab at 0x7f5354bea950>,
#  '도': <gensim.models.keyedvectors.Vocab at 0x7f5354bea990>,
#  '만찬': <gensim.models.keyedvectors.Vocab at 0x7f5354bea9d0>,
#  '별로': <gensim.models.keyedvectors.Vocab at 0x7f5354beaa10>,
#  '핀란드': <gensim.models.keyedvectors.Vocab at 0x7f5354beaa50>,
#  '풍경': <gensim.models.keyedvectors.Vocab at 0x7f5354beaa90>,
#  '평범하다': <gensim.models.keyedvectors.Vocab at 0x7f5354beaad0>,
#  '수작': <gensim.models.keyedvectors.Vocab at 0x7f5354beab10>,
#  '는걸': <gensim.models.keyedvectors.Vocab at 0x7f5354beab50>,
#  '주제': <gensim.models.keyedvectors.Vocab at 0x7f5354beab90>,
#  '중반': <gensim.models.keyedvectors.Vocab at 0x7f5354beabd0>,
#  '납득': <gensim.models.keyedvectors.Vocab at 0x7f5354beac10>,
#  '수': <gensim.models.keyedvectors.Vocab at 0x7f5354beac50>,
#  '그렇다': <gensim.models.keyedvectors.Vocab at 0x7f5354beac90>,
#  '꼭': <gensim.models.keyedvectors.Vocab at 0x7f5354beacd0>,
#  '카밀라': <gensim.models.keyedvectors.Vocab at 0x7f5354bead10>,
#  '벨': <gensim.models.keyedvectors.Vocab at 0x7f5354bead50>,
#  '발연기': <gensim.models.keyedvectors.Vocab at 0x7f5354bead90>,
#  '센스': <gensim.models.keyedvectors.Vocab at 0x7f5354beadd0>,
#  '연출': <gensim.models.keyedvectors.Vocab at 0x7f5354beae10>,
#  '탁월하다': <gensim.models.keyedvectors.Vocab at 0x7f5354beae50>,
#  '점': <gensim.models.keyedvectors.Vocab at 0x7f5354beae90>,
#  '위력': <gensim.models.keyedvectors.Vocab at 0x7f5354beaed0>,
#  '다시': <gensim.models.keyedvectors.Vocab at 0x7f5354beaf10>,
#  '한번': <gensim.models.keyedvectors.Vocab at 0x7f5354beaf50>,
#  '적': <gensim.models.keyedvectors.Vocab at 0x7f5354beaf90>,
#  '남': <gensim.models.keyedvectors.Vocab at 0x7f5354beafd0>,
#  '꽃': <gensim.models.keyedvectors.Vocab at 0x7f5354bed050>,
#  '검사': <gensim.models.keyedvectors.Vocab at 0x7f5354bed090>,
#  '완전': <gensim.models.keyedvectors.Vocab at 0x7f5354bed0d0>,
#  '명품': <gensim.models.keyedvectors.Vocab at 0x7f5354bed110>,
#  '졸': <gensim.models.keyedvectors.Vocab at 0x7f5354bed150>,
#  '쓰레기': <gensim.models.keyedvectors.Vocab at 0x7f5354bed190>,
#  '진부하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed1d0>,
#  '도안': <gensim.models.keyedvectors.Vocab at 0x7f5354bed210>,
#  '시간': <gensim.models.keyedvectors.Vocab at 0x7f5354bed250>,
#  '재밌다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed2d0>,
#  '기대하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed310>,
#  '내': <gensim.models.keyedvectors.Vocab at 0x7f5354bed290>,
#  '죄인': <gensim.models.keyedvectors.Vocab at 0x7f5354bed350>,
#  '이다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed390>,
#  '이': <gensim.models.keyedvectors.Vocab at 0x7f5354bed3d0>,
#  '인생': <gensim.models.keyedvectors.Vocab at 0x7f5354bed410>,
#  '최고': <gensim.models.keyedvectors.Vocab at 0x7f5354bed450>,
#  '패션': <gensim.models.keyedvectors.Vocab at 0x7f5354bed490>,
#  '대한': <gensim.models.keyedvectors.Vocab at 0x7f5354bed4d0>,
#  '열정': <gensim.models.keyedvectors.Vocab at 0x7f5354bed510>,
#  '안나': <gensim.models.keyedvectors.Vocab at 0x7f5354bed550>,
#  '윈': <gensim.models.keyedvectors.Vocab at 0x7f5354bed590>,
#  '투어': <gensim.models.keyedvectors.Vocab at 0x7f5354bed5d0>,
#  '키이라': <gensim.models.keyedvectors.Vocab at 0x7f5354bed610>,
#  '나이틀리': <gensim.models.keyedvectors.Vocab at 0x7f5354bed650>,
#  '대체': <gensim.models.keyedvectors.Vocab at 0x7f5354bed690>,
#  '정신': <gensim.models.keyedvectors.Vocab at 0x7f5354bed6d0>,
#  '유령': <gensim.models.keyedvectors.Vocab at 0x7f5354bed710>,
#  '재미있다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed750>,
#  '관객': <gensim.models.keyedvectors.Vocab at 0x7f5354bed790>,
#  '명': <gensim.models.keyedvectors.Vocab at 0x7f5354bed7d0>,
#  '평가': <gensim.models.keyedvectors.Vocab at 0x7f5354bed810>,
#  '단순하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed850>,
#  '은은하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed890>,
#  '매력': <gensim.models.keyedvectors.Vocab at 0x7f5354bed8d0>,
#  '알바생': <gensim.models.keyedvectors.Vocab at 0x7f5354bed910>,
#  '내용': <gensim.models.keyedvectors.Vocab at 0x7f5354bed950>,
#  '무섭다': <gensim.models.keyedvectors.Vocab at 0x7f5354bed990>,
#  '하나': <gensim.models.keyedvectors.Vocab at 0x7f5354bed9d0>,
#  '싱겁다': <gensim.models.keyedvectors.Vocab at 0x7f5354beda10>,
#  '낚임': <gensim.models.keyedvectors.Vocab at 0x7f5354beda50>,
#  '맘': <gensim.models.keyedvectors.Vocab at 0x7f5354beda90>,
#  '또': <gensim.models.keyedvectors.Vocab at 0x7f5354bedad0>,
#  '방법': <gensim.models.keyedvectors.Vocab at 0x7f5354bedb10>,
#  '윤제문': <gensim.models.keyedvectors.Vocab at 0x7f5354bedb50>,
#  '멋지다': <gensim.models.keyedvectors.Vocab at 0x7f5354bedb90>,
#  '배우': <gensim.models.keyedvectors.Vocab at 0x7f5354bedbd0>,
#  '발견': <gensim.models.keyedvectors.Vocab at 0x7f5354bedc10>,
#  '소소하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bedc50>,
#  '탈': <gensim.models.keyedvectors.Vocab at 0x7f5354bedc90>,
#  '잔잔하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bedcd0>,
#  '미소': <gensim.models.keyedvectors.Vocab at 0x7f5354bedd10>,
#  '머금': <gensim.models.keyedvectors.Vocab at 0x7f5354bedd50>,
#  '음악': <gensim.models.keyedvectors.Vocab at 0x7f5354bedd90>,
#  '조금': <gensim.models.keyedvectors.Vocab at 0x7f5354beddd0>,
#  '아쉽다': <gensim.models.keyedvectors.Vocab at 0x7f5354bede10>,
#  '속지': <gensim.models.keyedvectors.Vocab at 0x7f5354bede50>,
#  '낭비': <gensim.models.keyedvectors.Vocab at 0x7f5354bede90>,
#  '돈': <gensim.models.keyedvectors.Vocab at 0x7f5354beded0>,
#  '리얼리티': <gensim.models.keyedvectors.Vocab at 0x7f5354bedf10>,
#  '뛰어나다': <gensim.models.keyedvectors.Vocab at 0x7f5354bedf50>,
#  '공감': <gensim.models.keyedvectors.Vocab at 0x7f5354bedf90>,
#  '안': <gensim.models.keyedvectors.Vocab at 0x7f5354bedfd0>,
#  '간다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0050>,
#  '이민기': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0090>,
#  '캐릭터': <gensim.models.keyedvectors.Vocab at 0x7f5354bf00d0>,
#  '분노조절': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0110>,
#  '장애': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0150>,
#  '초기': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0190>,
#  '툭하면': <gensim.models.keyedvectors.Vocab at 0x7f5354bf01d0>,
#  '패': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0210>,
#  '물건': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0250>,
#  '바': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0290>,
#  '초반': <gensim.models.keyedvectors.Vocab at 0x7f5354bf02d0>,
#  '신선하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0310>,
#  '가면': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0350>,
#  '상태': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0390>,
#  '불가': <gensim.models.keyedvectors.Vocab at 0x7f5354bf03d0>,
#  '마이너스': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0410>,
#  '뮤비': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0450>,
#  '수준': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0490>,
#  '알': <gensim.models.keyedvectors.Vocab at 0x7f5354bf04d0>,
#  '북한': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0510>,
#  '이렇다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0550>,
#  '난': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0590>,
#  '우리': <gensim.models.keyedvectors.Vocab at 0x7f5354bf05d0>,
#  '사랑': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0610>,
#  '리스': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0650>,
#  '타르': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0690>,
#  '용의': <gensim.models.keyedvectors.Vocab at 0x7f5354bf06d0>,
#  '주인': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0710>,
#  '누': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0750>,
#  '근친상간': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0790>,
#  '소설': <gensim.models.keyedvectors.Vocab at 0x7f5354bf07d0>,
#  '속': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0810>,
#  '제일': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0850>,
#  '자': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0890>,
#  '메': <gensim.models.keyedvectors.Vocab at 0x7f5354bf08d0>,
#  '니스': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0910>,
#  '터': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0950>,
#  '드래곤': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0990>,
#  '용': <gensim.models.keyedvectors.Vocab at 0x7f5354bf09d0>,
#  '웃음': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0a10>,
#  '감독': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0a50>,
#  '토르': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0a90>,
#  '다크': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0ad0>,
#  '월드': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0b10>,
#  '말': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0b50>,
#  '기본': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0b90>,
#  '영혼': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0bd0>,
#  '수도': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0c10>,
#  '상사': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0c50>,
#  '잠시': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0c90>,
#  '동화': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0cd0>,
#  '행복하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0d10>,
#  '세르게이': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0d50>,
#  '작다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0d90>,
#  '고추': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0dd0>,
#  '맵다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0e10>,
#  '맛': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0e50>,
#  '저그': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0e90>,
#  '콩': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0ed0>,
#  '진호': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0f10>,
#  '가슴': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0f50>,
#  '시리': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0f90>,
#  '자체': <gensim.models.keyedvectors.Vocab at 0x7f5354bf0fd0>,
#  '난또': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4050>,
#  '저': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4090>,
#  '꼬마': <gensim.models.keyedvectors.Vocab at 0x7f5354bf40d0>,
#  '애가': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4110>,
#  '무슨': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4150>,
#  '원한': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4190>,
#  '깊다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf41d0>,
#  '혼자': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4210>,
#  '충격': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4250>,
#  '기분': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4290>,
#  '완전하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf42d0>,
#  '푹': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4310>,
#  '느낌': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4350>,
#  '활': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4390>,
#  '무겁다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf43d0>,
#  '지독하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4410>,
#  '차갑다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4450>,
#  '무자비하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4490>,
#  '일본인': <gensim.models.keyedvectors.Vocab at 0x7f5354bf44d0>,
#  '상상력': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4510>,
#  '대단하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4550>,
#  '생각': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4590>,
#  '그대로': <gensim.models.keyedvectors.Vocab at 0x7f5354bf45d0>,
#  '예측': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4610>,
#  '카리스마': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4650>,
#  '악역': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4690>,
#  '당황': <gensim.models.keyedvectors.Vocab at 0x7f5354bf46d0>,
#  '중간': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4710>,
#  '일상': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4750>,
#  '밋밋하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4790>,
#  '계속': <gensim.models.keyedvectors.Vocab at 0x7f5354bf47d0>,
#  '전개도': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4810>,
#  '느리다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4850>,
#  '주인공': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4890>,
#  '은희': <gensim.models.keyedvectors.Vocab at 0x7f5354bf48d0>,
#  '컷': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4910>,
#  '극적': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4950>,
#  '모습': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4990>,
#  '짜증': <gensim.models.keyedvectors.Vocab at 0x7f5354bf49d0>,
#  '언제': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4a10>,
#  '대만': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4a50>,
#  '전개': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4a90>,
#  '좀': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4ad0>,
#  '가슴속': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4b10>,
#  '감정': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4b50>,
#  '많다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4b90>,
#  '다큐': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4bd0>,
#  '우리나라': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4c10>,
#  '슬프다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4c50>,
#  '현대': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4c90>,
#  '사의': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4cd0>,
#  '단면': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4d10>,
#  '대해': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4d50>,
#  '깊이': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4d90>,
#  '사죄': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4dd0>,
#  '바로': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4e10>,
#  '잡기': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4e50>,
#  '위해': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4e90>,
#  '노력': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4ed0>,
#  '말로': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4f10>,
#  '보도': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4f50>,
#  '민간인': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4f90>,
#  '학살': <gensim.models.keyedvectors.Vocab at 0x7f5354bf4fd0>,
#  '이정': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7050>,
#  '일': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7090>,
#  '명백하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf70d0>,
#  '살인': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7110>,
#  '살인자': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7150>,
#  '어디': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7190>,
#  '예전': <gensim.models.keyedvectors.Vocab at 0x7f5354bf71d0>,
#  '작품': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7210>,
#  '에피소드': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7250>,
#  '재탕': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7290>,
#  '탕': <gensim.models.keyedvectors.Vocab at 0x7f5354bf72d0>,
#  '사골': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7310>,
#  '우려': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7350>,
#  '먹듯': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7390>,
#  '산': <gensim.models.keyedvectors.Vocab at 0x7f5354bf73d0>,
#  '시청률': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7410>,
#  '아예': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7450>,
#  '이제': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7490>,
#  '부작': <gensim.models.keyedvectors.Vocab at 0x7f5354bf74d0>,
#  '김남길': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7510>,
#  '연기력': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7550>,
#  '몰입도': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7590>,
#  '불구': <gensim.models.keyedvectors.Vocab at 0x7f5354bf75d0>,
#  '손예진': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7610>,
#  '비슷하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7650>,
#  '분': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7690>,
#  '노래실력': <gensim.models.keyedvectors.Vocab at 0x7f5354bf76d0>,
#  '박시환': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7710>,
#  '망신': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7750>,
#  '일본': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7790>,
#  '건가': <gensim.models.keyedvectors.Vocab at 0x7f5354bf77d0>,
#  '유치하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7810>,
#  '이틀': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7850>,
#  '차': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7890>,
#  '조작': <gensim.models.keyedvectors.Vocab at 0x7f5354bf78d0>,
#  '안이': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7910>,
#  '집': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7950>,
#  '활짝': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7990>,
#  '아무나': <gensim.models.keyedvectors.Vocab at 0x7f5354bf79d0>,
#  '문자': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7a10>,
#  '건': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7a50>,
#  '억지스럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7a90>,
#  '재밋네': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7ad0>,
#  '달팽이': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7b10>,
#  '빨': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7b50>,
#  '더': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7b90>,
#  '어설프다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7bd0>,
#  '어이없다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7c10>,
#  '결말': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7c50>,
#  '부패하다': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7c90>,
#  '기리': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7cd0>,
#  '뭣같': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7d10>,
#  '온몸': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7d50>,
#  '러시아': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7d90>,
#  '민중': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7dd0>,
#  '폭도': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7e10>,
#  '무난': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7e50>,
#  '한국영': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7e90>,
#  '흥행': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7ed0>,
#  '코드': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7f10>,
#  '갈등': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7f50>,
#  '계': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7f90>,
#  '화해': <gensim.models.keyedvectors.Vocab at 0x7f5354bf7fd0>,
#  '남발': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a050>,
#  '뻔하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a090>,
#  '뭐': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a0d0>,
#  '시작': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a110>,
#  '사진': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a150>,
#  '불안하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a190>,
#  '럼': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a1d0>,
#  '뭘': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a210>,
#  '엉망': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a250>,
#  '진창': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a290>,
#  '개': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a2d0>,
#  '우뢰매': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a310>,
#  '진정': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a350>,
#  '위대하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a390>,
#  '조미': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a3d0>,
#  '좋아하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a410>,
#  '가요': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a450>,
#  '눈': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a490>,
#  '성룡': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a4d0>,
#  '최악': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a510>,
#  '골': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a550>,
#  '인공': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a590>,
#  '강추': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a5d0>,
#  '클라라': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a610>,
#  '볼라': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a650>,
#  '화신': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a690>,
#  '설정': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a6d0>,
#  '새롭다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a710>,
#  '메인': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a750>,
#  '마코토': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a790>,
#  '작화': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a7d0>,
#  '밉다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a810>,
#  '유': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a850>,
#  '대박': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a890>,
#  '진심': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a8d0>,
#  '못': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a910>,
#  '노골': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a950>,
#  '술': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a990>,
#  '광고': <gensim.models.keyedvectors.Vocab at 0x7f5354b7a9d0>,
#  '어떻다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7aa10>,
#  '행복': <gensim.models.keyedvectors.Vocab at 0x7f5354b7aa50>,
#  '요': <gensim.models.keyedvectors.Vocab at 0x7f5354b7aa90>,
#  '쫌': <gensim.models.keyedvectors.Vocab at 0x7f5354b7aad0>,
#  '산만하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ab10>,
#  '처음': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ab50>,
#  '불륜': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ab90>,
#  '로맨스': <gensim.models.keyedvectors.Vocab at 0x7f5354b7abd0>,
#  '왕': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ac10>,
#  '아주': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ac50>,
#  '짬뽕': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ac90>,
#  '믹스': <gensim.models.keyedvectors.Vocab at 0x7f5354b7acd0>,
#  '음향': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ad10>,
#  '기준': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ad50>,
#  '패널': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ad90>,
#  '가구': <gensim.models.keyedvectors.Vocab at 0x7f5354b7add0>,
#  '머': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ae10>,
#  '명작': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ae50>,
#  '망치': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ae90>,
#  '서운하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7aed0>,
#  '몬스터': <gensim.models.keyedvectors.Vocab at 0x7f5354b7af10>,
#  '주식회사': <gensim.models.keyedvectors.Vocab at 0x7f5354b7af50>,
#  '소재': <gensim.models.keyedvectors.Vocab at 0x7f5354b7af90>,
#  '흥미': <gensim.models.keyedvectors.Vocab at 0x7f5354b7afd0>,
#  '끌': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e050>,
#  '투': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e090>,
#  '박하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e0d0>,
#  '몰입': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e110>,
#  '중국인': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e150>,
#  '특유': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e190>,
#  '과장': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e1d0>,
#  '허풍': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e210>,
#  '가상하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e250>,
#  '고증': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e290>,
#  '실감': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e2d0>,
#  '거북': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e310>,
#  '스럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e350>,
#  '도대체': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e390>,
#  '스스로': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e3d0>,
#  '과대': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e410>,
#  '포장': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e450>,
#  '불법체류자': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e490>,
#  '미국': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e4d0>,
#  '따뜻하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e510>,
#  '뭥미': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e550>,
#  '삶속': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e590>,
#  '생애': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e5d0>,
#  '전부': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e610>,
#  '지난': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e650>,
#  '후': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e690>,
#  '지나': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e6d0>,
#  '순수하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e710>,
#  '숀펜': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e750>,
#  '또한': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e790>,
#  '올레': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e7d0>,
#  '공짜': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e810>,
#  '문제': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e850>,
#  '연기자': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e890>,
#  '전혀': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e8d0>,
#  '배역': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e910>,
#  '상대': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e950>,
#  '보아': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e990>,
#  '라미란': <gensim.models.keyedvectors.Vocab at 0x7f5354b7e9d0>,
#  '아들': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ea10>,
#  '젤': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ea50>,
#  '욕심': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ea90>,
#  '쪽': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ead0>,
#  '베댓': <gensim.models.keyedvectors.Vocab at 0x7f5354b7eb10>,
#  '도둑': <gensim.models.keyedvectors.Vocab at 0x7f5354b7eb50>,
#  '뫼비우스': <gensim.models.keyedvectors.Vocab at 0x7f5354b7eb90>,
#  '나라': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ebd0>,
#  '짜릿': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ec10>,
#  '나': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ec50>,
#  '용기': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ec90>,
#  '교훈': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ecd0>,
#  '화이': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ed10>,
#  '당시': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ed50>,
#  '상황': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ed90>,
#  '주입': <gensim.models.keyedvectors.Vocab at 0x7f5354b7edd0>,
#  '식이': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ee10>,
#  '전하': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ee50>,
#  '다르덴': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ee90>,
#  '채': <gensim.models.keyedvectors.Vocab at 0x7f5354b7eed0>,
#  '그릇': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ef10>,
#  '여군': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ef50>,
#  '잼': <gensim.models.keyedvectors.Vocab at 0x7f5354b7ef90>,
#  '엠비씨': <gensim.models.keyedvectors.Vocab at 0x7f5354b7efd0>,
#  '한석규': <gensim.models.keyedvectors.Vocab at 0x7f5354b82050>,
#  '김혜수': <gensim.models.keyedvectors.Vocab at 0x7f5354b82090>,
#  '어딘': <gensim.models.keyedvectors.Vocab at 0x7f5354b820d0>,
#  '바이러스': <gensim.models.keyedvectors.Vocab at 0x7f5354b82110>,
#  '해': <gensim.models.keyedvectors.Vocab at 0x7f5354b82150>,
#  '면': <gensim.models.keyedvectors.Vocab at 0x7f5354b82190>,
#  '년전': <gensim.models.keyedvectors.Vocab at 0x7f5354b821d0>,
#  '보기': <gensim.models.keyedvectors.Vocab at 0x7f5354b82210>,
#  '힘들다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82250>,
#  '정도': <gensim.models.keyedvectors.Vocab at 0x7f5354b82290>,
#  '마지막': <gensim.models.keyedvectors.Vocab at 0x7f5354b822d0>,
#  '후반': <gensim.models.keyedvectors.Vocab at 0x7f5354b82310>,
#  '부가': <gensim.models.keyedvectors.Vocab at 0x7f5354b82350>,
#  '살짝': <gensim.models.keyedvectors.Vocab at 0x7f5354b82390>,
#  '용가리': <gensim.models.keyedvectors.Vocab at 0x7f5354b823d0>,
#  '짱짱맨': <gensim.models.keyedvectors.Vocab at 0x7f5354b82410>,
#  '감히': <gensim.models.keyedvectors.Vocab at 0x7f5354b82450>,
#  '하나로': <gensim.models.keyedvectors.Vocab at 0x7f5354b82490>,
#  '꼽': <gensim.models.keyedvectors.Vocab at 0x7f5354b824d0>,
#  '살': <gensim.models.keyedvectors.Vocab at 0x7f5354b82510>,
#  '야하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82550>,
#  '고민': <gensim.models.keyedvectors.Vocab at 0x7f5354b82590>,
#  '모건': <gensim.models.keyedvectors.Vocab at 0x7f5354b825d0>,
#  '프리': <gensim.models.keyedvectors.Vocab at 0x7f5354b82610>,
#  '멀다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82650>,
#  '나이': <gensim.models.keyedvectors.Vocab at 0x7f5354b82690>,
#  '여전하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b826d0>,
#  '섹시하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82710>,
#  '작가': <gensim.models.keyedvectors.Vocab at 0x7f5354b82750>,
#  '용이': <gensim.models.keyedvectors.Vocab at 0x7f5354b82790>,
#  '기대': <gensim.models.keyedvectors.Vocab at 0x7f5354b827d0>,
#  '재방송': <gensim.models.keyedvectors.Vocab at 0x7f5354b82810>,
#  '혹': <gensim.models.keyedvectors.Vocab at 0x7f5354b82850>,
#  '시나': <gensim.models.keyedvectors.Vocab at 0x7f5354b82890>,
#  '답': <gensim.models.keyedvectors.Vocab at 0x7f5354b828d0>,
#  '여운': <gensim.models.keyedvectors.Vocab at 0x7f5354b82910>,
#  '왠만하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82950>,
#  '상업': <gensim.models.keyedvectors.Vocab at 0x7f5354b82990>,
#  '퀄리티': <gensim.models.keyedvectors.Vocab at 0x7f5354b829d0>,
#  '질': <gensim.models.keyedvectors.Vocab at 0x7f5354b82a10>,
#  '충분하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82a50>,
#  '개인': <gensim.models.keyedvectors.Vocab at 0x7f5354b82a90>,
#  '잔인하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82ad0>,
#  '노출씬': <gensim.models.keyedvectors.Vocab at 0x7f5354b82b10>,
#  '화끈하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82b50>,
#  '국산': <gensim.models.keyedvectors.Vocab at 0x7f5354b82b90>,
#  '보임': <gensim.models.keyedvectors.Vocab at 0x7f5354b82bd0>,
#  '끝내': <gensim.models.keyedvectors.Vocab at 0x7f5354b82c10>,
#  '지겹다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82c50>,
#  '역시': <gensim.models.keyedvectors.Vocab at 0x7f5354b82c90>,
#  '드니': <gensim.models.keyedvectors.Vocab at 0x7f5354b82cd0>,
#  '일품': <gensim.models.keyedvectors.Vocab at 0x7f5354b82d10>,
#  '맥스': <gensim.models.keyedvectors.Vocab at 0x7f5354b82d50>,
#  '샘': <gensim.models.keyedvectors.Vocab at 0x7f5354b82d90>,
#  '바랬다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82dd0>,
#  '괜찮다': <gensim.models.keyedvectors.Vocab at 0x7f5354b82e10>,
#  '실망': <gensim.models.keyedvectors.Vocab at 0x7f5354b82e50>,
#  '지네': <gensim.models.keyedvectors.Vocab at 0x7f5354b82e90>,
#  '면상': <gensim.models.keyedvectors.Vocab at 0x7f5354b82ed0>,
#  '자신': <gensim.models.keyedvectors.Vocab at 0x7f5354b82f10>,
#  '어린이': <gensim.models.keyedvectors.Vocab at 0x7f5354b82f50>,
#  '동심': <gensim.models.keyedvectors.Vocab at 0x7f5354b82f90>,
#  '멀리': <gensim.models.keyedvectors.Vocab at 0x7f5354b82fd0>,
#  '무술': <gensim.models.keyedvectors.Vocab at 0x7f5354b85050>,
#  '크리스토퍼': <gensim.models.keyedvectors.Vocab at 0x7f5354b85090>,
#  '왈츠': <gensim.models.keyedvectors.Vocab at 0x7f5354b850d0>,
#  '타란티노': <gensim.models.keyedvectors.Vocab at 0x7f5354b85110>,
#  '조합': <gensim.models.keyedvectors.Vocab at 0x7f5354b85150>,
#  '한국': <gensim.models.keyedvectors.Vocab at 0x7f5354b85190>,
#  '유명': <gensim.models.keyedvectors.Vocab at 0x7f5354b851d0>,
#  '한편': <gensim.models.keyedvectors.Vocab at 0x7f5354b85210>,
#  '외국': <gensim.models.keyedvectors.Vocab at 0x7f5354b85250>,
#  '상상': <gensim.models.keyedvectors.Vocab at 0x7f5354b85290>,
#  '초월': <gensim.models.keyedvectors.Vocab at 0x7f5354b852d0>,
#  '유명하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85310>,
#  '만': <gensim.models.keyedvectors.Vocab at 0x7f5354b85350>,
#  '재밋': <gensim.models.keyedvectors.Vocab at 0x7f5354b85390>,
#  '종방': <gensim.models.keyedvectors.Vocab at 0x7f5354b853d0>,
#  '오늘': <gensim.models.keyedvectors.Vocab at 0x7f5354b85410>,
#  '방도': <gensim.models.keyedvectors.Vocab at 0x7f5354b85450>,
#  '방송': <gensim.models.keyedvectors.Vocab at 0x7f5354b85490>,
#  '대본': <gensim.models.keyedvectors.Vocab at 0x7f5354b854d0>,
#  '완성': <gensim.models.keyedvectors.Vocab at 0x7f5354b85510>,
#  '요즘': <gensim.models.keyedvectors.Vocab at 0x7f5354b85550>,
#  '막장': <gensim.models.keyedvectors.Vocab at 0x7f5354b85590>,
#  '수백향': <gensim.models.keyedvectors.Vocab at 0x7f5354b855d0>,
#  '심하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85610>,
#  '화이팅': <gensim.models.keyedvectors.Vocab at 0x7f5354b85650>,
#  '조절': <gensim.models.keyedvectors.Vocab at 0x7f5354b85690>,
#  '위원회': <gensim.models.keyedvectors.Vocab at 0x7f5354b856d0>,
#  '김혜선': <gensim.models.keyedvectors.Vocab at 0x7f5354b85710>,
#  '내일': <gensim.models.keyedvectors.Vocab at 0x7f5354b85750>,
#  '김': <gensim.models.keyedvectors.Vocab at 0x7f5354b85790>,
#  '순정': <gensim.models.keyedvectors.Vocab at 0x7f5354b857d0>,
#  '역할': <gensim.models.keyedvectors.Vocab at 0x7f5354b85810>,
#  '팜므파탈': <gensim.models.keyedvectors.Vocab at 0x7f5354b85850>,
#  '로써': <gensim.models.keyedvectors.Vocab at 0x7f5354b85890>,
#  '의외': <gensim.models.keyedvectors.Vocab at 0x7f5354b858d0>,
#  '사극': <gensim.models.keyedvectors.Vocab at 0x7f5354b85910>,
#  '그녀': <gensim.models.keyedvectors.Vocab at 0x7f5354b85950>,
#  '논란': <gensim.models.keyedvectors.Vocab at 0x7f5354b85990>,
#  '코미디': <gensim.models.keyedvectors.Vocab at 0x7f5354b859d0>,
#  '장면': <gensim.models.keyedvectors.Vocab at 0x7f5354b85a10>,
#  '끝': <gensim.models.keyedvectors.Vocab at 0x7f5354b85a50>,
#  '멍하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85a90>,
#  '한마디': <gensim.models.keyedvectors.Vocab at 0x7f5354b85ad0>,
#  '상쾌': <gensim.models.keyedvectors.Vocab at 0x7f5354b85b10>,
#  '발랄하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85b50>,
#  '성': <gensim.models.keyedvectors.Vocab at 0x7f5354b85b90>,
#  '유쾌하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85bd0>,
#  '해설': <gensim.models.keyedvectors.Vocab at 0x7f5354b85c10>,
#  '소파': <gensim.models.keyedvectors.Vocab at 0x7f5354b85c50>,
#  '죽': <gensim.models.keyedvectors.Vocab at 0x7f5354b85c90>,
#  '이유': <gensim.models.keyedvectors.Vocab at 0x7f5354b85cd0>,
#  '타겟': <gensim.models.keyedvectors.Vocab at 0x7f5354b85d10>,
#  '일반': <gensim.models.keyedvectors.Vocab at 0x7f5354b85d50>,
#  '논리': <gensim.models.keyedvectors.Vocab at 0x7f5354b85d90>,
#  '통': <gensim.models.keyedvectors.Vocab at 0x7f5354b85dd0>,
#  '게임': <gensim.models.keyedvectors.Vocab at 0x7f5354b85e10>,
#  '흥미롭다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85e50>,
#  '요원': <gensim.models.keyedvectors.Vocab at 0x7f5354b85e90>,
#  '무능력하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b85ed0>,
#  '배경': <gensim.models.keyedvectors.Vocab at 0x7f5354b85f10>,
#  '뮤지컬': <gensim.models.keyedvectors.Vocab at 0x7f5354b85f50>,
#  '사운드': <gensim.models.keyedvectors.Vocab at 0x7f5354b85f90>,
#  '녹음': <gensim.models.keyedvectors.Vocab at 0x7f5354b85fd0>,
#  '춤': <gensim.models.keyedvectors.Vocab at 0x7f5354b88050>,
#  '어제': <gensim.models.keyedvectors.Vocab at 0x7f5354b88090>,
#  '말리': <gensim.models.keyedvectors.Vocab at 0x7f5354b880d0>,
#  '영국': <gensim.models.keyedvectors.Vocab at 0x7f5354b88110>,
#  '예산': <gensim.models.keyedvectors.Vocab at 0x7f5354b88150>,
#  '뮤지컬영화': <gensim.models.keyedvectors.Vocab at 0x7f5354b88190>,
#  '맘마미아': <gensim.models.keyedvectors.Vocab at 0x7f5354b881d0>,
#  '로맨틱코미디': <gensim.models.keyedvectors.Vocab at 0x7f5354b88210>,
#  '머임': <gensim.models.keyedvectors.Vocab at 0x7f5354b88250>,
#  '알고싶다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88290>,
#  '스텝': <gensim.models.keyedvectors.Vocab at 0x7f5354b882d0>,
#  '꼭두각시': <gensim.models.keyedvectors.Vocab at 0x7f5354b88310>,
#  '아름답다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88350>,
#  '현대인': <gensim.models.keyedvectors.Vocab at 0x7f5354b88390>,
#  '힘드다': <gensim.models.keyedvectors.Vocab at 0x7f5354b883d0>,
#  '뻑': <gensim.models.keyedvectors.Vocab at 0x7f5354b88410>,
#  '볼걸': <gensim.models.keyedvectors.Vocab at 0x7f5354b88450>,
#  '당하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88490>,
#  '극치': <gensim.models.keyedvectors.Vocab at 0x7f5354b884d0>,
#  '굉장하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88510>,
#  '뚱뚱하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88550>,
#  '남자': <gensim.models.keyedvectors.Vocab at 0x7f5354b88590>,
#  '애': <gensim.models.keyedvectors.Vocab at 0x7f5354b885d0>,
#  '시종일관': <gensim.models.keyedvectors.Vocab at 0x7f5354b88610>,
#  '고역': <gensim.models.keyedvectors.Vocab at 0x7f5354b88650>,
#  '클래식': <gensim.models.keyedvectors.Vocab at 0x7f5354b88690>,
#  '듣기': <gensim.models.keyedvectors.Vocab at 0x7f5354b886d0>,
#  '싫다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88710>,
#  '상당하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88750>,
#  '주기도': <gensim.models.keyedvectors.Vocab at 0x7f5354b88790>,
#  '얼마나': <gensim.models.keyedvectors.Vocab at 0x7f5354b887d0>,
#  '죄송하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88810>,
#  '화가': <gensim.models.keyedvectors.Vocab at 0x7f5354b88850>,
#  '아무': <gensim.models.keyedvectors.Vocab at 0x7f5354b88890>,
#  '보지': <gensim.models.keyedvectors.Vocab at 0x7f5354b888d0>,
#  '티비': <gensim.models.keyedvectors.Vocab at 0x7f5354b88910>,
#  '판': <gensim.models.keyedvectors.Vocab at 0x7f5354b88950>,
#  '거': <gensim.models.keyedvectors.Vocab at 0x7f5354b88990>,
#  '돼지': <gensim.models.keyedvectors.Vocab at 0x7f5354b889d0>,
#  '피': <gensim.models.keyedvectors.Vocab at 0x7f5354b88a10>,
#  '우웩': <gensim.models.keyedvectors.Vocab at 0x7f5354b88a50>,
#  '무당': <gensim.models.keyedvectors.Vocab at 0x7f5354b88a90>,
#  '잠': <gensim.models.keyedvectors.Vocab at 0x7f5354b88ad0>,
#  '류': <gensim.models.keyedvectors.Vocab at 0x7f5354b88b10>,
#  '판타지': <gensim.models.keyedvectors.Vocab at 0x7f5354b88b50>,
#  '복귀': <gensim.models.keyedvectors.Vocab at 0x7f5354b88b90>,
#  '참가자': <gensim.models.keyedvectors.Vocab at 0x7f5354b88bd0>,
#  '실력': <gensim.models.keyedvectors.Vocab at 0x7f5354b88c10>,
#  '전': <gensim.models.keyedvectors.Vocab at 0x7f5354b88c50>,
#  '심사': <gensim.models.keyedvectors.Vocab at 0x7f5354b88c90>,
#  '위원': <gensim.models.keyedvectors.Vocab at 0x7f5354b88cd0>,
#  '인격': <gensim.models.keyedvectors.Vocab at 0x7f5354b88d10>,
#  '어': <gensim.models.keyedvectors.Vocab at 0x7f5354b88d50>,
#  '광장': <gensim.models.keyedvectors.Vocab at 0x7f5354b88d90>,
#  '옛날': <gensim.models.keyedvectors.Vocab at 0x7f5354b88dd0>,
#  '생': <gensim.models.keyedvectors.Vocab at 0x7f5354b88e10>,
#  '어린시절': <gensim.models.keyedvectors.Vocab at 0x7f5354b88e50>,
#  '추억': <gensim.models.keyedvectors.Vocab at 0x7f5354b88e90>,
#  '판타지영화': <gensim.models.keyedvectors.Vocab at 0x7f5354b88ed0>,
#  '나쁘다': <gensim.models.keyedvectors.Vocab at 0x7f5354b88f10>,
#  '금물': <gensim.models.keyedvectors.Vocab at 0x7f5354b88f50>,
#  '지옥': <gensim.models.keyedvectors.Vocab at 0x7f5354b88f90>,
#  '기존': <gensim.models.keyedvectors.Vocab at 0x7f5354b88fd0>,
#  '멜로영화': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c050>,
#  '형식': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c090>,
#  '탈피': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c0d0>,
#  '쏙': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c110>,
#  '후회': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c150>,
#  '이영화': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c190>,
#  '보': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c1d0>,
#  '주네': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c210>,
#  '싸이코': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c250>,
#  '물': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c290>,
#  '개봉': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c2d0>,
#  '접해': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c310>,
#  '사랑스럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c350>,
#  '귀엽다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c390>,
#  '청춘': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c3d0>,
#  '넘치다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c410>,
#  '순간': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c450>,
#  '무한': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c490>,
#  '젊음': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c4d0>,
#  '건담': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c510>,
#  '시리즈': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c550>,
#  '중': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c590>,
#  '최고봉': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c5d0>,
#  '개콘': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c610>,
#  '코너': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c650>,
#  '이안': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c690>,
#  '사다코': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c6d0>,
#  '서린': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c710>,
#  '우물': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c750>,
#  '펀치': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c790>,
#  '후세': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c7d0>,
#  '결정': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c810>,
#  '계기': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c850>,
#  '표현': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c890>,
#  '람': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c8d0>,
#  '생명': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c910>,
#  '등': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c950>,
#  '출현': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c990>,
#  '연극': <gensim.models.keyedvectors.Vocab at 0x7f5354b8c9d0>,
#  '로': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ca10>,
#  '본능': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ca50>,
#  '면서': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ca90>,
#  '시': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cad0>,
#  '새벽': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cb10>,
#  '졸작': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cb50>,
#  '다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cb90>,
#  '강수연': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cbd0>,
#  '신음': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cc10>,
#  '신': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cc50>,
#  '예쁘다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cc90>,
#  '여정': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ccd0>,
#  '재밋어': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cd10>,
#  '배두나': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cd50>,
#  '성적': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cd90>,
#  '호기심': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cdd0>,
#  '필요': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ce10>,
#  '닥치고': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ce50>,
#  '각기': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ce90>,
#  '다른': <gensim.models.keyedvectors.Vocab at 0x7f5354b8ced0>,
#  '파워': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cf10>,
#  '미묘하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cf50>,
#  '응답': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cf90>,
#  '하라': <gensim.models.keyedvectors.Vocab at 0x7f5354b8cfd0>,
#  '은지원': <gensim.models.keyedvectors.Vocab at 0x7f5354b90050>,
#  '웃기': <gensim.models.keyedvectors.Vocab at 0x7f5354b90090>,
#  '배꼽': <gensim.models.keyedvectors.Vocab at 0x7f5354b900d0>,
#  '컴': <gensim.models.keyedvectors.Vocab at 0x7f5354b90110>,
#  '구성': <gensim.models.keyedvectors.Vocab at 0x7f5354b90150>,
#  '부실하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90190>,
#  '네이버': <gensim.models.keyedvectors.Vocab at 0x7f5354b901d0>,
#  '장끌': <gensim.models.keyedvectors.Vocab at 0x7f5354b90210>,
#  '로드': <gensim.models.keyedvectors.Vocab at 0x7f5354b90250>,
#  '몰락': <gensim.models.keyedvectors.Vocab at 0x7f5354b90290>,
#  '오우삼': <gensim.models.keyedvectors.Vocab at 0x7f5354b902d0>,
#  '제적': <gensim.models.keyedvectors.Vocab at 0x7f5354b90310>,
#  '영웅본색': <gensim.models.keyedvectors.Vocab at 0x7f5354b90350>,
#  '현실': <gensim.models.keyedvectors.Vocab at 0x7f5354b90390>,
#  '제로': <gensim.models.keyedvectors.Vocab at 0x7f5354b903d0>,
#  '설레다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90410>,
#  '학창시절': <gensim.models.keyedvectors.Vocab at 0x7f5354b90450>,
#  '그때': <gensim.models.keyedvectors.Vocab at 0x7f5354b90490>,
#  '대사': <gensim.models.keyedvectors.Vocab at 0x7f5354b904d0>,
#  '배경음악': <gensim.models.keyedvectors.Vocab at 0x7f5354b90510>,
#  '높다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90550>,
#  '화남': <gensim.models.keyedvectors.Vocab at 0x7f5354b90590>,
#  '더럽다': <gensim.models.keyedvectors.Vocab at 0x7f5354b905d0>,
#  '형태': <gensim.models.keyedvectors.Vocab at 0x7f5354b90610>,
#  '허무하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90650>,
#  '완벽하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90690>,
#  '영양가': <gensim.models.keyedvectors.Vocab at 0x7f5354b906d0>,
#  '이승기': <gensim.models.keyedvectors.Vocab at 0x7f5354b90710>,
#  '조연': <gensim.models.keyedvectors.Vocab at 0x7f5354b90750>,
#  '꿈': <gensim.models.keyedvectors.Vocab at 0x7f5354b90790>,
#  '특집': <gensim.models.keyedvectors.Vocab at 0x7f5354b907d0>,
#  '프로': <gensim.models.keyedvectors.Vocab at 0x7f5354b90810>,
#  '매우': <gensim.models.keyedvectors.Vocab at 0x7f5354b90850>,
#  '훌륭하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90890>,
#  '미로': <gensim.models.keyedvectors.Vocab at 0x7f5354b908d0>,
#  '급': <gensim.models.keyedvectors.Vocab at 0x7f5354b90910>,
#  '제대': <gensim.models.keyedvectors.Vocab at 0x7f5354b90950>,
#  '마음': <gensim.models.keyedvectors.Vocab at 0x7f5354b90990>,
#  '휴가': <gensim.models.keyedvectors.Vocab at 0x7f5354b909d0>,
#  '소박하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90a10>,
#  '햇살': <gensim.models.keyedvectors.Vocab at 0x7f5354b90a50>,
#  '가득하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b90a90>,
#  '비': <gensim.models.keyedvectors.Vocab at 0x7f5354b90ad0>,
#  '이의': <gensim.models.keyedvectors.Vocab at 0x7f5354b90b10>,
#  '요리': <gensim.models.keyedvectors.Vocab at 0x7f5354b90b50>,
#  '인상': <gensim.models.keyedvectors.Vocab at 0x7f5354b90b90>,
#  '코믹': <gensim.models.keyedvectors.Vocab at 0x7f5354b90bd0>,
#  '짜임새': <gensim.models.keyedvectors.Vocab at 0x7f5354b90c10>,
#  '신현준': <gensim.models.keyedvectors.Vocab at 0x7f5354b90c50>,
#  '황': <gensim.models.keyedvectors.Vocab at 0x7f5354b90c90>,
#  '장군': <gensim.models.keyedvectors.Vocab at 0x7f5354b90cd0>,
#  '음': <gensim.models.keyedvectors.Vocab at 0x7f5354b90d10>,
#  '대가': <gensim.models.keyedvectors.Vocab at 0x7f5354b90d50>,
#  '일단': <gensim.models.keyedvectors.Vocab at 0x7f5354b90d90>,
#  '재생': <gensim.models.keyedvectors.Vocab at 0x7f5354b90dd0>,
#  '괴물': <gensim.models.keyedvectors.Vocab at 0x7f5354b90e10>,
#  '서스펜스': <gensim.models.keyedvectors.Vocab at 0x7f5354b90e50>,
#  '귀신': <gensim.models.keyedvectors.Vocab at 0x7f5354b90e90>,
#  '흡입': <gensim.models.keyedvectors.Vocab at 0x7f5354b90ed0>,
#  '댓글': <gensim.models.keyedvectors.Vocab at 0x7f5354b90f10>,
#  '기': <gensim.models.keyedvectors.Vocab at 0x7f5354b90f50>,
#  '게': <gensim.models.keyedvectors.Vocab at 0x7f5354b90f90>,
#  '버킷리스트': <gensim.models.keyedvectors.Vocab at 0x7f5354b90fd0>,
#  '직전': <gensim.models.keyedvectors.Vocab at 0x7f5354b93050>,
#  '소원': <gensim.models.keyedvectors.Vocab at 0x7f5354b93090>,
#  '란': <gensim.models.keyedvectors.Vocab at 0x7f5354b930d0>,
#  '발톱': <gensim.models.keyedvectors.Vocab at 0x7f5354b93110>,
#  '완존': <gensim.models.keyedvectors.Vocab at 0x7f5354b93150>,
#  '긍정': <gensim.models.keyedvectors.Vocab at 0x7f5354b93190>,
#  '역': <gensim.models.keyedvectors.Vocab at 0x7f5354b931d0>,
#  '이그': <gensim.models.keyedvectors.Vocab at 0x7f5354b93210>,
#  '기도': <gensim.models.keyedvectors.Vocab at 0x7f5354b93250>,
#  '시원하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93290>,
#  '답답하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b932d0>,
#  '낼': <gensim.models.keyedvectors.Vocab at 0x7f5354b93310>,
#  '월요일': <gensim.models.keyedvectors.Vocab at 0x7f5354b93350>,
#  '해피': <gensim.models.keyedvectors.Vocab at 0x7f5354b93390>,
#  '정치인': <gensim.models.keyedvectors.Vocab at 0x7f5354b933d0>,
#  '모순': <gensim.models.keyedvectors.Vocab at 0x7f5354b93410>,
#  '어렵다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93450>,
#  '전쟁': <gensim.models.keyedvectors.Vocab at 0x7f5354b93490>,
#  '묘사': <gensim.models.keyedvectors.Vocab at 0x7f5354b934d0>,
#  '주년': <gensim.models.keyedvectors.Vocab at 0x7f5354b93510>,
#  '극장판': <gensim.models.keyedvectors.Vocab at 0x7f5354b93550>,
#  '재개': <gensim.models.keyedvectors.Vocab at 0x7f5354b93590>,
#  '봉하': <gensim.models.keyedvectors.Vocab at 0x7f5354b935d0>,
#  '개그콘서트': <gensim.models.keyedvectors.Vocab at 0x7f5354b93610>,
#  '전화': <gensim.models.keyedvectors.Vocab at 0x7f5354b93650>,
#  '간': <gensim.models.keyedvectors.Vocab at 0x7f5354b93690>,
#  '서양': <gensim.models.keyedvectors.Vocab at 0x7f5354b936d0>,
#  '두': <gensim.models.keyedvectors.Vocab at 0x7f5354b93710>,
#  '푸하하하': <gensim.models.keyedvectors.Vocab at 0x7f5354b93750>,
#  '세계': <gensim.models.keyedvectors.Vocab at 0x7f5354b93790>,
#  '최초': <gensim.models.keyedvectors.Vocab at 0x7f5354b937d0>,
#  '반공': <gensim.models.keyedvectors.Vocab at 0x7f5354b93810>,
#  '애니매이션': <gensim.models.keyedvectors.Vocab at 0x7f5354b93850>,
#  '역사': <gensim.models.keyedvectors.Vocab at 0x7f5354b93890>,
#  '가치': <gensim.models.keyedvectors.Vocab at 0x7f5354b938d0>,
#  '감각': <gensim.models.keyedvectors.Vocab at 0x7f5354b93910>,
#  '시각': <gensim.models.keyedvectors.Vocab at 0x7f5354b93950>,
#  '색다르다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93990>,
#  '문학': <gensim.models.keyedvectors.Vocab at 0x7f5354b939d0>,
#  '엄마': <gensim.models.keyedvectors.Vocab at 0x7f5354b93a10>,
#  '무고': <gensim.models.keyedvectors.Vocab at 0x7f5354b93a50>,
#  '딸': <gensim.models.keyedvectors.Vocab at 0x7f5354b93a90>,
#  '제발': <gensim.models.keyedvectors.Vocab at 0x7f5354b93ad0>,
#  '책': <gensim.models.keyedvectors.Vocab at 0x7f5354b93b10>,
#  '미치다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93b50>,
#  '날': <gensim.models.keyedvectors.Vocab at 0x7f5354b93b90>,
#  '신나다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93bd0>,
#  '아이스': <gensim.models.keyedvectors.Vocab at 0x7f5354b93c10>,
#  '큐브': <gensim.models.keyedvectors.Vocab at 0x7f5354b93c50>,
#  '뿐': <gensim.models.keyedvectors.Vocab at 0x7f5354b93c90>,
#  '건데': <gensim.models.keyedvectors.Vocab at 0x7f5354b93cd0>,
#  '생생하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93d10>,
#  '이상하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b93d50>,
#  '옥소리': <gensim.models.keyedvectors.Vocab at 0x7f5354b93d90>,
#  '프로필': <gensim.models.keyedvectors.Vocab at 0x7f5354b93dd0>,
#  '아우': <gensim.models.keyedvectors.Vocab at 0x7f5354b93e10>,
#  '짱짱': <gensim.models.keyedvectors.Vocab at 0x7f5354b93e50>,
#  '시절': <gensim.models.keyedvectors.Vocab at 0x7f5354b93e90>,
#  '부터': <gensim.models.keyedvectors.Vocab at 0x7f5354b93ed0>,
#  '이적': <gensim.models.keyedvectors.Vocab at 0x7f5354b93f10>,
#  '액션영화': <gensim.models.keyedvectors.Vocab at 0x7f5354b93f50>,
#  '범죄': <gensim.models.keyedvectors.Vocab at 0x7f5354b93f90>,
#  '느와르': <gensim.models.keyedvectors.Vocab at 0x7f5354b93fd0>,
#  '영화롭다': <gensim.models.keyedvectors.Vocab at 0x7f5354b96050>,
#  '실패': <gensim.models.keyedvectors.Vocab at 0x7f5354b96090>,
#  '작': <gensim.models.keyedvectors.Vocab at 0x7f5354b960d0>,
#  '뭔가': <gensim.models.keyedvectors.Vocab at 0x7f5354b96110>,
#  '모녀': <gensim.models.keyedvectors.Vocab at 0x7f5354b96150>,
#  '토막': <gensim.models.keyedvectors.Vocab at 0x7f5354b96190>,
#  '살해': <gensim.models.keyedvectors.Vocab at 0x7f5354b961d0>,
#  '부': <gensim.models.keyedvectors.Vocab at 0x7f5354b96210>,
#  '본인': <gensim.models.keyedvectors.Vocab at 0x7f5354b96250>,
#  '피해자': <gensim.models.keyedvectors.Vocab at 0x7f5354b96290>,
#  '필름': <gensim.models.keyedvectors.Vocab at 0x7f5354b962d0>,
#  '값': <gensim.models.keyedvectors.Vocab at 0x7f5354b96310>,
#  '매미': <gensim.models.keyedvectors.Vocab at 0x7f5354b96350>,
#  '드': <gensim.models.keyedvectors.Vocab at 0x7f5354b96390>,
#  '안습': <gensim.models.keyedvectors.Vocab at 0x7f5354b963d0>,
#  '혀': <gensim.models.keyedvectors.Vocab at 0x7f5354b96410>,
#  '짧다': <gensim.models.keyedvectors.Vocab at 0x7f5354b96450>,
#  '소리': <gensim.models.keyedvectors.Vocab at 0x7f5354b96490>,
#  '매니저': <gensim.models.keyedvectors.Vocab at 0x7f5354b964d0>,
#  '역활': <gensim.models.keyedvectors.Vocab at 0x7f5354b96510>,
#  '훨': <gensim.models.keyedvectors.Vocab at 0x7f5354b96550>,
#  '적당하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b96590>,
#  '스릴러': <gensim.models.keyedvectors.Vocab at 0x7f5354b965d0>,
#  '스릴': <gensim.models.keyedvectors.Vocab at 0x7f5354b96610>,
#  '이구': <gensim.models.keyedvectors.Vocab at 0x7f5354b96650>,
#  '전달': <gensim.models.keyedvectors.Vocab at 0x7f5354b96690>,
#  '할머니': <gensim.models.keyedvectors.Vocab at 0x7f5354b966d0>,
#  '월': <gensim.models.keyedvectors.Vocab at 0x7f5354b96710>,
#  '익숙하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b96750>,
#  '모든': <gensim.models.keyedvectors.Vocab at 0x7f5354b96790>,
#  '부족하다': <gensim.models.keyedvectors.Vocab at 0x7f5354b967d0>,
#  '쇼': <gensim.models.keyedvectors.Vocab at 0x7f5354b96810>,
#  '기억': <gensim.models.keyedvectors.Vocab at 0x7f5354b96850>,
#  '이름': <gensim.models.keyedvectors.Vocab at 0x7f5354b96890>,
#  '정은지': <gensim.models.keyedvectors.Vocab at 0x7f5354b968d0>,
#  '언니': <gensim.models.keyedvectors.Vocab at 0x7f5354b96910>,
#  '노래': <gensim.models.keyedvectors.Vocab at 0x7f5354b96950>,
#  '회': <gensim.models.keyedvectors.Vocab at 0x7f5354b96990>,
#  '즐겁다': <gensim.models.keyedvectors.Vocab at 0x7f5354b969d0>,
#  '트로트': <gensim.models.keyedvectors.Vocab at 0x7f5354b96a10>,
#  '연인': <gensim.models.keyedvectors.Vocab at 0x7f5354b96a50>,
#  '아이': <gensim.models.keyedvectors.Vocab at 0x7f5354b96a90>,
#  '시선': <gensim.models.keyedvectors.Vocab at 0x7f5354b96ad0>,
#  '내내': <gensim.models.keyedvectors.Vocab at 0x7f5354b96b10>,
#  '레알': <gensim.models.keyedvectors.Vocab at 0x7f5354b96b50>,
#  '함': <gensim.models.keyedvectors.Vocab at 0x7f5354b96b90>,
#  '여자애': <gensim.models.keyedvectors.Vocab at 0x7f5354b96bd0>,
#  '복': <gensim.models.keyedvectors.Vocab at 0x7f5354b96c10>,
#  '순이': <gensim.models.keyedvectors.Vocab at 0x7f5354b96c50>,
#  '굳이': <gensim.models.keyedvectors.Vocab at 0x7f5354b96c90>,
#  '어색': <gensim.models.keyedvectors.Vocab at 0x7f5354b96cd0>,
#  '연속극': <gensim.models.keyedvectors.Vocab at 0x7f5354b96d10>,
#  '인터뷰': <gensim.models.keyedvectors.Vocab at 0x7f5354b96d50>,
#  '킬링타임': <gensim.models.keyedvectors.Vocab at 0x7f5354b96d90>,
#  '박스': <gensim.models.keyedvectors.Vocab at 0x7f5354b96dd0>,
#  '오피스': <gensim.models.keyedvectors.Vocab at 0x7f5354b96e10>,
#  '싸움': <gensim.models.keyedvectors.Vocab at 0x7f5354b96e50>,
#  '다르다': <gensim.models.keyedvectors.Vocab at 0x7f5354b96e90>,
#  '여자': <gensim.models.keyedvectors.Vocab at 0x7f5354b96ed0>,
#  '기량': <gensim.models.keyedvectors.Vocab at 0x7f5354b96f10>,
#  '울': <gensim.models.keyedvectors.Vocab at 0x7f5354b96f50>,
#  '개연': <gensim.models.keyedvectors.Vocab at 0x7f5354b96f90>,
#  '조디': <gensim.models.keyedvectors.Vocab at 0x7f5354b96fd0>,
#  '개막': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a050>,
#  '계시다': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a090>,
#  '당신': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a0d0>,
#  '호구': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a110>,
#  '두기': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a150>,
#  '쌀': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a190>,
#  '세기': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a1d0>,
#  '명대사': <gensim.models.keyedvectors.Vocab at 0x7f5354b9a210>,
#  ...}

# %%
#배우의 벡터값 조회
word2vector["배우"]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([ 0.01185523, -0.15960456,  0.19185   , -0.19377986, -0.06037734,
#        -0.14665957, -0.08359569,  0.2341845 ,  0.02404744, -0.04222106,
#         0.22095029, -0.39420843, -0.21075441,  0.50225645,  0.4097956 ,
#         0.12697709,  0.21732622, -0.02985599,  0.25036064,  0.12217396],
#       dtype=float32)

# %%
#""의 벡터값 조회
word2vector[""]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# array([-0.03500871,  0.36088094,  0.08279353, -0.12636705, -0.10819418,
#        -0.00555942, -0.20104562,  0.08952411, -0.5526991 , -0.01348251,
#         0.36969137, -0.35676765, -0.23197262,  0.09171937,  0.1320546 ,
#         0.20936279,  0.13044913,  0.11336042,  0.08256648, -0.23611943],
#       dtype=float32)

# %%
#word2vector.wv.vocab.keys(): word2vector에 저장된 단어들을 Dictionary 객체로 리턴
word_vector_keys=word2vector.wv.vocab.keys()
word_vector_keys
# Out:
# dict_keys(['더빙', '진짜', '짜증나다', '목소리', '', '흠', '포스터', '보고', '초딩', '영화', '줄', '오버', '연기', '가볍다', '무재', '다그', '래서', '추천', '교도소', '이야기', '구먼', '솔직하다', '재미', '없다', '평점', '조정', '의', '익살스럽다', '스파이더맨', '이쁘다', '막', '걸음', '마', '세', '초등학교', '학년', '생인', '반개', '아깝다', '움', '원작', '긴장감', '제대로', '별', '욕', '이응경', '생활', '년', '정말', '발', '해도', '그것', '납치', '감금', '반복', '드라마', '가족', '사람', '네', '액션', '있다', '몇', '안되다', '왜케', '낮다', '꽤', '볼', '데', '헐리우드', '화려하다', '인피니트', '짱', '볼때', '향수', '자극', '허진호', '감성', '절제', '멜로', '달인', '울면', '손', '때', '뻔', '이범수', '드럽다', '담백하다', '깔끔하다', '좋다', '로만', '자꾸', '그', '것', '취향', '존중', '다지', '내생', '극장', '가장', '노잼', '노', '감동', '임', '스토리', '어거지', '냥', '매번', '긴장', '재밋음', '바스코', '이기', '락스', '코', '바비', '아이돌', '그냥', '안달', '굿바이', '레닌', '표절', '이해', '왜', '뒤', '갈수록', '이건', '깨알', '캐스팅', '산뜻하다', '용구성', '일드', '위', '변명', '놈', '착하다', '절대', '아니다', '걸', '나름', '심오하다', '뜻', '듯', '학생', '선생', '재미없다', '지루하다', '같다', '음식', '도', '만찬', '별로', '핀란드', '풍경', '평범하다', '수작', '는걸', '주제', '중반', '납득', '수', '그렇다', '꼭', '카밀라', '벨', '발연기', '센스', '연출', '탁월하다', '점', '위력', '다시', '한번', '적', '남', '꽃', '검사', '완전', '명품', '졸', '쓰레기', '진부하다', '도안', '시간', '재밌다', '기대하다', '내', '죄인', '이다', '이', '인생', '최고', '패션', '대한', '열정', '안나', '윈', '투어', '키이라', '나이틀리', '대체', '정신', '유령', '재미있다', '관객', '명', '평가', '단순하다', '은은하다', '매력', '알바생', '내용', '무섭다', '하나', '싱겁다', '낚임', '맘', '또', '방법', '윤제문', '멋지다', '배우', '발견', '소소하다', '탈', '잔잔하다', '미소', '머금', '음악', '조금', '아쉽다', '속지', '낭비', '돈', '리얼리티', '뛰어나다', '공감', '안', '간다', '이민기', '캐릭터', '분노조절', '장애', '초기', '툭하면', '패', '물건', '바', '초반', '신선하다', '가면', '상태', '불가', '마이너스', '뮤비', '수준', '알', '북한', '이렇다', '난', '우리', '사랑', '리스', '타르', '용의', '주인', '누', '근친상간', '소설', '속', '제일', '자', '메', '니스', '터', '드래곤', '용', '웃음', '감독', '토르', '다크', '월드', '말', '기본', '영혼', '수도', '상사', '잠시', '동화', '행복하다', '세르게이', '작다', '고추', '맵다', '맛', '저그', '콩', '진호', '가슴', '시리', '자체', '난또', '저', '꼬마', '애가', '무슨', '원한', '깊다', '혼자', '충격', '기분', '완전하다', '푹', '느낌', '활', '무겁다', '지독하다', '차갑다', '무자비하다', '일본인', '상상력', '대단하다', '생각', '그대로', '예측', '카리스마', '악역', '당황', '중간', '일상', '밋밋하다', '계속', '전개도', '느리다', '주인공', '은희', '컷', '극적', '모습', '짜증', '언제', '대만', '전개', '좀', '가슴속', '감정', '많다', '다큐', '우리나라', '슬프다', '현대', '사의', '단면', '대해', '깊이', '사죄', '바로', '잡기', '위해', '노력', '말로', '보도', '민간인', '학살', '이정', '일', '명백하다', '살인', '살인자', '어디', '예전', '작품', '에피소드', '재탕', '탕', '사골', '우려', '먹듯', '산', '시청률', '아예', '이제', '부작', '김남길', '연기력', '몰입도', '불구', '손예진', '비슷하다', '분', '노래실력', '박시환', '망신', '일본', '건가', '유치하다', '이틀', '차', '조작', '안이', '집', '활짝', '아무나', '문자', '건', '억지스럽다', '재밋네', '달팽이', '빨', '더', '어설프다', '어이없다', '결말', '부패하다', '기리', '뭣같', '온몸', '러시아', '민중', '폭도', '무난', '한국영', '흥행', '코드', '갈등', '계', '화해', '남발', '뻔하다', '뭐', '시작', '사진', '불안하다', '럼', '뭘', '엉망', '진창', '개', '우뢰매', '진정', '위대하다', '조미', '좋아하다', '가요', '눈', '성룡', '최악', '골', '인공', '강추', '클라라', '볼라', '화신', '설정', '새롭다', '메인', '마코토', '작화', '밉다', '유', '대박', '진심', '못', '노골', '술', '광고', '어떻다', '행복', '요', '쫌', '산만하다', '처음', '불륜', '로맨스', '왕', '아주', '짬뽕', '믹스', '음향', '기준', '패널', '가구', '머', '명작', '망치', '서운하다', '몬스터', '주식회사', '소재', '흥미', '끌', '투', '박하다', '몰입', '중국인', '특유', '과장', '허풍', '가상하다', '고증', '실감', '거북', '스럽다', '도대체', '스스로', '과대', '포장', '불법체류자', '미국', '따뜻하다', '뭥미', '삶속', '생애', '전부', '지난', '후', '지나', '순수하다', '숀펜', '또한', '올레', '공짜', '문제', '연기자', '전혀', '배역', '상대', '보아', '라미란', '아들', '젤', '욕심', '쪽', '베댓', '도둑', '뫼비우스', '나라', '짜릿', '나', '용기', '교훈', '화이', '당시', '상황', '주입', '식이', '전하', '다르덴', '채', '그릇', '여군', '잼', '엠비씨', '한석규', '김혜수', '어딘', '바이러스', '해', '면', '년전', '보기', '힘들다', '정도', '마지막', '후반', '부가', '살짝', '용가리', '짱짱맨', '감히', '하나로', '꼽', '살', '야하다', '고민', '모건', '프리', '멀다', '나이', '여전하다', '섹시하다', '작가', '용이', '기대', '재방송', '혹', '시나', '답', '여운', '왠만하다', '상업', '퀄리티', '질', '충분하다', '개인', '잔인하다', '노출씬', '화끈하다', '국산', '보임', '끝내', '지겹다', '역시', '드니', '일품', '맥스', '샘', '바랬다', '괜찮다', '실망', '지네', '면상', '자신', '어린이', '동심', '멀리', '무술', '크리스토퍼', '왈츠', '타란티노', '조합', '한국', '유명', '한편', '외국', '상상', '초월', '유명하다', '만', '재밋', '종방', '오늘', '방도', '방송', '대본', '완성', '요즘', '막장', '수백향', '심하다', '화이팅', '조절', '위원회', '김혜선',  ...

# %%
#X_train의 문자열을 Word2Vector 로 변환해서 저장할 배열
X_train_vector=[]
#len(X_train) : X_train의 줄의 수만큼 반복
for index in tqdm(range(len(X_train))):
    input=[]
    #X_train[index]: X_train (네이버 영화 리뷰 단어가 저장된 리스트)
    #                     index번째줄 

    #단어를 word에 대입
    for word in X_train[index]:
        #단어 word가 word_vector_keys(Word2Vector에서 벡터로 변환한 단어 리스트) 에 포함되 있으면
        if word in word_vector_keys:
            #word2vector[word] : 단어의 word2vector 값을 input에 추가
            input.append(word2vector[word].tolist())
        else: 
            #word2vector[""] : ""의 word2vector 값을 input에 추가
            input.append(word2vector[""].tolist()) 

    X_train_vector.append(input)
# Out:
#   0%|          | 0/125008 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#X_train_vector 를 numpy 배열로 변환
X_train_vector=np.array(X_train_vector, dtype="float32")

# %%
del X_train

# %%
#X_test 의 문자열을 Word2Vector 로 변환해서 저장할 배열
X_test_vector=[]
#len(X_test) : X_test의 줄의 수만큼 반복
for index in tqdm(range(len(X_test))):
    input=[]
    #X_test[index]: X_test (네이버 영화 리뷰 단어가 저장된 리스트)
    #                     index번째줄 

    #단어를 word에 대입
    for word in X_test[index]:
        #단어 word가 word_vector_keys(Word2Vector에서 벡터로 변환한 단어 리스트) 에 포함되 있으면
        if word in word_vector_keys:
            #word2vector[word] : 단어의 word2vector 값을 input에 추가
            input.append(word2vector[word].tolist())
        else: 
            #word2vector[""] : ""의 word2vector 값을 input에 추가
            input.append(word2vector[""].tolist()) 

    X_test_vector.append(input)
# Out:
#   0%|          | 0/41727 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
#메모리에서 X_test 삭제
del X_test

# %%
#예측을 실행할 모델 객체 생성
model = Sequential()


#LSTM 실행 객체
model.add(LSTM(units=128, input_shape=(40,20)))


#결과의 확률을 계산할 레이어 0(부정),1(긍정) 2개의 값중 하나가 리턴됨
model.add(Dense(1,activation="sigmoid"))

#model의 정보를 조회
model.summary()

# %%
#모델을 실행할 준비를 함
model.compile(loss='binary_crossentropy',
            optimizer=Adam(lr=1e-3),
            metrics=['acc'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
#y_train을 float32 타입으로 변환
y_train=np.array(y_train, dtype="float32")

# %%
#학습 시작
model.fit(X_train_vector, y_train,
          batch_size=1000,
          epochs=100)
# Out:
# Epoch 1/100
# 126/126 [==============================] - 15s 33ms/step - loss: 0.5216 - acc: 0.7194
# Epoch 2/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4517 - acc: 0.7921
# Epoch 3/100
# 126/126 [==============================] - 5s 41ms/step - loss: 0.4427 - acc: 0.7948
# Epoch 4/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4375 - acc: 0.7961
# Epoch 5/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4440 - acc: 0.7927
# Epoch 6/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4310 - acc: 0.7991
# Epoch 7/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4460 - acc: 0.7923
# Epoch 8/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4274 - acc: 0.8017
# Epoch 9/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4268 - acc: 0.8021
# Epoch 10/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4224 - acc: 0.8042
# Epoch 11/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4235 - acc: 0.8037
# Epoch 12/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4194 - acc: 0.8050
# Epoch 13/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4192 - acc: 0.8058
# Epoch 14/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4259 - acc: 0.8020
# Epoch 15/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4176 - acc: 0.8070
# Epoch 16/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4201 - acc: 0.8052
# Epoch 17/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4198 - acc: 0.8057
# Epoch 18/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4098 - acc: 0.8110
# Epoch 19/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4107 - acc: 0.8105
# Epoch 20/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4131 - acc: 0.8108
# Epoch 21/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4099 - acc: 0.8103
# Epoch 22/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4111 - acc: 0.8100
# Epoch 23/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4059 - acc: 0.8128
# Epoch 24/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4067 - acc: 0.8121
# Epoch 25/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4077 - acc: 0.8134
# Epoch 26/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4073 - acc: 0.8126
# Epoch 27/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4012 - acc: 0.8152
# Epoch 28/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4033 - acc: 0.8150
# Epoch 29/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4013 - acc: 0.8154
# Epoch 30/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4016 - acc: 0.8153
# Epoch 31/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.4107 - acc: 0.8084
# Epoch 32/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4028 - acc: 0.8144
# Epoch 33/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3994 - acc: 0.8173
# Epoch 34/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3996 - acc: 0.8172
# Epoch 35/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3964 - acc: 0.8179
# Epoch 36/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4013 - acc: 0.8167
# Epoch 37/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3958 - acc: 0.8184
# Epoch 38/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3949 - acc: 0.8194
# Epoch 39/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3968 - acc: 0.8186
# Epoch 40/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3919 - acc: 0.8208
# Epoch 41/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3950 - acc: 0.8189
# Epoch 42/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3929 - acc: 0.8199
# Epoch 43/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3927 - acc: 0.8200
# Epoch 44/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3922 - acc: 0.8194
# Epoch 45/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3904 - acc: 0.8217
# Epoch 46/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3900 - acc: 0.8210
# Epoch 47/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4024 - acc: 0.8157
# Epoch 48/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.4005 - acc: 0.8163
# Epoch 49/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3891 - acc: 0.8220
# Epoch 50/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3907 - acc: 0.8210
# Epoch 51/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3876 - acc: 0.8230
# Epoch 52/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3867 - acc: 0.8230
# Epoch 53/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3875 - acc: 0.8232
# Epoch 54/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3865 - acc: 0.8238
# Epoch 55/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3850 - acc: 0.8243
# Epoch 56/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3850 - acc: 0.8240
# Epoch 57/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3859 - acc: 0.8224
# Epoch 58/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3824 - acc: 0.8254
# Epoch 59/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3821 - acc: 0.8251
# Epoch 60/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3817 - acc: 0.8258
# Epoch 61/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3809 - acc: 0.8273
# Epoch 62/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3830 - acc: 0.8259
# Epoch 63/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3815 - acc: 0.8262
# Epoch 64/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3798 - acc: 0.8269
# Epoch 65/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3805 - acc: 0.8265
# Epoch 66/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3803 - acc: 0.8262
# Epoch 67/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3770 - acc: 0.8280
# Epoch 68/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3775 - acc: 0.8277
# Epoch 69/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3766 - acc: 0.8280
# Epoch 70/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3744 - acc: 0.8293
# Epoch 71/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3737 - acc: 0.8299
# Epoch 72/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3766 - acc: 0.8278
# Epoch 73/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3729 - acc: 0.8301
# Epoch 74/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3721 - acc: 0.8304
# Epoch 75/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3699 - acc: 0.8324
# Epoch 76/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3693 - acc: 0.8325
# Epoch 77/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3764 - acc: 0.8287
# Epoch 78/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3681 - acc: 0.8332
# Epoch 79/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3689 - acc: 0.8323
# Epoch 80/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3688 - acc: 0.8322
# Epoch 81/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3678 - acc: 0.8332
# Epoch 82/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3737 - acc: 0.8300
# Epoch 83/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3665 - acc: 0.8340
# Epoch 84/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3627 - acc: 0.8351
# Epoch 85/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3616 - acc: 0.8364
# Epoch 86/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3628 - acc: 0.8350
# Epoch 87/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3608 - acc: 0.8362
# Epoch 88/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3589 - acc: 0.8367
# Epoch 89/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3571 - acc: 0.8378
# Epoch 90/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3638 - acc: 0.8347
# Epoch 91/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3634 - acc: 0.8346
# Epoch 92/100
# 126/126 [==============================] - 4s 33ms/step - loss: 0.3582 - acc: 0.8367
# Epoch 93/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3673 - acc: 0.8321
# Epoch 94/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3589 - acc: 0.8362
# Epoch 95/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3642 - acc: 0.8339
# Epoch 96/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3689 - acc: 0.8343
# Epoch 97/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3575 - acc: 0.8379
# Epoch 98/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3543 - acc: 0.8384
# Epoch 99/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3546 - acc: 0.8388
# Epoch 100/100
# 126/126 [==============================] - 4s 32ms/step - loss: 0.3505 - acc: 0.8409

# %%
#X_test_vector를 float32타입으로 변환
X_test_vector=np.array(X_test_vector, dtype="float32")

#y_test를 float32타입으로 변환
y_test=np.array(y_test, dtype="float32")

# %%
X_test_vector
# Out:
# array([[[-0.12288953,  0.10275614,  0.3767739 , ..., -0.13227223,
#          -0.12940075, -0.38132054],
#         [-0.01166544,  0.14941117,  0.15048963, ..., -0.12616794,
#           0.03345062, -0.17532158],
#         [-0.12190376,  0.01557616, -0.31275576, ..., -0.0972045 ,
#           0.09026631, -0.32357538],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]],
#
#        [[-0.1294102 ,  0.23440921,  0.33660397, ..., -0.00479057,
#          -0.25034222, -0.3470017 ],
#         [-0.08075727,  0.05239418,  0.20988086, ..., -0.06312324,
#           0.03398941, -0.13937093],
#         [-0.12074304,  0.23797783,  0.15654266, ...,  0.01097202,
#          -0.41895375, -0.0325513 ],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]],
#
#        [[-0.02896577, -0.02337262,  0.2434517 , ..., -0.2719593 ,
#          -0.05532892, -0.10225643],
#         [-0.38130766,  0.02267152,  0.20997289, ..., -0.27406326,
#          -0.18354161, -0.30391866],
#         [-0.02798692,  0.00726225, -0.17113614, ...,  0.09038593,
#          -0.10634874, -0.31307954],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]],
#
#        ...,
#
#        [[-0.19611691, -0.03806952,  0.57464   , ...,  0.18079881,
#           0.20620753, -0.19858399],
#         [-0.523282  , -0.35575002,  0.5252953 , ..., -0.26110616,
#          -0.09829024, -0.04725566],
#         [-0.33170417, -0.00059542,  0.1537171 , ..., -0.16487907,
#           0.11609724,  0.09921939],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]],
#
#        [[ 0.08819132,  0.31493288, -0.07694185, ...,  0.02846605,
#          -0.12932625, -0.52744955],
#         [ 0.04242535, -0.00384532,  0.39202383, ..., -0.323533  ,
#          -0.1963636 , -0.31651685],
#         [ 0.18397191, -0.07872152,  0.29367295, ...,  0.23349811,
#           0.10747775, -0.41494155],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]],
#
#        [[-0.18882251,  0.20357604,  0.42374614, ...,  0.09982598,
#          -0.08849637, -0.04805927],
#         [ 0.05531984,  0.30017477,  0.32749116, ..., -0.08329111,
#          -0.03230803, -0.01034633],
#         [ 0.07098529, -0.10853317,  0.35789815, ..., -0.16234863,
#           0.11709458, -0.45498317],
#         ...,
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943],
#         [-0.03500871,  0.36088094,  0.08279353, ...,  0.11336042,
#           0.08256648, -0.23611943]]], dtype=float32)

# %%
#X_test_vector(테스트 데이터) 의 cost와 정확도 조회
model.evaluate(X_test_vector, y_test)
# Out:
# 1304/1304 [==============================] - 7s 5ms/step - loss: 0.4012 - acc: 0.8196
# [0.4011814296245575, 0.8195652961730957]

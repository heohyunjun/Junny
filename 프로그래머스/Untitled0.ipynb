# %% [markdown]
# <a href="https://colab.research.google.com/github/heohyunjun/Junny/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 음양더하기

# %%
absolutes = [4,7,12]
signs = [True,False,True]

# %%
def solution(absolutes, signs):
  answer = 0
  for i in range(len(absolutes)):
    if sign[i]:
      answer += abs[i]
    else:
      answer -= abs[i]
  return answer
  
def solution(absolutes, signs):
  answer = 0
  for abs,sign in zip(absolutes, signs):
    if sign:
      answer += abs
    else:
      answer -= abs
  return answer

# %%
def solution(absolutes, signs):
  return sum(abs if sign else -abs for abs,sign in zip(absolutes,signs))

# %%
solution(absolutes,signs)
# Out:
# 9

# %% [markdown]
# # 내적

# %%
# a와 b의 내적은 1*(-3) + 2*(-1) + 3*0 + 4*2 = 3

# %%
a = [1, 2, 3, 4]
b = [-3, -1, 0, 2]

# %%
answer = 0
for i,j in zip(a,b):
  answer += (i*j)
# Out:
# 3

# %%
def solution(a, b):
    return sum(i*j for i,j in zip(a,b))

# %%
import numpy as np

def solution(a, b):
    return np.dot(a,b)

# %%
solution(a,b)
# Out:
# 3

# %% [markdown]
# # K번쨰수

# %% [markdown]
# 배열 array의 i번째 숫자부터 j번째 숫자까지 자르고 정렬했을 때, k번째에 있는 수를 구하려 합니다.
#
# 예를 들어 array가 [1, 5, 2, 6, 3, 7, 4], i = 2, j = 5, k = 3이라면
#
# 1. array의 2번째부터 5번째까지 자르면 [5, 2, 6, 3]입니다.
# 2. 1에서 나온 배열을 정렬하면 [2, 3, 5, 6]입니다.
# 3. 2에서 나온 배열의 3번째 숫자는 5입니다.
#
# ![image.png](data:image/png;base64,...)

# %%
array1 = [1, 5, 2, 6, 3, 7, 4]
commands = [[2, 5, 3], [4, 4, 1], [1, 7, 3]]
return1 = [5, 6, 3]

# %%
def solution(array, commands):
    return list(map(lambda x:sorted(array[x[0]-1:x[1]])[x[2]-1], commands))

# %%
def solution(array, commands):
  answer = []
  for i in range(len(commands)):
    answer.append(sorted(array1[commands[i][0] -1: commands[i][1]])[commands[i][2]-1])
  return answer

# %%
solution(array1,commands)
# Out:
# [5, 6, 3]

# %% [markdown]
# # 두개 뽑아서 더하기

# %% [markdown]
# 정수 배열 numbers 주어짐.
#
# 1. numbers에서 서로 다른 인덱스에 있는 두 개의 수를 뽑아
#
# 2. 더해서 만들 수 있는 모든 수를 배열에 오름차순으로 담아
#
# 3. return 하도록 solution 함수를 완성
#
#
# ![image.png](data:image/png;base64,...)

# %%
numbers = [2, 1, 3, 4, 1]
result = [2, 3, 4, 5, 6, 7]

# %%
import itertools

# %%
answer = []
for i in list(itertools.combinations(numbers, 2)):
  if i[0] + i[1] not in answer:
    answer.append(i[0] + i[1])
  
sorted(list(set(answer)))
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
for i in range(len(numbers)):
  for j in range(i+1, len(numbers)):
    print(j)
    answer.append(numbers[i] + numbers[j])
    print(answer)

# %% [markdown]
# # 정수내림차순으로 배치하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
"".join(sorted(list(str(n)),reverse = True))
# Out:
# '873211'

# %%
 n = 118372
def solution(n):
  str1 =""
  for i in sorted(list(str(n)),reverse = True):
    str1 += i
  return int(str1)
solution(n)
# Out:
# 873211

# %%
def solution(n):
    ls = list(str(n))
    ls.sort(reverse = True)
    return int("".join(ls))

# %%
solution(n)

# %% [markdown]
# # 두 정수사이의 합

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
a = 3
b = 5
sum(i for i in range(min(a,b), max(a,b)+1))
# Out:
# 12

# %% [markdown]
# # 짝수 홀수

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num = 4
# Out:
# 'Even'

# %%
def solution(num):
    return "Odd" if num%2 else "Even"
solution(5)
# Out:
# 'Odd'

# %% [markdown]
# # 콜라츠 추측

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = 6
result = 8

# %%
cnt = 0
while(True):

  if n%2 == 1:
      cnt +=1
      n = n*3 +1
  if n %2 ==0:
      cnt +=1
      n = n/2
  if n == 1:
      cnt +=1
      break
  if cnt > 500 and num != 1:
      cnt = -1

cnt
# Out:
# 7

# %% [markdown]
# # 다트게임

# %% [markdown]
# 1. 다트 게임은 총 3번
# 2. 각 기회마다 얻을 수 있는 점수는 0점에서 10점
# 3. 점수와 함께 Single(S), Double(D), Triple(T) 영역이 존재하고 각 영역 당첨 시 점수에서 1제곱, 2제곱, 3제곱 (점수1 , 점수2 , 점수3 )으로 계산된다.
# 4. 옵션으로 스타상(*) , 아차상(#)이 존재하며 스타상(*) 당첨 시 해당 점수와 바로 전에 얻은 점수를 각 2배로 만든다. 아차상(#) 당첨 시 해당 점수는 마이너스된다.
# 5. 스타상(*)은 첫 번째 기회에서도 나올 수 있다. 이 경우 첫 번째 스타상(*)의 점수만 2배가 된다. (예제 4번 참고)
# 6. 스타상(*)의 효과는 다른 스타상(*)의 효과와 중첩될 수 있다. 이 경우 중첩된 스타상(*) 점수는 4배가 된다. (예제 4번 참고)
# 7. 스타상(*)의 효과는 아차상(#)의 효과와 중첩될 수 있다. 이 경우 중첩된 아차상(#)의 점수는 -2배가 된다. (예제 5번 참고)
# 8. Single(S), Double(D), Triple(T)은 점수마다 하나씩 존재한다.
# 스타상(*), 아차상(#)은 점수마다 둘 중 하나만 존재할 수 있으며, 존재하지 않을 수도 있다.

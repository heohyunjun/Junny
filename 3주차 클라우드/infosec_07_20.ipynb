# %% [markdown]
# # Flask in colab

# %%
# !pip install flask-ngrok

# %%
# !pip install pyecharts

# %%
from flask_ngrok import run_with_ngrok
from flask import Flask, render_template
import matplotlib.pyplot as plt
import pandas as pd
from pyecharts.charts import Bar
from pyecharts import options as opts

# %%
plt.style.use("seaborn")
plt.rc('font', family = 'NanumGothic')

# %%
path ='/content/drive/MyDrive/Colab Notebooks/AI_허현준/dataset/weather.csv'
df = pd.read_csv(path, index_col = "point")
city_df = df.loc[["서울", "인천", "대전", "대구", "광주", "부산", "울산"]]
city_df

# %%
city_df
# Out:
#        temperature  humidity
# point
# 서울            34.0        46
# 인천            31.0        46
# 대전            31.1        67
# 대구            30.9        52
# 광주            30.2        63
# 부산            28.2        73
# 울산            27.8        74

# %%
app = Flask(__name__)
run_with_ngrok(app)   
# @app.route("/")
# def hello():
#   return render_template('form.html')

@app.route("/view_weather2")
def view_weatehr1():

  ax = city_df.plot(kind = "bar", title = "날씨", figsize=(12, 4), legend=True, fontsize = 12)

  ax.set_xlabel("도시",fontsize = 20)
  ax.set_ylabel("기온/습도", fontsize = 30)

  ax.legend(['기온','습도'], fontsize = 20)

  plt.savefig("/content/static/weather1.png")
  return render_template("weather1.html", image_name = "weather1.png",title = "광역시 날씨 시각화")

# %%
@app.route("/")
def view_weather2():
  bar = Bar()
  
  bar.add_xaxis(["서울", "인천", "대전", "대구", "광주", "부산", "울산"])
  
  bar.add_yaxis("온도", city_df["temperature"].tolist())
  bar.add_yaxis("습도", city_df["humidity"].tolist())
  
  bar.set_global_opts(title_opts =opts.TitleOpts(title = "광역시 온도 습도"))
  
  bar.render('/content/static/bar1.html')

  return render_template("weather2.html", graph_file_name = "bar1.html",title = "광역시 온습도")

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
#  * Running on http://ce23fc7f66a8.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 127.0.0.1 - - [23/Jul/2021 13:56:35] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Jul/2021 13:56:35] "GET /static/bar1.html HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Jul/2021 13:56:40] "GET /favicon.ico HTTP/1.1" 404 -

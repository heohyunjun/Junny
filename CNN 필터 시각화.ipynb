# %% [markdown]
# # CNN 필터 시각화
#
# - 603~637

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
from keras import models
import matplotlib.pyplot as plt

# %%
model_path = '/content/drive/MyDrive/cats_and_dogs_small_cnn.h5'
img_path = '/content/drive/MyDrive/Colab Notebooks/AI_허현준/12주차 DNN_CNN/datasets/cats_and_dogs/cats_and_dogs_small/test/cats/cat.1700.jpg'

# %%
model = load_model(model_path)

# %%
# 이미지 로드
img = image.load_img(img_path, target_size=(220,220))

# 3차원으로 변환
img_tensor = image.img_to_array(img)
print(img_tensor.shape)

# 4차원으로 변환
img_tensor = np.expand_dims(img_tensor, axis =0)
print(img_tensor.shape)

# 범위 수정
img_tensor = img_tensor/255

# 예측
model.predict(img_tensor)
# Out:
# (220, 220, 3)
# (1, 220, 220, 3)
# array([[0.30759504]], dtype=float32)

# %% [markdown]
# 필터 시각화

# %%
plt.imshow(img_tensor[0])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
layer_outputs = [layer.output for layer in model.layers[:6]]
layer_outputs
# Out:
# [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>,
#  <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>,
#  <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>,
#  <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>,
#  <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>,
#  <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>]

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 220, 220, 3) dtype=float32 (created by layer 'conv2d_input')>

# %%
activation_model = models.Model(
    # 이미지를 필터 연산가능하게 준비
    inputs = model.input,

    # 필터
    outputs = layer_outputs
)
activation_model

# %%
activations = activation_model.predict(img_tensor)

# %%
# 각 단계별 연산 결과 확인
for i in range(len(activations)):
  print("모델 layer 계산 {}층 , {} :".format(i ,layer_outputs))
  print("img_tensor 연산 결과 :")
  print("activations[{}].shape ={} ".format(i, activations[i].shape))
  print("="*100)
# Out:
# 모델 layer 계산 0층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[0].shape =(1, 220, 220, 32)
# ====================================================================================================
# 모델 layer 계산 1층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[1].shape =(1, 110, 110, 32)
# ====================================================================================================
# 모델 layer 계산 2층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[2].shape =(1, 110, 110, 64)
# ====================================================================================================
# 모델 layer 계산 3층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[3].shape =(1, 55, 55, 64)
# ====================================================================================================
# 모델 layer 계산 4층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[4].shape =(1, 55, 55, 128)
# ====================================================================================================
# 모델 layer 계산 5층 , [<KerasTensor: shape=(None, 220, 220, 32) dtype=float32 (created by layer 'conv2d')>, <KerasTensor: shape=(None, 110, 110, 32) dtype=float32 (created by layer 'max_pooling2d')>, <KerasTensor: shape=(None, 110, 110, 64) dtype=float32 (created by layer 'conv2d_1')>, <KerasTensor: shape=(None, 55, 55, 64) dtype=float32 (created by layer 'max_pooling2d_1')>, <KerasTensor: shape=(None, 55, 55, 128) dtype=float32 (created by layer 'conv2d_2')>, <KerasTensor: shape=(None, 28, 28, 128) dtype=float32 (created by layer 'max_pooling2d_2')>] :
# img_tensor 연산 결과 :
# activations[5].shape =(1, 28, 28, 128)
# ====================================================================================================

# %%
# 첫번쨰 필터 시각화
layer_out = activations[0]
layer_out.shape

fig = plt.figure(figsize = (15, 20))

# 첫번째 연산 필터 결과
i = 0
for i in range(32):
  subplot = fig.add_subplot(8, 4, i+1)
  subplot = plt.imshow(layer_out[0, :, :, i])

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 두번쨰 필터 시각화
layer_out = activations[2]
layer_out.shape

fig = plt.figure(figsize = (15, 40))

# 첫번째 연산 필터 결과
i = 0
for i in range(32):
  subplot = fig.add_subplot(16, 4, i+1)
  subplot = plt.imshow(layer_out[0, :, :, i])

# %% [markdown]
# ![image.png](data:image/png;base64,...)
